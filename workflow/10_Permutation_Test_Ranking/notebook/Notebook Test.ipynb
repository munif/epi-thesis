# %%
import polars
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import polars
#
# ModuleNotFoundError: No module named 'polars'

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !which python
# Out:
# /mmfs1/data/group/pmc021/amunif/env/pytorch/bin/python

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3
