# %%
import os
import glob
import pandas as pd

# %%
OUTPUT_PATH = "/group/pmc021/amunif/epi-thesis/workflow/10_Permutation_Test_Ranking/output/E066/test/"

# %%
# Get CSV files list from a folder
csv_files = glob.glob(os.path.join(OUTPUT_PATH, "*.csv"))
print(len(csv_files))
# Out:
# 325

# %%
# Read each CSV file into DataFrame
# This creates a list of dataframes
df_list = (pd.read_csv(file) for file in csv_files)

# %%
# Concatenate all DataFrames
big_df = pd.concat(df_list, ignore_index=True)

# %%
big_df
# Out:
#                                 histone_marker  train_loss_avg  \
# 0                                      H3K4me3          0.5609
# 1                                      H3K4me1          0.5989
# 2                                     H3K36me3          0.6692
# 3                                      H3K9me3          0.7092
# 4                                     H3K27me3          0.6793
# ..                                         ...             ...
# 320  H3K36me3-H3K9me3-H3K27me3-H3K4me3-H3K4me1          0.5236
# 321  H3K9me3-H3K4me3-H3K36me3-H3K4me1-H3K27me3          0.5205
# 322  H3K9me3-H3K27me3-H3K36me3-H3K4me3-H3K4me1          0.5266
# 323  H3K9me3-H3K36me3-H3K4me3-H3K4me1-H3K27me3          0.5203
# 324  H3K27me3-H3K4me1-H3K36me3-H3K4me3-H3K9me3          0.5257
#
#      train_accuracy_avg  train_auc_avg  val_loss_avg  val_accuracy_avg  \
# 0               73.7001         0.7378        0.5534           74.1578
# ...

# %%
# Save the files into single file
big_df.to_csv("all_results.csv", header=True, index=True)
