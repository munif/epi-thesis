# %%
import os
import glob
import pandas as pd

# %%
OUTPUT_PATH = "/group/pmc021/amunif/epi-thesis/workflow/10_Permutation_Test_Ranking/output/test/metric"

# %%
# Get CSV files list from a folder
csv_files = glob.glob(os.path.join(OUTPUT_PATH, "*.csv"))
print(len(csv_files))
# Out:
# 325

# %%
# Read each CSV file into DataFrame
# This creates a list of dataframes
df_list = (pd.read_csv(file) for file in csv_files)

# %%
df_list
# Out:
# <generator object <genexpr> at 0x7fae1cfa0110>

# %%
# Concatenate all DataFrames
big_df = pd.concat(df_list, ignore_index=True)

# %%
big_df
# Out:
#                       histone_marker  train_loss_avg  train_accuracy_avg  \
# 0                            H3K4me3          0.5954             70.0038
# 1                             H3K9ac          0.5984             69.8779
# 2                            H3K9me3          0.7064             52.6970
# 3                            H3K27ac          0.6009             69.6019
# 4                           H3K27me3          0.6963             54.8774
# ..                               ...             ...                 ...
# 320  H3K9me3-H3K9ac-H3K27ac-H3K27me3          0.5864             70.6571
# 321  H3K27ac-H3K27me3-H3K9me3-H3K9ac          0.5903             70.4852
# 322  H3K9me3-H3K9ac-H3K27me3-H3K27ac          0.5834             70.7144
# 323  H3K27me3-H3K9ac-H3K9me3-H3K27ac          0.5867             70.5711
# 324  H3K9me3-H3K27ac-H3K9ac-H3K27me3          0.5849             70.6423
#
#      train_auc_avg  val_loss_avg  val_accuracy_avg  val_auc_avg  \
# ...

# %%
# Save the files into single file
big_df.to_csv(os.path.join("all_results.csv"), header=True, index=True)
