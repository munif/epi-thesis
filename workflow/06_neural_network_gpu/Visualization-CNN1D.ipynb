# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plotting(df, c1, c2):
    plt.figure(figsize=(10, 6))
    plt.scatter(df.index, df[c1], label=f"value_1 {c1}", marker='o',)
    plt.scatter(df.index, df[c2], label=f"value_1 {c2}", marker='x', alpha=0.5)
    
    plt.xlabel('Row Number')
    plt.ylabel('value_1')
    # plt.yscale('log', base=10)
    plt.title('y_train vs y_pred')
    plt.legend()
    plt.grid(True)
    
    # Save the plot to a file
    plt.savefig(f'img/cnn1d/{c1}_vs_{c2}.png')
    
    plt.show()

# %%
def plotting_selected(df, c1, c2):
    plt.figure(figsize=(10, 6))
    plt.scatter(df.index, df[c1], label=f"value_1 {c1}", marker='o',)
    plt.scatter(df.index, df[c2], label=f"value_1 {c2}", marker='x', alpha=0.5)
    
    plt.xlabel('Row Number')
    plt.ylabel('value_1')
    # plt.yscale('log', base=10)
    plt.title('y_train vs y_pred')
    plt.legend()
    plt.grid(True)
    
    # Save the plot to a file
    #plt.savefig(f'img/fcnn/{c1}_vs_{c2}.png')
    
    plt.show()

# %% [markdown]
# # Visualization for Train Dataset

# %%
y_train = pd.read_csv('predictions/predictions_conv1d_train_20240805220922.csv')
y_train.head()
# Out:
#      y_train     y_pred
# 0   0.011101   0.503978
# 1  16.231900  24.000633
# 2   0.000000   2.114122
# 3  38.495300   8.240180
# 4  18.240000   4.531988

# %%
y_train.describe()
# Out:
#             y_train        y_pred
# count  47492.000000  47492.000000
# mean      18.756429     15.111837
# std      133.401878     62.871498
# min        0.000000   -306.489930
# 25%        0.000000      2.114122
# 50%        1.018850      4.138930
# 75%       12.211925     16.349258
# max     9933.060000   7850.116700

# %%
y_train.sort_values(by=y_train.columns[0], inplace=True)
y_train = y_train.reset_index(drop=True)
y_train.head()
# Out:
#    y_train     y_pred
# 0      0.0  16.209227
# 1      0.0  12.939656
# 2      0.0   2.114122
# 3      0.0   2.114122
# 4      0.0   2.114122

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_train.index, y_train['y_train'])
plt.show()

# %%
plotting(y_train, 'y_train', 'y_pred')

# %%
y_selected = y_train[(y_train['y_train'] <= 16.349258) & (y_train['y_pred'] <= 16.349258)]
y_selected.describe()
# Out:
#             y_train        y_pred
# count  32008.000000  32008.000000
# mean       2.093675      3.773144
# std        3.798081      5.401338
# min        0.000000   -188.567080
# 25%        0.000000      2.114122
# 50%        0.058760      2.114122
# 75%        2.469180      5.390904
# max       16.333400     16.348291

# %%
plotting_selected(y_selected, 'y_train', 'y_pred')

# %% [markdown]
# # Visualization for Test Dataset

# %%
y_test = pd.read_csv('predictions/predictions_conv1d_20240716084058.csv')
y_test.head()
# Out:
#       y_test     y_pred
# 0   0.000000   2.114122
# 1   0.000000   2.114122
# 2   0.078264   2.114122
# 3   0.005756   2.114122
# 4  13.954200  18.808857

# %%
y_test.sort_values(by=y_test.columns[0], inplace=True)
y_test = y_test.reset_index(drop=True)
y_test.head()
# Out:
#    y_test     y_pred
# 0     0.0   2.114122
# 1     0.0   2.114122
# 2     0.0   2.114122
# 3     0.0   2.114122
# 4     0.0  13.440008

# %%
y_test.describe()
# Out:
#              y_test        y_pred
# count  11874.000000  11874.000000
# mean      18.419855     14.581292
# std      113.170104     49.367330
# min        0.000000   -188.567080
# 25%        0.000000      2.114122
# 50%        1.062580      4.217390
# 75%       11.626900     16.760245
# max     5475.900000   1614.983900

# %%
plotting(y_test, 'y_test', 'y_pred')

# %%
y_test_selected = y_test[(y_test['y_test'] <= 16.760245) & (y_test['y_pred'] <= 16.760245)]
y_test_selected.head()
# Out:
#    y_test     y_pred
# 0     0.0   2.114122
# 1     0.0   2.114122
# 2     0.0   2.114122
# 3     0.0   2.114122
# 4     0.0  13.440008

# %%
plotting_selected(y_test_selected, 'y_test', 'y_pred')
