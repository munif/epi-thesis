# %%
# !which python
# Out:
# /group/pmc021/amunif/env/pytorch2/bin/python

# %%
import sys

# %%
print(sys.path)
# Out:
# ['/group/pmc021/amunif/env/pytorch2/lib/python311.zip', '/group/pmc021/amunif/env/pytorch2/lib/python3.11', '/group/pmc021/amunif/env/pytorch2/lib/python3.11/lib-dynload', '', '/group/pmc021/amunif/env/pytorch2/lib/python3.11/site-packages']

# %%
import torch

# %%
import polars

# %%
torch.__version__
# Out:
# '2.6.0'

# %%
polars.__version__
# Out:
# '1.31.0'
