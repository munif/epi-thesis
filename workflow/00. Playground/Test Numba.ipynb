# %%
import numba
import pandas as pd
import numpy as np

from numba import njit

# %%
numba.set_num_threads(1)

# %%
numba.set_num_threads(16)

# %%
df = pd.DataFrame(np.random.randn(10_000, 100))

# %%
roll = df.rolling(100)

# %%
# %timeit roll.mean(engine="numba", engine_kwargs={"parallel": True})
# Out:
# 18.3 ms ± 1.96 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit roll.mean(engine="numba", engine_kwargs={"parallel": True})
# Out:
# 5.28 ms ± 952 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
