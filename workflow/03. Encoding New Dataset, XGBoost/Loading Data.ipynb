# %%
import pandas as pd

# %%
dataset_path = "/group/pmc021/amunif/epi-thesis/dataset/"

# %%
chrom_df = pd.read_csv(f"{dataset_path}chrom_df.csv")
print(chrom_df.head())
print(chrom_df.shape)

# %%
value_1_df = pd.read_csv(f"{dataset_path}value_1_df.csv")
print(value_1_df.head())
print(value_1_df.shape)

# %%
h3k4me3_df = pd.read_csv(f"{dataset_path}h3k4me3_df.csv")
print(h3k4me3_df.head())
print(h3k4me3_df.shape)
