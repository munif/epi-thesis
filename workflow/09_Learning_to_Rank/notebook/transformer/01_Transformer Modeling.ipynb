# %%
import sys

sys.path.insert(0, '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/notebook/mylib')
print(sys.path)
# Out:
# ['/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/notebook/mylib', '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/notebook/transformer', '/uwahpc/centos8/python/Anaconda3/2024.06/lib/python312.zip', '/uwahpc/centos8/python/Anaconda3/2024.06/lib/python3.12', '/uwahpc/centos8/python/Anaconda3/2024.06/lib/python3.12/lib-dynload', '', '/home/amunif/.local/lib/python3.12/site-packages', '/uwahpc/centos8/python/Anaconda3/2024.06/lib/python3.12/site-packages']

# %%
import os
import random
from datetime import datetime

import pandas as pd
import polars as pl
import numpy as np

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import Dataset, DataLoader, TensorDataset

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

import BinaryClassifier as BC
import HepG2Dataset as HG2D
import my_util
import BinaryTransformer as BT

# %%
# Declare  variables, working directory and dataset directory
MODE = 'all_features'
NUM_EPOCHS = 100
START_EPOCH = 0
NUM_ITEMS = 1_000_000
BATCH_SIZE = 128
DROPOUT_RATE = 0.2

L1_lambda = 0.005
L2_lambda = 0.001
# L1_lambda = 0.0
# L2_lambda = 0.0

WORKING_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank'
DATASET_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/dataset'

MODEL_MODE = "dol1l2" # regular (reg), dropout (do), dropout + l1l2 (dol1l2)
PREFIX = f"{MODEL_MODE}-transformer-{DROPOUT_RATE}"
SUFFIX = f"{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}-{L1_lambda}-{L2_lambda}"

CHECKPOINT_NAME = os.path.join(WORKING_DIR, 'output', 'transformer', MODE, 'model', f'{PREFIX}-checkpoint-{SUFFIX}.pt')

IMAGE_FILE = os.path.join(WORKING_DIR, 'output', 'transformer', MODE, 'img', 'train', f"{PREFIX}-ranking-{SUFFIX}.png")
TEST_FILE = os.path.join(WORKING_DIR, 'output', 'transformer', MODE, 'test', f"{PREFIX}-test-results-{SUFFIX}.txt")
TRAINING_FILE = os.path.join(WORKING_DIR, 'output', 'transformer', MODE, "train", f"{PREFIX}-train-validation-metrics-{SUFFIX}.csv")
TEST_RESULT_FILE = os.path.join(WORKING_DIR, 'output', 'transformer', MODE, "test", f"{PREFIX}-test-metrics-{SUFFIX}.csv")
ROC_FILE = os.path.join(WORKING_DIR, 'output', 'transformer', MODE, 'img', 'roc', f"{PREFIX}-roc-{SUFFIX}.png")
CM_FILE = os.path.join(WORKING_DIR, 'output', 'transformer', MODE, 'img', 'cm', f"{PREFIX}-cm-{SUFFIX}.png")

INPUT_SIZE = 40000

print(CHECKPOINT_NAME)
# Out:
# /group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/output/transformer/all_features/model/dol1l2-transformer-0.2-checkpoint-1000000-100-128-0.005-0.001.pt

# %%
device = my_util.get_device()
# Out:
# Using device: cuda
# Current CUDA device: 0
# CUDA device name: Tesla P100-SXM2-16GB

# %%
# Parameters
input_dim = 20000 # input dimension
d_model = 512
nhead = 8
num_layers = 6
output_dim = 20000  # output dimension

# %%
# Create model
model_1d = BT.BinaryTransformer1D(input_dim, d_model, nhead, num_layers, output_dim).to(device)

# %%
# Load dataset
all_features = pl.read_parquet(os.path.join(DATASET_DIR, 'features', f'{MODE}.parquet'))
all_features
# Out:
# shape: (22_154, 4)
# ┌───────┬─────────────┬───────────────────┬───────────┐
# │ index ┆ gene_id     ┆ all_features      ┆ value_1   │
# │ ---   ┆ ---         ┆ ---               ┆ ---       │
# │ u32   ┆ str         ┆ list[f64]         ┆ f64       │
# ╞═══════╪═════════════╪═══════════════════╪═══════════╡
# │ 0     ┆ XLOC_000001 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 1     ┆ XLOC_000003 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 2     ┆ XLOC_000006 ┆ [0.0, 0.0, … 0.0] ┆ 0.0888452 │
# │ 3     ┆ XLOC_000007 ┆ [0.0, 0.0, … 0.0] ┆ 4.04743   │
# │ 4     ┆ XLOC_000008 ┆ [0.0, 0.0, … 0.0] ┆ 26.7934   │
# │ …     ┆ …           ┆ …                 ┆ …         │
# │ 22149 ┆ XLOC_030009 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22150 ┆ XLOC_030012 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22151 ┆ XLOC_030014 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22152 ┆ XLOC_030017 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22153 ┆ XLOC_030018 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# └───────┴─────────────┴───────────────────┴───────────┘

# %%
all_features_np = all_features.to_numpy()
all_features_np
# Out:
# array([[0, 'XLOC_000001', array([0., 0., 0., ..., 0., 0., 0.]), 0.0],
#        [1, 'XLOC_000003', array([0., 0., 0., ..., 0., 0., 0.]), 0.0],
#        [2, 'XLOC_000006', array([0., 0., 0., ..., 0., 0., 0.]),
#         0.0888452],
#        ...,
#        [22151, 'XLOC_030014', array([0., 0., 0., ..., 0., 0., 0.]), 0.0],
#        [22152, 'XLOC_030017', array([0., 0., 0., ..., 0., 0., 0.]), 0.0],
#        [22153, 'XLOC_030018', array([0., 0., 0., ..., 0., 0., 0.]), 0.0]],
#       dtype=object)

# %%
transformed = []

for i in range(all_features_np.shape[0]):
    transformed.append(BT.transform_feature(all_features_np[i, 2], model_1d, device))
    if (i % 1000 == 0):
        print(f"Processing {i}/{all_features_np.shape[0]}")
# Out:
# Processing 0/22154
# Processing 1000/22154
# Processing 2000/22154
# Processing 3000/22154
# Processing 4000/22154
# Processing 5000/22154
# Processing 6000/22154
# Processing 7000/22154
# Processing 8000/22154
# Processing 9000/22154
# Processing 10000/22154
# Processing 11000/22154
# Processing 12000/22154
# Processing 13000/22154
# Processing 14000/22154
# Processing 15000/22154
# Processing 16000/22154
# Processing 17000/22154
# Processing 18000/22154
# Processing 19000/22154
# Processing 20000/22154
# Processing 21000/22154
# Processing 22000/22154

# %%
af_transformed = np.empty((all_features_np.shape[0], all_features_np.shape[1] + 1), dtype=object)

# %%
af_transformed[:, :-1] = all_features_np
af_transformed[:, -1] = transformed

# %%
af_transformed.shape
# Out:
# (22154, 5)

# %%
# Split train, test, validation by index
data_indices = np.arange(len(af_transformed))
print(data_indices)
# Out:
# [    0     1     2 ... 22151 22152 22153]

# %%
# First split: 80% train, 20% temporary (for test + validation)
train_idx, temp_idx = train_test_split(
    data_indices, 
    test_size=0.2, 
    random_state=42  # For reproducibility
)

# %%
# Second split: Split temp_idx into 50% test and 50% validation
val_idx, test_idx = train_test_split(
    temp_idx, 
    test_size=0.5, 
    random_state=42  # Same random_state for consistency
)

# %%
print(train_idx)
print(val_idx)
print(test_idx)
# Out:
# [12829 12333  8225 ...  5390   860 15795]
# [13202 15153  3113 ...  1158  6603 15289]
# [17261  8344  1396 ...  7985   482 16493]

# %%
# Result: train_idx (80%), test_idx (10%), val_idx (10%)
print(f"Train indices: {len(train_idx)}")
print(f"Test indices: {len(test_idx)}")
print(f"Validation indices: {len(val_idx)}")
# Out:
# Train indices: 17723
# Test indices: 2216
# Validation indices: 2215

# %%
# Define the dataset
train_dataset = HG2D.HepG2DatasetTransformer(int(0.8 * NUM_ITEMS), af_transformed, train_idx)
val_dataset = HG2D.HepG2DatasetTransformer(int(0.1 * NUM_ITEMS), af_transformed, val_idx)
test_dataset = HG2D.HepG2DatasetTransformer(int(0.1 * NUM_ITEMS), af_transformed, test_idx)

# %%
print(len(train_dataset))
print(len(val_dataset))
print(len(test_dataset))
# Out:
# 800000
# 100000
# 100000

# %%
# Define the dataloader
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)

# %%
# Initialize the model
model = BC.BinaryClassifierDropOutL1L2(input_size=INPUT_SIZE, dropout_rate=DROPOUT_RATE, l1_lambda=L1_lambda, l2_lambda=L2_lambda).to(device)

# Define loss function for binary classification
criterion = nn.BCELoss()  # Binary Cross Entropy Loss

# Training loop example
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
optimizer = optim.SGD(model.parameters(), lr=0.0001, momentum=0.9)

# Define learning rate scheduler
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.1)

# %%
print(model)
# Out:
# BinaryClassifierDropOutL1L2(
#   (network): Sequential(
#     (0): Linear(in_features=40000, out_features=64, bias=True)
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=64, out_features=32, bias=True)
#     (4): LeakyReLU(negative_slope=0.1)
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=32, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )

# %%
# Arrays for saving the performance metric
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
train_aucs, val_aucs = [], []
val_precisions = []
val_recalls = []
val_f1_scores = []

# %%
# Check if the checkpoint exists
if os.path.exists(CHECKPOINT_NAME):
    checkpoint = torch.load(CHECKPOINT_NAME)
    
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler'])
    START_EPOCH = checkpoint['epoch'] + 1
    train_losses = checkpoint['train_losses']
    val_losses = checkpoint['val_losses']
    train_accuracies = checkpoint['train_accuracies']
    val_accuracies = checkpoint['val_accuracies']
    train_aucs = checkpoint['train_aucs']
    val_aucs = checkpoint['val_aucs']
    val_precisions = checkpoint['val_precisions']
    val_recalls = checkpoint['val_recalls']
    val_f1_scores = checkpoint['val_f1_scores']

    print(f"{CHECKPOINT_NAME} exists. Resuming training from epoch {START_EPOCH}.")
else:
    START_EPOCH = 0

# %%
# Training loop
for epoch in range(START_EPOCH, NUM_EPOCHS):
    model.train()

    train_loss = 0
    train_correct = 0
    train_total = 0
    train_true_labels = []
    train_predicted_labels = []

    # Training phase
    for X_batch, y_batch in train_loader:

        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Calculate accuracy
        predictions = (outputs.squeeze(1) >= 0.5).long()

        train_loss += loss.item()
        train_correct += (predictions == y_batch.to(device)).sum().item()
        train_total += y_batch.size(0)
        
        train_true_labels.extend(y_batch.cpu().numpy())
        train_predicted_labels.extend(predictions.cpu().numpy())
        
    # # Adjust learning rate
    # scheduler.step()
    
    avg_train_loss = train_loss / len(train_loader)
    train_accuracy = 100 * train_correct / train_total
    train_auc_score = roc_auc_score(train_true_labels, train_predicted_labels)

    train_losses.append(round(avg_train_loss, 4))
    train_accuracies.append(round(train_accuracy, 2))
    train_aucs.append(round(train_auc_score, 2))

    # Validation phase
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    val_metric = 0
    val_true_labels = []
    val_predicted_labels = []

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            
            if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
                outputs = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
            elif MODEL_MODE == "dol1l2":
                outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg
            
            predictions = (outputs.squeeze(1) >= 0.5).long()
            
            val_loss += loss.item()
            val_correct += (predictions == y_batch.to(dtype=torch.float32).to(device)).sum().item()
            val_total += y_batch.size(0)
            val_true_labels.extend(y_batch.cpu().numpy())
            val_predicted_labels.extend(predictions.cpu().numpy())
            
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_metric = val_correct / len(val_loader)

        # Calculate precision, recall, and F1-score
        precision, recall, f1_score, _ = precision_recall_fscore_support(
            val_true_labels, 
            val_predicted_labels, 
            average='binary'  # Use macro average for multi-class classification
        )

        val_true_labels = np.array(val_true_labels)
        val_predicted_labels = np.array(val_predicted_labels)
        val_auc_score = roc_auc_score(val_true_labels, val_predicted_labels)

        val_losses.append(round(avg_val_loss, 4))
        val_accuracies.append(round(val_accuracy, 2))
        val_aucs.append(round(val_auc_score, 2))
        val_precisions.append(round(precision, 2))
        val_recalls.append(round(recall, 2))
        val_f1_scores.append(round(f1_score, 2))

    # Adjust learning rate
    scheduler.step(val_loss)

    print(f'Epoch [{epoch+1}/{NUM_EPOCHS}] - '
          f'[TRAIN] Loss: {avg_train_loss:.4f}, Accuracy: {train_accuracy:.2f}%, AUC: {train_auc_score:.2f} '
          f'[VAL] Loss: {avg_val_loss:.4f}, Accuracy: {val_accuracy:.2f}%, '
          f'Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1_score:.2f}, '
          f'AUC: {val_auc_score:.2f}')
    
    # Save the model
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler': scheduler.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accuracies': train_accuracies,
        'val_accuracies': val_accuracies,
        'train_aucs': train_aucs,
        'val_aucs': val_aucs,
        'val_precisions': val_precisions,
        'val_recalls': val_recalls,
        'val_f1_scores': val_f1_scores,
    }, CHECKPOINT_NAME)
# Out:
# Epoch [1/100] - [TRAIN] Loss: 0.5978, Accuracy: 69.65%, AUC: 0.69 [VAL] Loss: 0.5884, Accuracy: 69.94%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [2/100] - [TRAIN] Loss: 0.5827, Accuracy: 70.48%, AUC: 0.70 [VAL] Loss: 0.5870, Accuracy: 69.99%, Precision: 0.70, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [3/100] - [TRAIN] Loss: 0.5792, Accuracy: 70.77%, AUC: 0.70 [VAL] Loss: 0.5849, Accuracy: 70.36%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [4/100] - [TRAIN] Loss: 0.5771, Accuracy: 70.84%, AUC: 0.71 [VAL] Loss: 0.5856, Accuracy: 70.07%, Precision: 0.69, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [5/100] - [TRAIN] Loss: 0.5753, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5818, Accuracy: 70.59%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [6/100] - [TRAIN] Loss: 0.5729, Accuracy: 71.07%, AUC: 0.71 [VAL] Loss: 0.5837, Accuracy: 70.25%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [7/100] - [TRAIN] Loss: 0.5724, Accuracy: 71.16%, AUC: 0.71 [VAL] Loss: 0.5833, Accuracy: 70.34%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [8/100] - [TRAIN] Loss: 0.5704, Accuracy: 71.32%, AUC: 0.71 [VAL] Loss: 0.5853, Accuracy: 70.14%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [9/100] - [TRAIN] Loss: 0.5684, Accuracy: 71.48%, AUC: 0.71 [VAL] Loss: 0.5811, Accuracy: 70.69%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [10/100] - [TRAIN] Loss: 0.5695, Accuracy: 71.44%, AUC: 0.71 [VAL] Loss: 0.5807, Accuracy: 70.61%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [11/100] - [TRAIN] Loss: 0.5688, Accuracy: 71.45%, AUC: 0.71 [VAL] Loss: 0.5802, Accuracy: 70.96%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [12/100] - [TRAIN] Loss: 0.5667, Accuracy: 71.73%, AUC: 0.71 [VAL] Loss: 0.5797, Accuracy: 70.65%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [13/100] - [TRAIN] Loss: 0.5657, Accuracy: 71.72%, AUC: 0.71 [VAL] Loss: 0.5791, Accuracy: 70.85%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [14/100] - [TRAIN] Loss: 0.5649, Accuracy: 71.80%, AUC: 0.72 [VAL] Loss: 0.5812, Accuracy: 70.52%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [15/100] - [TRAIN] Loss: 0.5643, Accuracy: 71.86%, AUC: 0.72 [VAL] Loss: 0.5792, Accuracy: 70.94%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.71
# Epoch [16/100] - [TRAIN] Loss: 0.5634, Accuracy: 71.90%, AUC: 0.72 [VAL] Loss: 0.5816, Accuracy: 70.55%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [17/100] - [TRAIN] Loss: 0.5625, Accuracy: 71.99%, AUC: 0.72 [VAL] Loss: 0.5790, Accuracy: 70.90%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [18/100] - [TRAIN] Loss: 0.5611, Accuracy: 72.16%, AUC: 0.72 [VAL] Loss: 0.5773, Accuracy: 70.94%, Precision: 0.72, Recall: 0.63, F1-Score: 0.68, AUC: 0.71
# Epoch [19/100] - [TRAIN] Loss: 0.5602, Accuracy: 72.18%, AUC: 0.72 [VAL] Loss: 0.5796, Accuracy: 70.90%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [20/100] - [TRAIN] Loss: 0.5593, Accuracy: 72.27%, AUC: 0.72 [VAL] Loss: 0.5801, Accuracy: 70.60%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [21/100] - [TRAIN] Loss: 0.5577, Accuracy: 72.35%, AUC: 0.72 [VAL] Loss: 0.5817, Accuracy: 70.46%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [22/100] - [TRAIN] Loss: 0.5576, Accuracy: 72.46%, AUC: 0.72 [VAL] Loss: 0.5794, Accuracy: 70.57%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [23/100] - [TRAIN] Loss: 0.5567, Accuracy: 72.57%, AUC: 0.72 [VAL] Loss: 0.5824, Accuracy: 70.47%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [24/100] - [TRAIN] Loss: 0.5559, Accuracy: 72.54%, AUC: 0.72 [VAL] Loss: 0.5802, Accuracy: 70.66%, Precision: 0.72, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [25/100] - [TRAIN] Loss: 0.5545, Accuracy: 72.63%, AUC: 0.72 [VAL] Loss: 0.5788, Accuracy: 70.77%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [26/100] - [TRAIN] Loss: 0.5556, Accuracy: 72.60%, AUC: 0.72 [VAL] Loss: 0.5793, Accuracy: 70.76%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [27/100] - [TRAIN] Loss: 0.5544, Accuracy: 72.67%, AUC: 0.72 [VAL] Loss: 0.5789, Accuracy: 70.66%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [28/100] - [TRAIN] Loss: 0.5536, Accuracy: 72.72%, AUC: 0.72 [VAL] Loss: 0.5794, Accuracy: 70.72%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [29/100] - [TRAIN] Loss: 0.5537, Accuracy: 72.76%, AUC: 0.72 [VAL] Loss: 0.5805, Accuracy: 70.69%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [30/100] - [TRAIN] Loss: 0.5536, Accuracy: 72.75%, AUC: 0.72 [VAL] Loss: 0.5773, Accuracy: 70.81%, Precision: 0.72, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [31/100] - [TRAIN] Loss: 0.5530, Accuracy: 72.83%, AUC: 0.73 [VAL] Loss: 0.5798, Accuracy: 70.65%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [32/100] - [TRAIN] Loss: 0.5535, Accuracy: 72.68%, AUC: 0.72 [VAL] Loss: 0.5808, Accuracy: 70.57%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [33/100] - [TRAIN] Loss: 0.5540, Accuracy: 72.75%, AUC: 0.72 [VAL] Loss: 0.5801, Accuracy: 70.63%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [34/100] - [TRAIN] Loss: 0.5541, Accuracy: 72.76%, AUC: 0.72 [VAL] Loss: 0.5792, Accuracy: 70.70%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [35/100] - [TRAIN] Loss: 0.5532, Accuracy: 72.82%, AUC: 0.73 [VAL] Loss: 0.5769, Accuracy: 70.77%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.70
# Epoch [36/100] - [TRAIN] Loss: 0.5543, Accuracy: 72.70%, AUC: 0.72 [VAL] Loss: 0.5801, Accuracy: 70.71%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [37/100] - [TRAIN] Loss: 0.5539, Accuracy: 72.72%, AUC: 0.72 [VAL] Loss: 0.5785, Accuracy: 70.83%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [38/100] - [TRAIN] Loss: 0.5522, Accuracy: 72.88%, AUC: 0.73 [VAL] Loss: 0.5769, Accuracy: 71.00%, Precision: 0.72, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [39/100] - [TRAIN] Loss: 0.5540, Accuracy: 72.81%, AUC: 0.73 [VAL] Loss: 0.5790, Accuracy: 70.65%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [40/100] - [TRAIN] Loss: 0.5532, Accuracy: 72.79%, AUC: 0.72 [VAL] Loss: 0.5824, Accuracy: 70.36%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [41/100] - [TRAIN] Loss: 0.5535, Accuracy: 72.76%, AUC: 0.72 [VAL] Loss: 0.5779, Accuracy: 70.67%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [42/100] - [TRAIN] Loss: 0.5541, Accuracy: 72.75%, AUC: 0.72 [VAL] Loss: 0.5795, Accuracy: 70.59%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [43/100] - [TRAIN] Loss: 0.5532, Accuracy: 72.73%, AUC: 0.72 [VAL] Loss: 0.5802, Accuracy: 70.62%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [44/100] - [TRAIN] Loss: 0.5531, Accuracy: 72.72%, AUC: 0.72 [VAL] Loss: 0.5788, Accuracy: 70.72%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [45/100] - [TRAIN] Loss: 0.5533, Accuracy: 72.79%, AUC: 0.72 [VAL] Loss: 0.5797, Accuracy: 70.74%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [46/100] - [TRAIN] Loss: 0.5531, Accuracy: 72.82%, AUC: 0.73 [VAL] Loss: 0.5808, Accuracy: 70.74%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.70
# Epoch [47/100] - [TRAIN] Loss: 0.5533, Accuracy: 72.78%, AUC: 0.72 [VAL] Loss: 0.5803, Accuracy: 70.64%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.70
# Epoch [48/100] - [TRAIN] Loss: 0.5537, Accuracy: 72.76%, AUC: 0.72 [VAL] Loss: 0.5810, Accuracy: 70.61%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [49/100] - [TRAIN] Loss: 0.5535, Accuracy: 72.79%, AUC: 0.72 [VAL] Loss: 0.5797, Accuracy: 70.70%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [50/100] - [TRAIN] Loss: 0.5530, Accuracy: 72.81%, AUC: 0.73 [VAL] Loss: 0.5791, Accuracy: 70.66%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [51/100] - [TRAIN] Loss: 0.5540, Accuracy: 72.72%, AUC: 0.72 [VAL] Loss: 0.5794, Accuracy: 70.65%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [52/100] - [TRAIN] Loss: 0.5535, Accuracy: 72.79%, AUC: 0.72 [VAL] Loss: 0.5807, Accuracy: 70.56%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [53/100] - [TRAIN] Loss: 0.5539, Accuracy: 72.75%, AUC: 0.72 [VAL] Loss: 0.5792, Accuracy: 70.71%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [54/100] - [TRAIN] Loss: 0.5534, Accuracy: 72.80%, AUC: 0.73 [VAL] Loss: 0.5767, Accuracy: 70.86%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [55/100] - [TRAIN] Loss: 0.5527, Accuracy: 72.80%, AUC: 0.72 [VAL] Loss: 0.5807, Accuracy: 70.75%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [56/100] - [TRAIN] Loss: 0.5524, Accuracy: 72.83%, AUC: 0.73 [VAL] Loss: 0.5804, Accuracy: 70.77%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [57/100] - [TRAIN] Loss: 0.5531, Accuracy: 72.80%, AUC: 0.73 [VAL] Loss: 0.5795, Accuracy: 70.68%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [58/100] - [TRAIN] Loss: 0.5526, Accuracy: 72.85%, AUC: 0.73 [VAL] Loss: 0.5784, Accuracy: 70.69%, Precision: 0.72, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [59/100] - [TRAIN] Loss: 0.5537, Accuracy: 72.73%, AUC: 0.72 [VAL] Loss: 0.5808, Accuracy: 70.78%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.70
# Epoch [60/100] - [TRAIN] Loss: 0.5532, Accuracy: 72.82%, AUC: 0.73 [VAL] Loss: 0.5815, Accuracy: 70.54%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [61/100] - [TRAIN] Loss: 0.5538, Accuracy: 72.71%, AUC: 0.72 [VAL] Loss: 0.5781, Accuracy: 70.73%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [62/100] - [TRAIN] Loss: 0.5539, Accuracy: 72.76%, AUC: 0.72 [VAL] Loss: 0.5786, Accuracy: 70.85%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [63/100] - [TRAIN] Loss: 0.5542, Accuracy: 72.71%, AUC: 0.72 [VAL] Loss: 0.5773, Accuracy: 70.73%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [64/100] - [TRAIN] Loss: 0.5533, Accuracy: 72.83%, AUC: 0.73 [VAL] Loss: 0.5808, Accuracy: 70.58%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [65/100] - [TRAIN] Loss: 0.5522, Accuracy: 72.88%, AUC: 0.73 [VAL] Loss: 0.5797, Accuracy: 70.74%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.70
# Epoch [66/100] - [TRAIN] Loss: 0.5537, Accuracy: 72.79%, AUC: 0.72 [VAL] Loss: 0.5799, Accuracy: 70.70%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [67/100] - [TRAIN] Loss: 0.5540, Accuracy: 72.73%, AUC: 0.72 [VAL] Loss: 0.5762, Accuracy: 70.73%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [68/100] - [TRAIN] Loss: 0.5532, Accuracy: 72.72%, AUC: 0.72 [VAL] Loss: 0.5793, Accuracy: 70.59%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [69/100] - [TRAIN] Loss: 0.5531, Accuracy: 72.79%, AUC: 0.72 [VAL] Loss: 0.5787, Accuracy: 70.79%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [70/100] - [TRAIN] Loss: 0.5531, Accuracy: 72.82%, AUC: 0.73 [VAL] Loss: 0.5786, Accuracy: 70.75%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [71/100] - [TRAIN] Loss: 0.5535, Accuracy: 72.74%, AUC: 0.72 [VAL] Loss: 0.5769, Accuracy: 70.98%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [72/100] - [TRAIN] Loss: 0.5528, Accuracy: 72.82%, AUC: 0.73 [VAL] Loss: 0.5797, Accuracy: 70.65%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [73/100] - [TRAIN] Loss: 0.5525, Accuracy: 72.83%, AUC: 0.73 [VAL] Loss: 0.5747, Accuracy: 71.12%, Precision: 0.72, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [74/100] - [TRAIN] Loss: 0.5528, Accuracy: 72.82%, AUC: 0.73 [VAL] Loss: 0.5781, Accuracy: 70.69%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [75/100] - [TRAIN] Loss: 0.5538, Accuracy: 72.73%, AUC: 0.72 [VAL] Loss: 0.5792, Accuracy: 70.67%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [76/100] - [TRAIN] Loss: 0.5531, Accuracy: 72.76%, AUC: 0.72 [VAL] Loss: 0.5804, Accuracy: 70.55%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [77/100] - [TRAIN] Loss: 0.5524, Accuracy: 72.86%, AUC: 0.73 [VAL] Loss: 0.5767, Accuracy: 70.96%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [78/100] - [TRAIN] Loss: 0.5541, Accuracy: 72.77%, AUC: 0.72 [VAL] Loss: 0.5789, Accuracy: 70.69%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [79/100] - [TRAIN] Loss: 0.5532, Accuracy: 72.85%, AUC: 0.73 [VAL] Loss: 0.5807, Accuracy: 70.55%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [80/100] - [TRAIN] Loss: 0.5527, Accuracy: 72.78%, AUC: 0.73 [VAL] Loss: 0.5801, Accuracy: 70.68%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [81/100] - [TRAIN] Loss: 0.5532, Accuracy: 72.81%, AUC: 0.73 [VAL] Loss: 0.5774, Accuracy: 70.62%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [82/100] - [TRAIN] Loss: 0.5533, Accuracy: 72.78%, AUC: 0.72 [VAL] Loss: 0.5798, Accuracy: 70.60%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [83/100] - [TRAIN] Loss: 0.5536, Accuracy: 72.75%, AUC: 0.72 [VAL] Loss: 0.5790, Accuracy: 70.76%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.70
# Epoch [84/100] - [TRAIN] Loss: 0.5531, Accuracy: 72.78%, AUC: 0.72 [VAL] Loss: 0.5800, Accuracy: 70.49%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [85/100] - [TRAIN] Loss: 0.5529, Accuracy: 72.81%, AUC: 0.73 [VAL] Loss: 0.5781, Accuracy: 70.55%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [86/100] - [TRAIN] Loss: 0.5532, Accuracy: 72.76%, AUC: 0.72 [VAL] Loss: 0.5741, Accuracy: 71.09%, Precision: 0.72, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [87/100] - [TRAIN] Loss: 0.5544, Accuracy: 72.71%, AUC: 0.72 [VAL] Loss: 0.5780, Accuracy: 70.60%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [88/100] - [TRAIN] Loss: 0.5528, Accuracy: 72.83%, AUC: 0.73 [VAL] Loss: 0.5808, Accuracy: 70.58%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [89/100] - [TRAIN] Loss: 0.5529, Accuracy: 72.83%, AUC: 0.73 [VAL] Loss: 0.5766, Accuracy: 70.87%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [90/100] - [TRAIN] Loss: 0.5542, Accuracy: 72.70%, AUC: 0.72 [VAL] Loss: 0.5790, Accuracy: 70.68%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.70
# Epoch [91/100] - [TRAIN] Loss: 0.5523, Accuracy: 72.95%, AUC: 0.73 [VAL] Loss: 0.5806, Accuracy: 70.81%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [92/100] - [TRAIN] Loss: 0.5533, Accuracy: 72.81%, AUC: 0.73 [VAL] Loss: 0.5780, Accuracy: 70.82%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [93/100] - [TRAIN] Loss: 0.5543, Accuracy: 72.68%, AUC: 0.72 [VAL] Loss: 0.5794, Accuracy: 70.69%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [94/100] - [TRAIN] Loss: 0.5542, Accuracy: 72.72%, AUC: 0.72 [VAL] Loss: 0.5818, Accuracy: 70.60%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [95/100] - [TRAIN] Loss: 0.5532, Accuracy: 72.83%, AUC: 0.73 [VAL] Loss: 0.5793, Accuracy: 70.81%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [96/100] - [TRAIN] Loss: 0.5530, Accuracy: 72.80%, AUC: 0.73 [VAL] Loss: 0.5767, Accuracy: 71.03%, Precision: 0.72, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [97/100] - [TRAIN] Loss: 0.5530, Accuracy: 72.80%, AUC: 0.73 [VAL] Loss: 0.5788, Accuracy: 70.71%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [98/100] - [TRAIN] Loss: 0.5534, Accuracy: 72.83%, AUC: 0.73 [VAL] Loss: 0.5799, Accuracy: 70.74%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [99/100] - [TRAIN] Loss: 0.5533, Accuracy: 72.76%, AUC: 0.72 [VAL] Loss: 0.5748, Accuracy: 71.05%, Precision: 0.72, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [100/100] - [TRAIN] Loss: 0.5525, Accuracy: 72.84%, AUC: 0.73 [VAL] Loss: 0.5807, Accuracy: 70.49%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70

# %%
# Plot metrics
my_util.plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies, NUM_ITEMS, IMAGE_FILE)

# %%
# Predict on test set
test_predictions = []
test_true_labels = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, _, _ = model(X_batch.to(dtype=torch.float32).to(device))
        
        predictions = (outputs.squeeze(1) >= 0.5).long()
        test_true_labels.extend(y_batch.cpu().numpy())
        test_predictions.extend(predictions.cpu().numpy())

# %%
# Evaluation metrics
# Precision, Recall, F1-Score
precision, recall, f1_score, _ = precision_recall_fscore_support(
    test_true_labels, 
    test_predictions, 
    average='binary'  # Use 'macro' for multi-class
)

test_acc_score = accuracy_score(test_true_labels, test_predictions) * 100
test_auc_score = roc_auc_score(test_true_labels, test_predictions)
cr = classification_report(test_true_labels, test_predictions)
cm = confusion_matrix(test_true_labels, test_predictions)

# %%
test_output = f"""Accuracy Score on test set: {test_acc_score:.2f} %
AUC Score on test set: {test_auc_score:.2f}
Precision: {precision:.4f}
Recall: {recall:.4f}
F1-Score: {f1_score:.4f}

Detailed Classification Report:
{cr}

Confusion Matrix:
{cm}
"""

print(test_output)
# Out:
# Accuracy Score on test set: 71.05 %
# AUC Score on test set: 0.71
# Precision: 0.7189
# Recall: 0.6455
# F1-Score: 0.6802
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.77      0.74     52302
#            1       0.72      0.65      0.68     47698
#
#     accuracy                           0.71    100000
#    macro avg       0.71      0.71      0.71    100000
# weighted avg       0.71      0.71      0.71    100000
#
#
# Confusion Matrix:
# [[40261 12041]
#  [16911 30787]]

# %%
# Save the test output to text file
with open(TEST_FILE, 'w', newline = '') as text_file:
    text_file.write(test_output)

# %%
# Training metrics
experiment_results = {
    'train_loss'    : train_losses,
    'train_accuracy': train_accuracies,
    'train_auc'     : train_aucs,
    'val_loss'      : val_losses,
    'val_accuracy'  : val_accuracies,
    'val_auc'       : val_aucs
}

experiment_pl = pl.DataFrame(experiment_results)
experiment_pl.write_csv(TRAINING_FILE)

# %%
# Test output
test_results = {
    'test_acc'    : round(test_acc_score, 4),
    'test_auc'    : round(test_auc_score, 4)
}

test_pl = pl.DataFrame(test_results)
test_pl.write_csv(TEST_RESULT_FILE)

# %%
# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(test_true_labels, test_predictions) 
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC for HepG2 Ranking')
plt.legend()

plt.savefig(ROC_FILE)

plt.show()

# %%
# Plot the confusion matrix
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm)
fig, ax = plt.subplots(figsize=(10, 8))
cm_display.plot(ax=ax)
plt.savefig(CM_FILE)
