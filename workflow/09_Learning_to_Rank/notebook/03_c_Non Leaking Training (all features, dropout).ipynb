# %%
import os
import random

import pandas as pd
import polars as pl
import numpy as np

import pyarrow as pa
import pyarrow.parquet as pq

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Declare  variables, working directory and dataset directory
MODE = 'all_features'
NUM_EPOCHS = 100
START_EPOCH = 0
NUM_ITEMS = 100_000
BATCH_SIZE = 512

WORKING_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank'
DATASET_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/dataset'

MODEL_MODE = "dol1l2" # regular (reg), dropout (do), dropout + l1l2 (dol1l2)
CHECKPOINT_NAME = os.path.join(WORKING_DIR, 'output', 'model', MODE, f'{MODEL_MODE}-checkpoint-{NUM_ITEMS}-{NUM_EPOCHS}.pt')

INPUT_SIZE = 40000

# %%
def get_device():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    if device.type == "cuda":
        print(f"Current CUDA device: {torch.cuda.current_device()}")
        print(f"CUDA device name: {torch.cuda.get_device_name(0)}")

    return device

# %%
device = get_device()
# Out:
# Using device: cuda
# Current CUDA device: 0
# CUDA device name: Tesla P100-SXM2-16GB

# %%
class HepG2Dataset(Dataset):
    def __init__(self, total_samples, features, indexes):
        self.total_samples = total_samples
        self.features = features
        self.indexes = indexes

    def __len__(self):
        return self.total_samples

    def __getitem__(self, idx):
        r1 = random.choice(self.indexes)
        r2 = random.choice(self.indexes)
        
        feature_1 = self.features[r1, 2]
        feature_2 = self.features[r2, 2]
        feature = np.concatenate((feature_1, feature_2), axis=0)
        
        val_1 = self.features[r1, 3]
        val_2 = self.features[r2, 3]
        
        y = 1 if val_1 > val_2 else 0
        
        return feature, y

# %%
class BinaryClassifier(nn.Module):
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1):
        super(BinaryClassifier, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(input_size, hidden1_size),
            nn.ReLU(),
            nn.Linear(hidden1_size, hidden2_size),
            nn.ReLU(),
            nn.Linear(hidden2_size, output_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        # x = x.squeeze(1)
        return self.network(x)

    def predict(self, x):
        with torch.no_grad():
            outputs = self.forward(x)
            return (outputs >= 0.5).long()

# %%
class BinaryClassifierDropOut(nn.Module):
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1, dropout_rate=0.2):
        super(BinaryClassifierDropOut, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(input_size, hidden1_size),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(hidden1_size, hidden2_size),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(hidden2_size, output_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        # x = x.squeeze(1)
        return self.network(x)

    def predict(self, x):
        with torch.no_grad():
            outputs = self.forward(x)
            return (outputs >= 0.5).long()

# %%
class BinaryClassifierDropOutL1L2(nn.Module):
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1, dropout_rate=0.2, l1_lambda=0.001, l2_lambda=0.001):
        super(BinaryClassifierDropOutL1L2, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(input_size, hidden1_size),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(hidden1_size, hidden2_size),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(hidden2_size, output_size),
            nn.Sigmoid()
        )

        self.l1_lambda = l1_lambda
        self.l2_lambda = l2_lambda

    def forward(self, x):
        # x = x.squeeze(1)
        outputs = self.network(x)
        l1_reg = torch.tensor(0., requires_grad=True)
        l2_reg = torch.tensor(0., requires_grad=True)

        for name, param in self.named_parameters():
            if 'weight' in name:
                l1_reg = l1_reg + torch.linalg.norm(param, 1)
                l2_reg = l2_reg + torch.linalg.norm(param, 2)

        return outputs, self.l1_lambda * l1_reg, self.l2_lambda * l2_reg

    def predict(self, x):
        with torch.no_grad():
            outputs, _, _ = self.forward(x)
            return (outputs >= 0.5).long()

# %%
def plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies, num_items):
    epochs = range(1, len(train_losses) + 1)
    
    plt.figure(figsize=(14, 6))
    
    # Plot for training and validation Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, 'blue', label='Training Loss')
    plt.plot(epochs, val_losses, 'orange', label='Validation Loss')
    plt.title(f'Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim(0.4, 0.8)
    plt.legend()
    plt.grid(True)
    
    # Plot for training and validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, 'blue', label='Training Accuracy')
    plt.plot(epochs, val_accuracies, 'orange', label='Validation Accuracy')
    plt.title(f'Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.ylim(50, 90)
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()

    img_name = f"{MODEL_MODE}-ranking-{NUM_ITEMS}-{NUM_EPOCHS}.png"
    plt.savefig(os.path.join(WORKING_DIR, 'output', 'img', 'train', MODE, img_name))
    
    plt.show()

# %%
# Load dataset
all_features = pl.read_parquet(os.path.join(DATASET_DIR, 'features', f'{MODE}.parquet'))
all_features
# Out:
# shape: (22_154, 4)
# ┌───────┬─────────────┬───────────────────┬───────────┐
# │ index ┆ gene_id     ┆ all_features      ┆ value_1   │
# │ ---   ┆ ---         ┆ ---               ┆ ---       │
# │ u32   ┆ str         ┆ list[f64]         ┆ f64       │
# ╞═══════╪═════════════╪═══════════════════╪═══════════╡
# │ 0     ┆ XLOC_000001 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 1     ┆ XLOC_000003 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 2     ┆ XLOC_000006 ┆ [0.0, 0.0, … 0.0] ┆ 0.0888452 │
# │ 3     ┆ XLOC_000007 ┆ [0.0, 0.0, … 0.0] ┆ 4.04743   │
# │ 4     ┆ XLOC_000008 ┆ [0.0, 0.0, … 0.0] ┆ 26.7934   │
# │ …     ┆ …           ┆ …                 ┆ …         │
# │ 22149 ┆ XLOC_030009 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22150 ┆ XLOC_030012 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22151 ┆ XLOC_030014 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22152 ┆ XLOC_030017 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22153 ┆ XLOC_030018 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# └───────┴─────────────┴───────────────────┴───────────┘

# %%
# Convert to numpy array
all_features_np = all_features.to_numpy()

# %%
# Split train, test, validation by index
data_indices = np.arange(len(all_features_np))
print(data_indices)
# Out:
# [    0     1     2 ... 22151 22152 22153]

# %%
# First split: 80% train, 20% temporary (for test + validation)
train_idx, temp_idx = train_test_split(
    data_indices, 
    test_size=0.2, 
    random_state=42  # For reproducibility
)

# %%
# Second split: Split temp_idx into 50% test and 50% validation
val_idx, test_idx = train_test_split(
    temp_idx, 
    test_size=0.5, 
    random_state=42  # Same random_state for consistency
)

# %%
# Result: train_idx (80%), test_idx (10%), val_idx (10%)
print(f"Train indices: {len(train_idx)}")
print(f"Test indices: {len(test_idx)}")
print(f"Validation indices: {len(val_idx)}")
# Out:
# Train indices: 17723
# Test indices: 2216
# Validation indices: 2215

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Training

# %%
# Define the dataset
train_dataset = HepG2Dataset(int(0.8 * NUM_ITEMS), all_features_np, train_idx)
val_dataset = HepG2Dataset(int(0.1 * NUM_ITEMS), all_features_np, val_idx)
test_dataset = HepG2Dataset(int(0.1 * NUM_ITEMS), all_features_np, test_idx)

# %%
print(len(train_dataset))
print(len(val_dataset))
print(len(test_dataset))
# Out:
# 80000
# 10000
# 10000

# %%
# Define the dataloader
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)

# %%
# Initialize model
if MODEL_MODE == "reg":
    model = BinaryClassifier(input_size=INPUT_SIZE).to(device)
elif MODEL_MODE == "do":
    model = BinaryClassifierDropOut(input_size=INPUT_SIZE).to(device)
elif MODEL_MODE == "dol1l2":
    model = BinaryClassifierDropOutL1L2(input_size=INPUT_SIZE).to(device)

# Define loss function for binary classification
criterion = nn.BCELoss()  # Binary Cross Entropy Loss

# Training loop example
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Arrays for saving the performance metric
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
train_aucs, val_aucs = [], []
val_precisions = []
val_recalls = []
val_f1_scores = []

# %%
# Check if the checkpoint exists
if os.path.exists(CHECKPOINT_NAME):
    checkpoint = torch.load(CHECKPOINT_NAME)
    
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    START_EPOCH = checkpoint['epoch'] + 1
    train_losses = checkpoint['train_losses']
    val_losses = checkpoint['val_losses']
    train_accuracies = checkpoint['train_accuracies']
    val_accuracies = checkpoint['val_accuracies']
    train_aucs = checkpoint['train_aucs']
    val_aucs = checkpoint['val_aucs']
    val_precisions = checkpoint['val_precisions']
    val_recalls = checkpoint['val_recalls']
    val_f1_scores = checkpoint['val_f1_scores']

    print(f"{CHECKPOINT_NAME} exists. Resuming training from epoch {START_EPOCH}.")
else:
    START_EPOCH = 0

# %%
# Training loop
for epoch in range(START_EPOCH, NUM_EPOCHS):
    model.train()

    train_loss = 0
    train_correct = 0
    train_total = 0
    train_true_labels = []
    train_predicted_labels = []

    # Training phase
    for X_batch, y_batch in train_loader:

        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Calculate accuracy
        predictions = (outputs.squeeze(1) >= 0.5).long()

        train_loss += loss.item()
        train_correct += (predictions == y_batch.to(device)).sum().item()
        train_total += y_batch.size(0)
        
        train_true_labels.extend(y_batch.cpu().numpy())
        train_predicted_labels.extend(predictions.cpu().numpy())
        
    avg_train_loss = train_loss / len(train_loader)
    train_accuracy = 100 * train_correct / train_total
    train_auc_score = roc_auc_score(train_true_labels, train_predicted_labels)

    train_losses.append(round(avg_train_loss, 4))
    train_accuracies.append(round(train_accuracy, 2))
    train_aucs.append(round(train_auc_score, 2))

    # Validation phase
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    val_metric = 0
    val_true_labels = []
    val_predicted_labels = []

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            
            if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
                outputs = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
            elif MODEL_MODE == "dol1l2":
                outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg
            
            predictions = (outputs.squeeze(1) >= 0.5).long()
            
            val_loss += loss.item()
            val_correct += (predictions == y_batch.to(dtype=torch.float32).to(device)).sum().item()
            val_total += y_batch.size(0)
            val_true_labels.extend(y_batch.cpu().numpy())
            val_predicted_labels.extend(predictions.cpu().numpy())
            
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_metric = val_correct / len(val_loader)

        # Calculate precision, recall, and F1-score
        precision, recall, f1_score, _ = precision_recall_fscore_support(
            val_true_labels, 
            val_predicted_labels, 
            average='binary'  # Use macro average for multi-class classification
        )

        val_true_labels = np.array(val_true_labels)
        val_predicted_labels = np.array(val_predicted_labels)
        val_auc_score = roc_auc_score(val_true_labels, val_predicted_labels)

        val_losses.append(round(avg_val_loss, 4))
        val_accuracies.append(round(val_accuracy, 2))
        val_aucs.append(round(val_auc_score, 2))
        val_precisions.append(round(precision, 2))
        val_recalls.append(round(recall, 2))
        val_f1_scores.append(round(f1_score, 2))
    

    print(f'Epoch [{epoch+1}/{NUM_EPOCHS}] - '
          f'[TRAIN] Loss: {avg_train_loss:.4f}, Accuracy: {train_accuracy:.2f}%, AUC: {train_auc_score:.2f} '
          f'[VAL] Loss: {avg_val_loss:.4f}, Accuracy: {val_accuracy:.2f}%, '
          f'Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1_score:.2f}, '
          f'AUC: {val_auc_score:.2f}')
    
    # Save the model
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accuracies': train_accuracies,
        'val_accuracies': val_accuracies,
        'train_aucs': train_aucs,
        'val_aucs': val_aucs,
        'val_precisions': val_precisions,
        'val_recalls': val_recalls,
        'val_f1_scores': val_f1_scores,
    }, CHECKPOINT_NAME)
# Out:
# Epoch [1/100] - [TRAIN] Loss: 0.5851, Accuracy: 69.93%, AUC: 0.70 [VAL] Loss: 0.5850, Accuracy: 70.27%, Precision: 0.74, Recall: 0.58, F1-Score: 0.65, AUC: 0.70
# Epoch [2/100] - [TRAIN] Loss: 0.5778, Accuracy: 70.89%, AUC: 0.71 [VAL] Loss: 0.5843, Accuracy: 69.75%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.69
# Epoch [3/100] - [TRAIN] Loss: 0.5717, Accuracy: 71.23%, AUC: 0.71 [VAL] Loss: 0.5830, Accuracy: 70.60%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [4/100] - [TRAIN] Loss: 0.5653, Accuracy: 71.78%, AUC: 0.71 [VAL] Loss: 0.5791, Accuracy: 70.60%, Precision: 0.72, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [5/100] - [TRAIN] Loss: 0.5649, Accuracy: 71.79%, AUC: 0.71 [VAL] Loss: 0.5802, Accuracy: 70.66%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [6/100] - [TRAIN] Loss: 0.5672, Accuracy: 71.30%, AUC: 0.71 [VAL] Loss: 0.5789, Accuracy: 70.57%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [7/100] - [TRAIN] Loss: 0.5648, Accuracy: 71.79%, AUC: 0.71 [VAL] Loss: 0.5867, Accuracy: 69.81%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [8/100] - [TRAIN] Loss: 0.5630, Accuracy: 71.97%, AUC: 0.72 [VAL] Loss: 0.5760, Accuracy: 71.38%, Precision: 0.71, Recall: 0.68, F1-Score: 0.69, AUC: 0.71
# Epoch [9/100] - [TRAIN] Loss: 0.5628, Accuracy: 71.81%, AUC: 0.71 [VAL] Loss: 0.5823, Accuracy: 70.50%, Precision: 0.69, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [10/100] - [TRAIN] Loss: 0.5590, Accuracy: 72.33%, AUC: 0.72 [VAL] Loss: 0.5877, Accuracy: 70.58%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [11/100] - [TRAIN] Loss: 0.5606, Accuracy: 72.11%, AUC: 0.72 [VAL] Loss: 0.5800, Accuracy: 71.46%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [12/100] - [TRAIN] Loss: 0.5571, Accuracy: 72.53%, AUC: 0.72 [VAL] Loss: 0.5848, Accuracy: 70.87%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [13/100] - [TRAIN] Loss: 0.5582, Accuracy: 72.72%, AUC: 0.72 [VAL] Loss: 0.5745, Accuracy: 71.18%, Precision: 0.71, Recall: 0.67, F1-Score: 0.69, AUC: 0.71
# Epoch [14/100] - [TRAIN] Loss: 0.5550, Accuracy: 72.66%, AUC: 0.72 [VAL] Loss: 0.5877, Accuracy: 70.72%, Precision: 0.73, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [15/100] - [TRAIN] Loss: 0.5548, Accuracy: 72.65%, AUC: 0.72 [VAL] Loss: 0.5924, Accuracy: 70.48%, Precision: 0.73, Recall: 0.61, F1-Score: 0.67, AUC: 0.70
# Epoch [16/100] - [TRAIN] Loss: 0.5573, Accuracy: 72.55%, AUC: 0.72 [VAL] Loss: 0.5885, Accuracy: 71.01%, Precision: 0.71, Recall: 0.67, F1-Score: 0.68, AUC: 0.71
# Epoch [17/100] - [TRAIN] Loss: 0.5548, Accuracy: 72.81%, AUC: 0.72 [VAL] Loss: 0.5843, Accuracy: 70.42%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [18/100] - [TRAIN] Loss: 0.5487, Accuracy: 73.15%, AUC: 0.73 [VAL] Loss: 0.5951, Accuracy: 69.57%, Precision: 0.70, Recall: 0.62, F1-Score: 0.66, AUC: 0.69
# Epoch [19/100] - [TRAIN] Loss: 0.5511, Accuracy: 73.12%, AUC: 0.73 [VAL] Loss: 0.5790, Accuracy: 71.55%, Precision: 0.72, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [20/100] - [TRAIN] Loss: 0.5525, Accuracy: 73.19%, AUC: 0.73 [VAL] Loss: 0.5908, Accuracy: 70.15%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [21/100] - [TRAIN] Loss: 0.5504, Accuracy: 73.17%, AUC: 0.73 [VAL] Loss: 0.5831, Accuracy: 70.89%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [22/100] - [TRAIN] Loss: 0.5507, Accuracy: 72.96%, AUC: 0.73 [VAL] Loss: 0.5950, Accuracy: 70.36%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [23/100] - [TRAIN] Loss: 0.5513, Accuracy: 73.11%, AUC: 0.73 [VAL] Loss: 0.5980, Accuracy: 70.16%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [24/100] - [TRAIN] Loss: 0.5471, Accuracy: 73.56%, AUC: 0.73 [VAL] Loss: 0.6002, Accuracy: 69.74%, Precision: 0.70, Recall: 0.63, F1-Score: 0.66, AUC: 0.69
# Epoch [25/100] - [TRAIN] Loss: 0.5505, Accuracy: 73.34%, AUC: 0.73 [VAL] Loss: 0.5845, Accuracy: 71.31%, Precision: 0.72, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [26/100] - [TRAIN] Loss: 0.5483, Accuracy: 73.33%, AUC: 0.73 [VAL] Loss: 0.5908, Accuracy: 70.09%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [27/100] - [TRAIN] Loss: 0.5464, Accuracy: 73.54%, AUC: 0.73 [VAL] Loss: 0.5963, Accuracy: 70.32%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [28/100] - [TRAIN] Loss: 0.5444, Accuracy: 73.64%, AUC: 0.73 [VAL] Loss: 0.6005, Accuracy: 70.35%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [29/100] - [TRAIN] Loss: 0.5439, Accuracy: 73.81%, AUC: 0.73 [VAL] Loss: 0.5940, Accuracy: 70.25%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [30/100] - [TRAIN] Loss: 0.5439, Accuracy: 73.69%, AUC: 0.73 [VAL] Loss: 0.6012, Accuracy: 70.17%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [31/100] - [TRAIN] Loss: 0.5423, Accuracy: 73.85%, AUC: 0.74 [VAL] Loss: 0.5897, Accuracy: 70.63%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.70
# Epoch [32/100] - [TRAIN] Loss: 0.5427, Accuracy: 73.86%, AUC: 0.74 [VAL] Loss: 0.6002, Accuracy: 70.53%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [33/100] - [TRAIN] Loss: 0.5425, Accuracy: 73.75%, AUC: 0.73 [VAL] Loss: 0.5990, Accuracy: 70.23%, Precision: 0.72, Recall: 0.59, F1-Score: 0.65, AUC: 0.70
# Epoch [34/100] - [TRAIN] Loss: 0.5440, Accuracy: 73.72%, AUC: 0.73 [VAL] Loss: 0.5985, Accuracy: 70.54%, Precision: 0.71, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [35/100] - [TRAIN] Loss: 0.5419, Accuracy: 73.82%, AUC: 0.73 [VAL] Loss: 0.5894, Accuracy: 71.10%, Precision: 0.72, Recall: 0.64, F1-Score: 0.68, AUC: 0.71
# Epoch [36/100] - [TRAIN] Loss: 0.5424, Accuracy: 73.93%, AUC: 0.74 [VAL] Loss: 0.5902, Accuracy: 70.55%, Precision: 0.72, Recall: 0.62, F1-Score: 0.67, AUC: 0.70
# Epoch [37/100] - [TRAIN] Loss: 0.5431, Accuracy: 73.84%, AUC: 0.73 [VAL] Loss: 0.5966, Accuracy: 70.74%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [38/100] - [TRAIN] Loss: 0.5389, Accuracy: 74.28%, AUC: 0.74 [VAL] Loss: 0.5970, Accuracy: 70.45%, Precision: 0.69, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [39/100] - [TRAIN] Loss: 0.5396, Accuracy: 74.22%, AUC: 0.74 [VAL] Loss: 0.5997, Accuracy: 70.22%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [40/100] - [TRAIN] Loss: 0.5434, Accuracy: 74.23%, AUC: 0.74 [VAL] Loss: 0.6058, Accuracy: 69.94%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [41/100] - [TRAIN] Loss: 0.5375, Accuracy: 74.45%, AUC: 0.74 [VAL] Loss: 0.5915, Accuracy: 70.70%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [42/100] - [TRAIN] Loss: 0.5360, Accuracy: 74.50%, AUC: 0.74 [VAL] Loss: 0.6127, Accuracy: 69.31%, Precision: 0.70, Recall: 0.62, F1-Score: 0.65, AUC: 0.69
# Epoch [43/100] - [TRAIN] Loss: 0.5371, Accuracy: 74.44%, AUC: 0.74 [VAL] Loss: 0.6027, Accuracy: 69.67%, Precision: 0.70, Recall: 0.62, F1-Score: 0.66, AUC: 0.69
# Epoch [44/100] - [TRAIN] Loss: 0.5385, Accuracy: 74.20%, AUC: 0.74 [VAL] Loss: 0.5893, Accuracy: 71.46%, Precision: 0.72, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [45/100] - [TRAIN] Loss: 0.5375, Accuracy: 74.41%, AUC: 0.74 [VAL] Loss: 0.6052, Accuracy: 70.19%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [46/100] - [TRAIN] Loss: 0.5404, Accuracy: 74.25%, AUC: 0.74 [VAL] Loss: 0.6011, Accuracy: 70.39%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [47/100] - [TRAIN] Loss: 0.5364, Accuracy: 74.59%, AUC: 0.74 [VAL] Loss: 0.6002, Accuracy: 70.55%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [48/100] - [TRAIN] Loss: 0.5339, Accuracy: 74.59%, AUC: 0.74 [VAL] Loss: 0.6082, Accuracy: 70.11%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [49/100] - [TRAIN] Loss: 0.5384, Accuracy: 74.39%, AUC: 0.74 [VAL] Loss: 0.5893, Accuracy: 70.62%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [50/100] - [TRAIN] Loss: 0.5351, Accuracy: 74.61%, AUC: 0.74 [VAL] Loss: 0.6057, Accuracy: 70.17%, Precision: 0.70, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [51/100] - [TRAIN] Loss: 0.5346, Accuracy: 74.68%, AUC: 0.74 [VAL] Loss: 0.5979, Accuracy: 70.64%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [52/100] - [TRAIN] Loss: 0.5369, Accuracy: 74.39%, AUC: 0.74 [VAL] Loss: 0.6143, Accuracy: 69.61%, Precision: 0.71, Recall: 0.61, F1-Score: 0.65, AUC: 0.69
# Epoch [53/100] - [TRAIN] Loss: 0.5351, Accuracy: 74.66%, AUC: 0.74 [VAL] Loss: 0.5970, Accuracy: 70.52%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [54/100] - [TRAIN] Loss: 0.5319, Accuracy: 74.67%, AUC: 0.74 [VAL] Loss: 0.6072, Accuracy: 69.98%, Precision: 0.70, Recall: 0.63, F1-Score: 0.66, AUC: 0.70
# Epoch [55/100] - [TRAIN] Loss: 0.5357, Accuracy: 74.74%, AUC: 0.74 [VAL] Loss: 0.6017, Accuracy: 70.47%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [56/100] - [TRAIN] Loss: 0.5307, Accuracy: 74.96%, AUC: 0.75 [VAL] Loss: 0.6080, Accuracy: 69.59%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.69
# Epoch [57/100] - [TRAIN] Loss: 0.5354, Accuracy: 74.71%, AUC: 0.74 [VAL] Loss: 0.6102, Accuracy: 70.07%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [58/100] - [TRAIN] Loss: 0.5335, Accuracy: 74.69%, AUC: 0.74 [VAL] Loss: 0.6038, Accuracy: 70.33%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [59/100] - [TRAIN] Loss: 0.5289, Accuracy: 75.19%, AUC: 0.75 [VAL] Loss: 0.6028, Accuracy: 70.15%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [60/100] - [TRAIN] Loss: 0.5337, Accuracy: 74.70%, AUC: 0.74 [VAL] Loss: 0.6082, Accuracy: 70.61%, Precision: 0.69, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [61/100] - [TRAIN] Loss: 0.5318, Accuracy: 75.02%, AUC: 0.75 [VAL] Loss: 0.6033, Accuracy: 70.31%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [62/100] - [TRAIN] Loss: 0.5311, Accuracy: 74.86%, AUC: 0.75 [VAL] Loss: 0.6119, Accuracy: 69.66%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.69
# Epoch [63/100] - [TRAIN] Loss: 0.5293, Accuracy: 75.22%, AUC: 0.75 [VAL] Loss: 0.5985, Accuracy: 70.48%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [64/100] - [TRAIN] Loss: 0.5311, Accuracy: 75.06%, AUC: 0.75 [VAL] Loss: 0.6080, Accuracy: 70.05%, Precision: 0.71, Recall: 0.63, F1-Score: 0.66, AUC: 0.70
# Epoch [65/100] - [TRAIN] Loss: 0.5310, Accuracy: 75.17%, AUC: 0.75 [VAL] Loss: 0.6128, Accuracy: 70.34%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [66/100] - [TRAIN] Loss: 0.5290, Accuracy: 75.28%, AUC: 0.75 [VAL] Loss: 0.6205, Accuracy: 70.32%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [67/100] - [TRAIN] Loss: 0.5310, Accuracy: 75.23%, AUC: 0.75 [VAL] Loss: 0.6002, Accuracy: 70.85%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [68/100] - [TRAIN] Loss: 0.5315, Accuracy: 75.14%, AUC: 0.75 [VAL] Loss: 0.5960, Accuracy: 71.02%, Precision: 0.72, Recall: 0.62, F1-Score: 0.67, AUC: 0.70
# Epoch [69/100] - [TRAIN] Loss: 0.5291, Accuracy: 75.10%, AUC: 0.75 [VAL] Loss: 0.6122, Accuracy: 70.42%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [70/100] - [TRAIN] Loss: 0.5313, Accuracy: 74.89%, AUC: 0.75 [VAL] Loss: 0.6082, Accuracy: 70.44%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [71/100] - [TRAIN] Loss: 0.5257, Accuracy: 75.42%, AUC: 0.75 [VAL] Loss: 0.6173, Accuracy: 69.54%, Precision: 0.72, Recall: 0.59, F1-Score: 0.65, AUC: 0.69
# Epoch [72/100] - [TRAIN] Loss: 0.5255, Accuracy: 75.26%, AUC: 0.75 [VAL] Loss: 0.6109, Accuracy: 70.07%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [73/100] - [TRAIN] Loss: 0.5283, Accuracy: 75.19%, AUC: 0.75 [VAL] Loss: 0.6147, Accuracy: 70.43%, Precision: 0.70, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [74/100] - [TRAIN] Loss: 0.5293, Accuracy: 75.28%, AUC: 0.75 [VAL] Loss: 0.6141, Accuracy: 70.04%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [75/100] - [TRAIN] Loss: 0.5295, Accuracy: 75.23%, AUC: 0.75 [VAL] Loss: 0.5982, Accuracy: 70.88%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [76/100] - [TRAIN] Loss: 0.5276, Accuracy: 75.50%, AUC: 0.75 [VAL] Loss: 0.6091, Accuracy: 69.75%, Precision: 0.69, Recall: 0.63, F1-Score: 0.66, AUC: 0.69
# Epoch [77/100] - [TRAIN] Loss: 0.5279, Accuracy: 75.27%, AUC: 0.75 [VAL] Loss: 0.6152, Accuracy: 69.73%, Precision: 0.71, Recall: 0.61, F1-Score: 0.65, AUC: 0.69
# Epoch [78/100] - [TRAIN] Loss: 0.5302, Accuracy: 75.23%, AUC: 0.75 [VAL] Loss: 0.6171, Accuracy: 70.12%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [79/100] - [TRAIN] Loss: 0.5265, Accuracy: 75.42%, AUC: 0.75 [VAL] Loss: 0.6138, Accuracy: 70.44%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [80/100] - [TRAIN] Loss: 0.5256, Accuracy: 75.62%, AUC: 0.75 [VAL] Loss: 0.6189, Accuracy: 69.99%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [81/100] - [TRAIN] Loss: 0.5279, Accuracy: 75.37%, AUC: 0.75 [VAL] Loss: 0.6120, Accuracy: 69.73%, Precision: 0.70, Recall: 0.63, F1-Score: 0.66, AUC: 0.69
# Epoch [82/100] - [TRAIN] Loss: 0.5230, Accuracy: 75.66%, AUC: 0.75 [VAL] Loss: 0.6160, Accuracy: 70.38%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [83/100] - [TRAIN] Loss: 0.5294, Accuracy: 75.22%, AUC: 0.75 [VAL] Loss: 0.6175, Accuracy: 69.92%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [84/100] - [TRAIN] Loss: 0.5268, Accuracy: 75.45%, AUC: 0.75 [VAL] Loss: 0.6143, Accuracy: 70.34%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [85/100] - [TRAIN] Loss: 0.5275, Accuracy: 75.49%, AUC: 0.75 [VAL] Loss: 0.6034, Accuracy: 70.94%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [86/100] - [TRAIN] Loss: 0.5263, Accuracy: 75.68%, AUC: 0.75 [VAL] Loss: 0.6074, Accuracy: 70.27%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [87/100] - [TRAIN] Loss: 0.5235, Accuracy: 75.54%, AUC: 0.75 [VAL] Loss: 0.6185, Accuracy: 69.98%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [88/100] - [TRAIN] Loss: 0.5252, Accuracy: 75.54%, AUC: 0.75 [VAL] Loss: 0.6029, Accuracy: 70.30%, Precision: 0.72, Recall: 0.62, F1-Score: 0.67, AUC: 0.70
# Epoch [89/100] - [TRAIN] Loss: 0.5226, Accuracy: 75.60%, AUC: 0.75 [VAL] Loss: 0.6268, Accuracy: 69.64%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.69
# Epoch [90/100] - [TRAIN] Loss: 0.5221, Accuracy: 75.80%, AUC: 0.75 [VAL] Loss: 0.6254, Accuracy: 69.41%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [91/100] - [TRAIN] Loss: 0.5231, Accuracy: 75.77%, AUC: 0.75 [VAL] Loss: 0.6189, Accuracy: 70.00%, Precision: 0.71, Recall: 0.63, F1-Score: 0.66, AUC: 0.70
# Epoch [92/100] - [TRAIN] Loss: 0.5212, Accuracy: 75.93%, AUC: 0.76 [VAL] Loss: 0.6116, Accuracy: 71.44%, Precision: 0.72, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [93/100] - [TRAIN] Loss: 0.5242, Accuracy: 75.85%, AUC: 0.76 [VAL] Loss: 0.6133, Accuracy: 69.92%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [94/100] - [TRAIN] Loss: 0.5208, Accuracy: 75.89%, AUC: 0.76 [VAL] Loss: 0.6140, Accuracy: 70.07%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [95/100] - [TRAIN] Loss: 0.5225, Accuracy: 75.66%, AUC: 0.75 [VAL] Loss: 0.6205, Accuracy: 70.03%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [96/100] - [TRAIN] Loss: 0.5270, Accuracy: 75.58%, AUC: 0.75 [VAL] Loss: 0.6135, Accuracy: 70.15%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [97/100] - [TRAIN] Loss: 0.5219, Accuracy: 75.81%, AUC: 0.75 [VAL] Loss: 0.6060, Accuracy: 70.95%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [98/100] - [TRAIN] Loss: 0.5223, Accuracy: 75.84%, AUC: 0.76 [VAL] Loss: 0.6170, Accuracy: 70.17%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [99/100] - [TRAIN] Loss: 0.5245, Accuracy: 75.68%, AUC: 0.75 [VAL] Loss: 0.6178, Accuracy: 69.99%, Precision: 0.69, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [100/100] - [TRAIN] Loss: 0.5265, Accuracy: 75.71%, AUC: 0.75 [VAL] Loss: 0.6064, Accuracy: 70.66%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.70

# %%
plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies, NUM_ITEMS)

# %% [markdown]
# ## Testing

# %%
# Predict on test set
test_predictions = []
test_true_labels = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, _, _ = model(X_batch.to(dtype=torch.float32).to(device))
        
        predictions = (outputs.squeeze(1) >= 0.5).long()
        test_true_labels.extend(y_batch.cpu().numpy())
        test_predictions.extend(predictions.cpu().numpy())

# %%
# Evaluation metrics
# Precision, Recall, F1-Score
precision, recall, f1_score, _ = precision_recall_fscore_support(
    test_true_labels, 
    test_predictions, 
    average='binary'  # Use 'macro' for multi-class
)

test_acc_score = accuracy_score(test_true_labels, test_predictions) * 100
test_auc_score = roc_auc_score(test_true_labels, test_predictions)
cr = classification_report(test_true_labels, test_predictions)
cm = confusion_matrix(test_true_labels, test_predictions)

# %%
test_output = f"""Accuracy Score on test set: {test_acc_score:.2f} %
AUC Score on test set: {test_auc_score:.2f}
Precision: {precision:.4f}
Recall: {recall:.4f}
F1-Score: {f1_score:.4f}

Detailed Classification Report:
{cr}

Confusion Matrix:
{cm}
"""

print(test_output)
# Out:
# Accuracy Score on test set: 69.97 %
# AUC Score on test set: 0.70
# Precision: 0.6853
# Recall: 0.6515
# F1-Score: 0.6680
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.73      5363
#            1       0.69      0.65      0.67      4637
#
#     accuracy                           0.70     10000
#    macro avg       0.70      0.70      0.70     10000
# weighted avg       0.70      0.70      0.70     10000
#
#
# Confusion Matrix:
# [[3976 1387]
#  [1616 3021]]

# %%
# Save the test output to text file
test_file_name = os.path.join(WORKING_DIR, 'output', 'test', MODE, f"{MODEL_MODE}-test-results-{NUM_ITEMS}-{NUM_EPOCHS}.txt")
with open(test_file_name, 'w', newline = '') as text_file:
    text_file.write(test_output)

# %% [markdown]
# # Saving All Metrics

# %%
# Training metrics
file_name = f"{MODEL_MODE}-train-validation-metrics-{NUM_ITEMS}-{NUM_EPOCHS}.csv"
result_file = os.path.join(WORKING_DIR, 'output', 'train', MODE, f"{file_name}")

experiment_results = {
    'train_loss'    : train_losses,
    'train_accuracy': train_accuracies,
    'train_auc'     : train_aucs,
    'val_loss'      : val_losses,
    'val_accuracy'  : val_accuracies,
    'val_auc'       : val_aucs
}

experiment_pl = pl.DataFrame(experiment_results)

experiment_pl.write_csv(result_file)

# %%
# Test output
test_name = f"{MODEL_MODE}-test-metrics-{NUM_ITEMS}-{NUM_EPOCHS}.csv"
test_file = os.path.join(WORKING_DIR, 'output', 'test', MODE,f"{test_name}")

test_results = {
    'test_acc'    : round(test_acc_score, 4),
    'test_auc'    : round(test_auc_score, 4)
}

test_pl = pl.DataFrame(test_results)
test_pl.write_csv(test_file)

# %%
# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(test_true_labels, test_predictions) 
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC for HepG2 Ranking')
plt.legend()

img_name = f"{MODEL_MODE}-roc-{NUM_ITEMS}-{NUM_EPOCHS}.png"
plt.savefig(os.path.join(WORKING_DIR, 'output', 'img', 'roc', MODE, img_name))

plt.show()

# %%
# Plot the confusion matrix
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm)
fig, ax = plt.subplots(figsize=(10, 8))
cm_display.plot(ax=ax)
img_name = f"{MODEL_MODE}-cm-{NUM_ITEMS}-{NUM_EPOCHS}.png"
plt.savefig(os.path.join(WORKING_DIR, 'output', 'img', 'confusion_matrix', MODE, img_name))
