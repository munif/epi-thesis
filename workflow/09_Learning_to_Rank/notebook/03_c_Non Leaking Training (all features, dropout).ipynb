# %%
import os
import random

import pandas as pd
import polars as pl
import numpy as np

import pyarrow as pa
import pyarrow.parquet as pq

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Declare  variables, working directory and dataset directory
MODE = 'all_features'
NUM_EPOCHS = 100
START_EPOCH = 0
NUM_ITEMS = 100_000
BATCH_SIZE = 512
DROPOUT_RATE = 0.5

WORKING_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank'
DATASET_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/dataset'

MODEL_MODE = "do" # regular (reg), dropout (do), dropout + l1l2 (dol1l2)
CHECKPOINT_NAME = os.path.join(WORKING_DIR, 'output', 'model', MODE, f'{MODEL_MODE}-{DROPOUT_RATE}-checkpoint-{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}.pt')

INPUT_SIZE = 40000

# %%
CHECKPOINT_NAME
# Out:
# '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/output/model/all_features/do-0.5-checkpoint-100000-100-1024.pt'

# %%
def get_device():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    if device.type == "cuda":
        print(f"Current CUDA device: {torch.cuda.current_device()}")
        print(f"CUDA device name: {torch.cuda.get_device_name(0)}")

    return device

# %%
device = get_device()
# Out:
# Using device: cuda
# Current CUDA device: 0
# CUDA device name: Tesla P100-SXM2-16GB

# %%
class HepG2Dataset(Dataset):
    def __init__(self, total_samples, features, indexes):
        self.total_samples = total_samples
        self.features = features
        self.indexes = indexes

    def __len__(self):
        return self.total_samples

    def __getitem__(self, idx):
        r1 = random.choice(self.indexes)
        r2 = random.choice(self.indexes)
        
        feature_1 = self.features[r1, 2]
        feature_2 = self.features[r2, 2]
        feature = np.concatenate((feature_1, feature_2), axis=0)
        
        val_1 = self.features[r1, 3]
        val_2 = self.features[r2, 3]
        
        y = 1 if val_1 > val_2 else 0
        
        return feature, y

# %%
class BinaryClassifier(nn.Module):
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1):
        super(BinaryClassifier, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(input_size, hidden1_size),
            nn.ReLU(),
            nn.Linear(hidden1_size, hidden2_size),
            nn.ReLU(),
            nn.Linear(hidden2_size, output_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        # x = x.squeeze(1)
        return self.network(x)

    def predict(self, x):
        with torch.no_grad():
            outputs = self.forward(x)
            return (outputs >= 0.5).long()

# %%
class BinaryClassifierDropOut(nn.Module):
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1, dropout_rate=0.2):
        super(BinaryClassifierDropOut, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(input_size, hidden1_size),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(hidden1_size, hidden2_size),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(hidden2_size, output_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        # x = x.squeeze(1)
        return self.network(x)

    def predict(self, x):
        with torch.no_grad():
            outputs = self.forward(x)
            return (outputs >= 0.5).long()

# %%
class BinaryClassifierDropOutL1L2(nn.Module):
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1, dropout_rate=0.2, l1_lambda=0.001, l2_lambda=0.001):
        super(BinaryClassifierDropOutL1L2, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(input_size, hidden1_size),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(hidden1_size, hidden2_size),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(hidden2_size, output_size),
            nn.Sigmoid()
        )

        self.l1_lambda = l1_lambda
        self.l2_lambda = l2_lambda

    def forward(self, x):
        # x = x.squeeze(1)
        outputs = self.network(x)
        l1_reg = torch.tensor(0., requires_grad=True)
        l2_reg = torch.tensor(0., requires_grad=True)

        for name, param in self.named_parameters():
            if 'weight' in name:
                l1_reg = l1_reg + torch.linalg.norm(param, 1)
                l2_reg = l2_reg + torch.linalg.norm(param, 2)

        return outputs, self.l1_lambda * l1_reg, self.l2_lambda * l2_reg

    def predict(self, x):
        with torch.no_grad():
            outputs, _, _ = self.forward(x)
            return (outputs >= 0.5).long()

# %%
def plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies, num_items):
    epochs = range(1, len(train_losses) + 1)
    
    plt.figure(figsize=(14, 6))
    
    # Plot for training and validation Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, 'blue', label='Training Loss')
    plt.plot(epochs, val_losses, 'orange', label='Validation Loss')
    plt.title(f'Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim(0.4, 0.8)
    plt.legend()
    plt.grid(True)
    
    # Plot for training and validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, 'blue', label='Training Accuracy')
    plt.plot(epochs, val_accuracies, 'orange', label='Validation Accuracy')
    
    if DROPOUT_RATE != 0:
        plt.title(f'Training and Validation Accuracy with {NUM_ITEMS} and dropout rate = {DROPOUT_RATE}')
    else:
        plt.title(f'Training and Validation Accuracy with {NUM_ITEMS}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.ylim(50, 90)
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()

    img_name = f"{MODEL_MODE}-{DROPOUT_RATE}-ranking-{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}.png"
    plt.savefig(os.path.join(WORKING_DIR, 'output', 'img', 'train', MODE, img_name))
    
    plt.show()

# %%
# Load dataset
all_features = pl.read_parquet(os.path.join(DATASET_DIR, 'features', f'{MODE}.parquet'))
all_features
# Out:
# shape: (22_154, 4)
# ┌───────┬─────────────┬───────────────────┬───────────┐
# │ index ┆ gene_id     ┆ all_features      ┆ value_1   │
# │ ---   ┆ ---         ┆ ---               ┆ ---       │
# │ u32   ┆ str         ┆ list[f64]         ┆ f64       │
# ╞═══════╪═════════════╪═══════════════════╪═══════════╡
# │ 0     ┆ XLOC_000001 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 1     ┆ XLOC_000003 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 2     ┆ XLOC_000006 ┆ [0.0, 0.0, … 0.0] ┆ 0.0888452 │
# │ 3     ┆ XLOC_000007 ┆ [0.0, 0.0, … 0.0] ┆ 4.04743   │
# │ 4     ┆ XLOC_000008 ┆ [0.0, 0.0, … 0.0] ┆ 26.7934   │
# │ …     ┆ …           ┆ …                 ┆ …         │
# │ 22149 ┆ XLOC_030009 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22150 ┆ XLOC_030012 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22151 ┆ XLOC_030014 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22152 ┆ XLOC_030017 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# │ 22153 ┆ XLOC_030018 ┆ [0.0, 0.0, … 0.0] ┆ 0.0       │
# └───────┴─────────────┴───────────────────┴───────────┘

# %%
# Convert to numpy array
all_features_np = all_features.to_numpy()

# %%
# Split train, test, validation by index
data_indices = np.arange(len(all_features_np))
print(data_indices)
# Out:
# [    0     1     2 ... 22151 22152 22153]

# %%
# First split: 80% train, 20% temporary (for test + validation)
train_idx, temp_idx = train_test_split(
    data_indices, 
    test_size=0.2, 
    random_state=42  # For reproducibility
)

# %%
# Second split: Split temp_idx into 50% test and 50% validation
val_idx, test_idx = train_test_split(
    temp_idx, 
    test_size=0.5, 
    random_state=42  # Same random_state for consistency
)

# %%
# Result: train_idx (80%), test_idx (10%), val_idx (10%)
print(f"Train indices: {len(train_idx)}")
print(f"Test indices: {len(test_idx)}")
print(f"Validation indices: {len(val_idx)}")
# Out:
# Train indices: 17723
# Test indices: 2216
# Validation indices: 2215

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Training

# %%
# Define the dataset
train_dataset = HepG2Dataset(int(0.8 * NUM_ITEMS), all_features_np, train_idx)
val_dataset = HepG2Dataset(int(0.1 * NUM_ITEMS), all_features_np, val_idx)
test_dataset = HepG2Dataset(int(0.1 * NUM_ITEMS), all_features_np, test_idx)

# %%
print(len(train_dataset))
print(len(val_dataset))
print(len(test_dataset))
# Out:
# 80000
# 10000
# 10000

# %%
# Define the dataloader
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)

# %%
# Initialize model
if MODEL_MODE == "reg":
    model = BinaryClassifier(input_size=INPUT_SIZE).to(device)
elif MODEL_MODE == "do":
    model = BinaryClassifierDropOut(input_size=INPUT_SIZE, dropout_rate=DROPOUT_RATE).to(device)
elif MODEL_MODE == "dol1l2":
    model = BinaryClassifierDropOutL1L2(input_size=INPUT_SIZE, dropout_rate=DROPOUT_RATE).to(device)

# Define loss function for binary classification
criterion = nn.BCELoss()  # Binary Cross Entropy Loss

# Training loop example
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Arrays for saving the performance metric
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
train_aucs, val_aucs = [], []
val_precisions = []
val_recalls = []
val_f1_scores = []

# %%
# Check if the checkpoint exists
if os.path.exists(CHECKPOINT_NAME):
    checkpoint = torch.load(CHECKPOINT_NAME)
    
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    START_EPOCH = checkpoint['epoch'] + 1
    train_losses = checkpoint['train_losses']
    val_losses = checkpoint['val_losses']
    train_accuracies = checkpoint['train_accuracies']
    val_accuracies = checkpoint['val_accuracies']
    train_aucs = checkpoint['train_aucs']
    val_aucs = checkpoint['val_aucs']
    val_precisions = checkpoint['val_precisions']
    val_recalls = checkpoint['val_recalls']
    val_f1_scores = checkpoint['val_f1_scores']

    print(f"{CHECKPOINT_NAME} exists. Resuming training from epoch {START_EPOCH}.")
else:
    START_EPOCH = 0

# %%
# Training loop
for epoch in range(START_EPOCH, NUM_EPOCHS):
    model.train()

    train_loss = 0
    train_correct = 0
    train_total = 0
    train_true_labels = []
    train_predicted_labels = []

    # Training phase
    for X_batch, y_batch in train_loader:

        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Calculate accuracy
        predictions = (outputs.squeeze(1) >= 0.5).long()

        train_loss += loss.item()
        train_correct += (predictions == y_batch.to(device)).sum().item()
        train_total += y_batch.size(0)
        
        train_true_labels.extend(y_batch.cpu().numpy())
        train_predicted_labels.extend(predictions.cpu().numpy())
        
    avg_train_loss = train_loss / len(train_loader)
    train_accuracy = 100 * train_correct / train_total
    train_auc_score = roc_auc_score(train_true_labels, train_predicted_labels)

    train_losses.append(round(avg_train_loss, 4))
    train_accuracies.append(round(train_accuracy, 2))
    train_aucs.append(round(train_auc_score, 2))

    # Validation phase
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    val_metric = 0
    val_true_labels = []
    val_predicted_labels = []

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            
            if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
                outputs = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
            elif MODEL_MODE == "dol1l2":
                outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg
            
            predictions = (outputs.squeeze(1) >= 0.5).long()
            
            val_loss += loss.item()
            val_correct += (predictions == y_batch.to(dtype=torch.float32).to(device)).sum().item()
            val_total += y_batch.size(0)
            val_true_labels.extend(y_batch.cpu().numpy())
            val_predicted_labels.extend(predictions.cpu().numpy())
            
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_metric = val_correct / len(val_loader)

        # Calculate precision, recall, and F1-score
        precision, recall, f1_score, _ = precision_recall_fscore_support(
            val_true_labels, 
            val_predicted_labels, 
            average='binary'  # Use macro average for multi-class classification
        )

        val_true_labels = np.array(val_true_labels)
        val_predicted_labels = np.array(val_predicted_labels)
        val_auc_score = roc_auc_score(val_true_labels, val_predicted_labels)

        val_losses.append(round(avg_val_loss, 4))
        val_accuracies.append(round(val_accuracy, 2))
        val_aucs.append(round(val_auc_score, 2))
        val_precisions.append(round(precision, 2))
        val_recalls.append(round(recall, 2))
        val_f1_scores.append(round(f1_score, 2))
    

    print(f'Epoch [{epoch+1}/{NUM_EPOCHS}] - '
          f'[TRAIN] Loss: {avg_train_loss:.4f}, Accuracy: {train_accuracy:.2f}%, AUC: {train_auc_score:.2f} '
          f'[VAL] Loss: {avg_val_loss:.4f}, Accuracy: {val_accuracy:.2f}%, '
          f'Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1_score:.2f}, '
          f'AUC: {val_auc_score:.2f}')
    
    # Save the model
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accuracies': train_accuracies,
        'val_accuracies': val_accuracies,
        'train_aucs': train_aucs,
        'val_aucs': val_aucs,
        'val_precisions': val_precisions,
        'val_recalls': val_recalls,
        'val_f1_scores': val_f1_scores,
    }, CHECKPOINT_NAME)
# Out:
# Epoch [1/100] - [TRAIN] Loss: 0.5998, Accuracy: 68.15%, AUC: 0.68 [VAL] Loss: 0.5771, Accuracy: 69.73%, Precision: 0.67, Recall: 0.71, F1-Score: 0.69, AUC: 0.70
# Epoch [2/100] - [TRAIN] Loss: 0.5855, Accuracy: 69.75%, AUC: 0.69 [VAL] Loss: 0.5667, Accuracy: 70.58%, Precision: 0.74, Recall: 0.59, F1-Score: 0.66, AUC: 0.70
# Epoch [3/100] - [TRAIN] Loss: 0.5789, Accuracy: 70.42%, AUC: 0.70 [VAL] Loss: 0.5806, Accuracy: 69.88%, Precision: 0.74, Recall: 0.58, F1-Score: 0.65, AUC: 0.69
# Epoch [4/100] - [TRAIN] Loss: 0.5752, Accuracy: 70.27%, AUC: 0.70 [VAL] Loss: 0.5666, Accuracy: 70.45%, Precision: 0.75, Recall: 0.57, F1-Score: 0.65, AUC: 0.70
# Epoch [5/100] - [TRAIN] Loss: 0.5730, Accuracy: 70.62%, AUC: 0.70 [VAL] Loss: 0.5680, Accuracy: 70.67%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.70
# Epoch [6/100] - [TRAIN] Loss: 0.5698, Accuracy: 70.90%, AUC: 0.70 [VAL] Loss: 0.5662, Accuracy: 70.27%, Precision: 0.75, Recall: 0.57, F1-Score: 0.65, AUC: 0.70
# Epoch [7/100] - [TRAIN] Loss: 0.5643, Accuracy: 70.97%, AUC: 0.70 [VAL] Loss: 0.5680, Accuracy: 70.56%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [8/100] - [TRAIN] Loss: 0.5671, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5669, Accuracy: 70.49%, Precision: 0.73, Recall: 0.60, F1-Score: 0.66, AUC: 0.70
# Epoch [9/100] - [TRAIN] Loss: 0.5652, Accuracy: 71.01%, AUC: 0.70 [VAL] Loss: 0.5670, Accuracy: 70.97%, Precision: 0.74, Recall: 0.58, F1-Score: 0.65, AUC: 0.70
# Epoch [10/100] - [TRAIN] Loss: 0.5633, Accuracy: 71.11%, AUC: 0.71 [VAL] Loss: 0.5728, Accuracy: 70.01%, Precision: 0.73, Recall: 0.58, F1-Score: 0.64, AUC: 0.69
# Epoch [11/100] - [TRAIN] Loss: 0.5668, Accuracy: 70.72%, AUC: 0.70 [VAL] Loss: 0.5685, Accuracy: 70.61%, Precision: 0.73, Recall: 0.60, F1-Score: 0.66, AUC: 0.70
# Epoch [12/100] - [TRAIN] Loss: 0.5612, Accuracy: 70.87%, AUC: 0.71 [VAL] Loss: 0.5732, Accuracy: 69.68%, Precision: 0.74, Recall: 0.56, F1-Score: 0.64, AUC: 0.69
# Epoch [13/100] - [TRAIN] Loss: 0.5604, Accuracy: 70.94%, AUC: 0.71 [VAL] Loss: 0.5693, Accuracy: 70.39%, Precision: 0.72, Recall: 0.60, F1-Score: 0.66, AUC: 0.70
# Epoch [14/100] - [TRAIN] Loss: 0.5644, Accuracy: 70.77%, AUC: 0.70 [VAL] Loss: 0.5564, Accuracy: 71.18%, Precision: 0.75, Recall: 0.58, F1-Score: 0.66, AUC: 0.71
# Epoch [15/100] - [TRAIN] Loss: 0.5605, Accuracy: 71.20%, AUC: 0.71 [VAL] Loss: 0.5576, Accuracy: 71.37%, Precision: 0.75, Recall: 0.59, F1-Score: 0.66, AUC: 0.71
# Epoch [16/100] - [TRAIN] Loss: 0.5592, Accuracy: 71.17%, AUC: 0.71 [VAL] Loss: 0.5717, Accuracy: 70.15%, Precision: 0.68, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [17/100] - [TRAIN] Loss: 0.5587, Accuracy: 71.12%, AUC: 0.71 [VAL] Loss: 0.5626, Accuracy: 70.72%, Precision: 0.75, Recall: 0.57, F1-Score: 0.65, AUC: 0.70
# Epoch [18/100] - [TRAIN] Loss: 0.5578, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5703, Accuracy: 69.72%, Precision: 0.74, Recall: 0.55, F1-Score: 0.63, AUC: 0.69
# Epoch [19/100] - [TRAIN] Loss: 0.5569, Accuracy: 71.19%, AUC: 0.71 [VAL] Loss: 0.5689, Accuracy: 70.42%, Precision: 0.69, Recall: 0.68, F1-Score: 0.69, AUC: 0.70
# Epoch [20/100] - [TRAIN] Loss: 0.5569, Accuracy: 71.31%, AUC: 0.71 [VAL] Loss: 0.5678, Accuracy: 70.20%, Precision: 0.68, Recall: 0.69, F1-Score: 0.68, AUC: 0.70
# Epoch [21/100] - [TRAIN] Loss: 0.5554, Accuracy: 71.41%, AUC: 0.71 [VAL] Loss: 0.5786, Accuracy: 69.63%, Precision: 0.73, Recall: 0.55, F1-Score: 0.63, AUC: 0.69
# Epoch [22/100] - [TRAIN] Loss: 0.5540, Accuracy: 71.38%, AUC: 0.71 [VAL] Loss: 0.5601, Accuracy: 70.62%, Precision: 0.69, Recall: 0.69, F1-Score: 0.69, AUC: 0.71
# Epoch [23/100] - [TRAIN] Loss: 0.5582, Accuracy: 70.93%, AUC: 0.71 [VAL] Loss: 0.5707, Accuracy: 70.48%, Precision: 0.68, Recall: 0.70, F1-Score: 0.69, AUC: 0.70
# Epoch [24/100] - [TRAIN] Loss: 0.5563, Accuracy: 71.33%, AUC: 0.71 [VAL] Loss: 0.5771, Accuracy: 69.67%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [25/100] - [TRAIN] Loss: 0.5580, Accuracy: 71.11%, AUC: 0.71 [VAL] Loss: 0.5636, Accuracy: 70.80%, Precision: 0.68, Recall: 0.69, F1-Score: 0.69, AUC: 0.71
# Epoch [26/100] - [TRAIN] Loss: 0.5547, Accuracy: 71.40%, AUC: 0.71 [VAL] Loss: 0.5727, Accuracy: 70.13%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [27/100] - [TRAIN] Loss: 0.5525, Accuracy: 71.52%, AUC: 0.71 [VAL] Loss: 0.5731, Accuracy: 70.27%, Precision: 0.68, Recall: 0.69, F1-Score: 0.69, AUC: 0.70
# Epoch [28/100] - [TRAIN] Loss: 0.5539, Accuracy: 71.26%, AUC: 0.71 [VAL] Loss: 0.5687, Accuracy: 70.39%, Precision: 0.67, Recall: 0.71, F1-Score: 0.69, AUC: 0.70
# Epoch [29/100] - [TRAIN] Loss: 0.5542, Accuracy: 71.39%, AUC: 0.71 [VAL] Loss: 0.5684, Accuracy: 70.89%, Precision: 0.70, Recall: 0.68, F1-Score: 0.69, AUC: 0.71
# Epoch [30/100] - [TRAIN] Loss: 0.5524, Accuracy: 71.35%, AUC: 0.71 [VAL] Loss: 0.5694, Accuracy: 70.31%, Precision: 0.73, Recall: 0.58, F1-Score: 0.65, AUC: 0.70
# Epoch [31/100] - [TRAIN] Loss: 0.5502, Accuracy: 71.39%, AUC: 0.71 [VAL] Loss: 0.5726, Accuracy: 70.29%, Precision: 0.69, Recall: 0.69, F1-Score: 0.69, AUC: 0.70
# Epoch [32/100] - [TRAIN] Loss: 0.5515, Accuracy: 71.29%, AUC: 0.71 [VAL] Loss: 0.5746, Accuracy: 69.57%, Precision: 0.73, Recall: 0.57, F1-Score: 0.64, AUC: 0.69
# Epoch [33/100] - [TRAIN] Loss: 0.5505, Accuracy: 71.65%, AUC: 0.71 [VAL] Loss: 0.5687, Accuracy: 70.16%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [34/100] - [TRAIN] Loss: 0.5511, Accuracy: 71.67%, AUC: 0.71 [VAL] Loss: 0.5662, Accuracy: 70.20%, Precision: 0.68, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [35/100] - [TRAIN] Loss: 0.5529, Accuracy: 71.37%, AUC: 0.71 [VAL] Loss: 0.5664, Accuracy: 70.64%, Precision: 0.69, Recall: 0.69, F1-Score: 0.69, AUC: 0.71
# Epoch [36/100] - [TRAIN] Loss: 0.5502, Accuracy: 71.61%, AUC: 0.71 [VAL] Loss: 0.5677, Accuracy: 70.93%, Precision: 0.69, Recall: 0.69, F1-Score: 0.69, AUC: 0.71
# Epoch [37/100] - [TRAIN] Loss: 0.5511, Accuracy: 71.31%, AUC: 0.71 [VAL] Loss: 0.5678, Accuracy: 70.75%, Precision: 0.69, Recall: 0.70, F1-Score: 0.69, AUC: 0.71
# Epoch [38/100] - [TRAIN] Loss: 0.5483, Accuracy: 71.62%, AUC: 0.71 [VAL] Loss: 0.5779, Accuracy: 70.09%, Precision: 0.68, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [39/100] - [TRAIN] Loss: 0.5494, Accuracy: 71.44%, AUC: 0.71 [VAL] Loss: 0.5677, Accuracy: 70.99%, Precision: 0.68, Recall: 0.72, F1-Score: 0.70, AUC: 0.71
# Epoch [40/100] - [TRAIN] Loss: 0.5466, Accuracy: 71.62%, AUC: 0.71 [VAL] Loss: 0.5759, Accuracy: 70.54%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [41/100] - [TRAIN] Loss: 0.5462, Accuracy: 71.90%, AUC: 0.72 [VAL] Loss: 0.5708, Accuracy: 70.22%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [42/100] - [TRAIN] Loss: 0.5491, Accuracy: 71.63%, AUC: 0.71 [VAL] Loss: 0.5632, Accuracy: 70.63%, Precision: 0.68, Recall: 0.70, F1-Score: 0.69, AUC: 0.71
# Epoch [43/100] - [TRAIN] Loss: 0.5454, Accuracy: 71.91%, AUC: 0.72 [VAL] Loss: 0.5808, Accuracy: 70.25%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [44/100] - [TRAIN] Loss: 0.5451, Accuracy: 71.93%, AUC: 0.72 [VAL] Loss: 0.5702, Accuracy: 70.89%, Precision: 0.70, Recall: 0.68, F1-Score: 0.69, AUC: 0.71
# Epoch [45/100] - [TRAIN] Loss: 0.5475, Accuracy: 71.86%, AUC: 0.72 [VAL] Loss: 0.5678, Accuracy: 71.11%, Precision: 0.71, Recall: 0.67, F1-Score: 0.69, AUC: 0.71
# Epoch [46/100] - [TRAIN] Loss: 0.5489, Accuracy: 71.78%, AUC: 0.72 [VAL] Loss: 0.5745, Accuracy: 70.19%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [47/100] - [TRAIN] Loss: 0.5465, Accuracy: 71.78%, AUC: 0.72 [VAL] Loss: 0.5700, Accuracy: 70.65%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [48/100] - [TRAIN] Loss: 0.5419, Accuracy: 72.25%, AUC: 0.72 [VAL] Loss: 0.5694, Accuracy: 70.19%, Precision: 0.68, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [49/100] - [TRAIN] Loss: 0.5457, Accuracy: 71.98%, AUC: 0.72 [VAL] Loss: 0.5740, Accuracy: 69.61%, Precision: 0.68, Recall: 0.67, F1-Score: 0.67, AUC: 0.69
# Epoch [50/100] - [TRAIN] Loss: 0.5456, Accuracy: 71.89%, AUC: 0.72 [VAL] Loss: 0.5676, Accuracy: 70.53%, Precision: 0.68, Recall: 0.70, F1-Score: 0.69, AUC: 0.71
# Epoch [51/100] - [TRAIN] Loss: 0.5486, Accuracy: 71.70%, AUC: 0.71 [VAL] Loss: 0.5822, Accuracy: 69.33%, Precision: 0.68, Recall: 0.66, F1-Score: 0.67, AUC: 0.69
# Epoch [52/100] - [TRAIN] Loss: 0.5461, Accuracy: 72.00%, AUC: 0.72 [VAL] Loss: 0.5717, Accuracy: 70.24%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [53/100] - [TRAIN] Loss: 0.5450, Accuracy: 72.03%, AUC: 0.72 [VAL] Loss: 0.5648, Accuracy: 70.79%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.71
# Epoch [54/100] - [TRAIN] Loss: 0.5450, Accuracy: 71.84%, AUC: 0.72 [VAL] Loss: 0.5672, Accuracy: 69.74%, Precision: 0.69, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [55/100] - [TRAIN] Loss: 0.5471, Accuracy: 71.87%, AUC: 0.72 [VAL] Loss: 0.5777, Accuracy: 69.94%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [56/100] - [TRAIN] Loss: 0.5429, Accuracy: 72.06%, AUC: 0.72 [VAL] Loss: 0.5842, Accuracy: 69.80%, Precision: 0.68, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [57/100] - [TRAIN] Loss: 0.5443, Accuracy: 72.20%, AUC: 0.72 [VAL] Loss: 0.5735, Accuracy: 69.86%, Precision: 0.70, Recall: 0.64, F1-Score: 0.66, AUC: 0.69
# Epoch [58/100] - [TRAIN] Loss: 0.5446, Accuracy: 72.17%, AUC: 0.72 [VAL] Loss: 0.5745, Accuracy: 70.61%, Precision: 0.73, Recall: 0.61, F1-Score: 0.67, AUC: 0.70
# Epoch [59/100] - [TRAIN] Loss: 0.5424, Accuracy: 72.15%, AUC: 0.72 [VAL] Loss: 0.5754, Accuracy: 70.11%, Precision: 0.67, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [60/100] - [TRAIN] Loss: 0.5417, Accuracy: 72.13%, AUC: 0.72 [VAL] Loss: 0.5808, Accuracy: 69.90%, Precision: 0.67, Recall: 0.70, F1-Score: 0.68, AUC: 0.70
# Epoch [61/100] - [TRAIN] Loss: 0.5429, Accuracy: 72.11%, AUC: 0.72 [VAL] Loss: 0.5755, Accuracy: 69.94%, Precision: 0.68, Recall: 0.69, F1-Score: 0.69, AUC: 0.70
# Epoch [62/100] - [TRAIN] Loss: 0.5407, Accuracy: 72.20%, AUC: 0.72 [VAL] Loss: 0.5624, Accuracy: 71.43%, Precision: 0.70, Recall: 0.68, F1-Score: 0.69, AUC: 0.71
# Epoch [63/100] - [TRAIN] Loss: 0.5445, Accuracy: 71.87%, AUC: 0.72 [VAL] Loss: 0.5702, Accuracy: 70.46%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [64/100] - [TRAIN] Loss: 0.5433, Accuracy: 72.02%, AUC: 0.72 [VAL] Loss: 0.5729, Accuracy: 69.78%, Precision: 0.69, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [65/100] - [TRAIN] Loss: 0.5413, Accuracy: 71.99%, AUC: 0.72 [VAL] Loss: 0.5776, Accuracy: 69.66%, Precision: 0.67, Recall: 0.68, F1-Score: 0.67, AUC: 0.70
# Epoch [66/100] - [TRAIN] Loss: 0.5413, Accuracy: 71.93%, AUC: 0.72 [VAL] Loss: 0.5853, Accuracy: 69.87%, Precision: 0.68, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [67/100] - [TRAIN] Loss: 0.5410, Accuracy: 72.22%, AUC: 0.72 [VAL] Loss: 0.5750, Accuracy: 70.36%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [68/100] - [TRAIN] Loss: 0.5421, Accuracy: 72.07%, AUC: 0.72 [VAL] Loss: 0.5835, Accuracy: 69.83%, Precision: 0.68, Recall: 0.70, F1-Score: 0.69, AUC: 0.70
# Epoch [69/100] - [TRAIN] Loss: 0.5411, Accuracy: 72.33%, AUC: 0.72 [VAL] Loss: 0.5748, Accuracy: 70.62%, Precision: 0.69, Recall: 0.70, F1-Score: 0.69, AUC: 0.71
# Epoch [70/100] - [TRAIN] Loss: 0.5403, Accuracy: 72.13%, AUC: 0.72 [VAL] Loss: 0.5657, Accuracy: 70.41%, Precision: 0.68, Recall: 0.70, F1-Score: 0.69, AUC: 0.70
# Epoch [71/100] - [TRAIN] Loss: 0.5408, Accuracy: 72.18%, AUC: 0.72 [VAL] Loss: 0.5737, Accuracy: 70.21%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [72/100] - [TRAIN] Loss: 0.5373, Accuracy: 72.48%, AUC: 0.72 [VAL] Loss: 0.5690, Accuracy: 70.65%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [73/100] - [TRAIN] Loss: 0.5380, Accuracy: 72.38%, AUC: 0.72 [VAL] Loss: 0.5705, Accuracy: 70.51%, Precision: 0.69, Recall: 0.69, F1-Score: 0.69, AUC: 0.70
# Epoch [74/100] - [TRAIN] Loss: 0.5394, Accuracy: 72.09%, AUC: 0.72 [VAL] Loss: 0.5699, Accuracy: 70.21%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [75/100] - [TRAIN] Loss: 0.5358, Accuracy: 72.52%, AUC: 0.72 [VAL] Loss: 0.5672, Accuracy: 70.23%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [76/100] - [TRAIN] Loss: 0.5408, Accuracy: 72.55%, AUC: 0.72 [VAL] Loss: 0.5833, Accuracy: 69.68%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [77/100] - [TRAIN] Loss: 0.5393, Accuracy: 72.39%, AUC: 0.72 [VAL] Loss: 0.5845, Accuracy: 69.79%, Precision: 0.69, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [78/100] - [TRAIN] Loss: 0.5397, Accuracy: 72.37%, AUC: 0.72 [VAL] Loss: 0.5855, Accuracy: 69.57%, Precision: 0.67, Recall: 0.69, F1-Score: 0.68, AUC: 0.70
# Epoch [79/100] - [TRAIN] Loss: 0.5398, Accuracy: 72.21%, AUC: 0.72 [VAL] Loss: 0.5696, Accuracy: 70.73%, Precision: 0.70, Recall: 0.68, F1-Score: 0.69, AUC: 0.71
# Epoch [80/100] - [TRAIN] Loss: 0.5391, Accuracy: 72.36%, AUC: 0.72 [VAL] Loss: 0.5747, Accuracy: 70.19%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [81/100] - [TRAIN] Loss: 0.5362, Accuracy: 72.39%, AUC: 0.72 [VAL] Loss: 0.5785, Accuracy: 69.85%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [82/100] - [TRAIN] Loss: 0.5388, Accuracy: 72.53%, AUC: 0.72 [VAL] Loss: 0.5737, Accuracy: 70.51%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [83/100] - [TRAIN] Loss: 0.5366, Accuracy: 72.44%, AUC: 0.72 [VAL] Loss: 0.5762, Accuracy: 70.00%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [84/100] - [TRAIN] Loss: 0.5355, Accuracy: 72.77%, AUC: 0.73 [VAL] Loss: 0.5688, Accuracy: 70.59%, Precision: 0.69, Recall: 0.69, F1-Score: 0.69, AUC: 0.71
# Epoch [85/100] - [TRAIN] Loss: 0.5363, Accuracy: 72.63%, AUC: 0.72 [VAL] Loss: 0.5696, Accuracy: 70.54%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [86/100] - [TRAIN] Loss: 0.5371, Accuracy: 72.58%, AUC: 0.72 [VAL] Loss: 0.5697, Accuracy: 70.57%, Precision: 0.69, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [87/100] - [TRAIN] Loss: 0.5351, Accuracy: 72.56%, AUC: 0.72 [VAL] Loss: 0.5711, Accuracy: 70.59%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [88/100] - [TRAIN] Loss: 0.5337, Accuracy: 72.91%, AUC: 0.73 [VAL] Loss: 0.5739, Accuracy: 70.27%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [89/100] - [TRAIN] Loss: 0.5367, Accuracy: 72.30%, AUC: 0.72 [VAL] Loss: 0.5791, Accuracy: 70.16%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [90/100] - [TRAIN] Loss: 0.5365, Accuracy: 72.70%, AUC: 0.72 [VAL] Loss: 0.5831, Accuracy: 69.17%, Precision: 0.68, Recall: 0.66, F1-Score: 0.67, AUC: 0.69
# Epoch [91/100] - [TRAIN] Loss: 0.5368, Accuracy: 72.51%, AUC: 0.72 [VAL] Loss: 0.5813, Accuracy: 69.83%, Precision: 0.67, Recall: 0.71, F1-Score: 0.69, AUC: 0.70
# Epoch [92/100] - [TRAIN] Loss: 0.5353, Accuracy: 72.38%, AUC: 0.72 [VAL] Loss: 0.5719, Accuracy: 70.42%, Precision: 0.68, Recall: 0.70, F1-Score: 0.69, AUC: 0.70
# Epoch [93/100] - [TRAIN] Loss: 0.5357, Accuracy: 72.68%, AUC: 0.72 [VAL] Loss: 0.5823, Accuracy: 70.33%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [94/100] - [TRAIN] Loss: 0.5346, Accuracy: 72.78%, AUC: 0.73 [VAL] Loss: 0.5760, Accuracy: 69.87%, Precision: 0.67, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [95/100] - [TRAIN] Loss: 0.5359, Accuracy: 72.43%, AUC: 0.72 [VAL] Loss: 0.5821, Accuracy: 69.58%, Precision: 0.68, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [96/100] - [TRAIN] Loss: 0.5359, Accuracy: 72.46%, AUC: 0.72 [VAL] Loss: 0.5823, Accuracy: 70.47%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [97/100] - [TRAIN] Loss: 0.5363, Accuracy: 72.44%, AUC: 0.72 [VAL] Loss: 0.5673, Accuracy: 71.00%, Precision: 0.70, Recall: 0.67, F1-Score: 0.68, AUC: 0.71
# Epoch [98/100] - [TRAIN] Loss: 0.5373, Accuracy: 72.37%, AUC: 0.72 [VAL] Loss: 0.5741, Accuracy: 70.30%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [99/100] - [TRAIN] Loss: 0.5325, Accuracy: 72.53%, AUC: 0.72 [VAL] Loss: 0.5899, Accuracy: 68.93%, Precision: 0.67, Recall: 0.66, F1-Score: 0.67, AUC: 0.69
# Epoch [100/100] - [TRAIN] Loss: 0.5335, Accuracy: 72.80%, AUC: 0.73 [VAL] Loss: 0.5760, Accuracy: 70.30%, Precision: 0.68, Recall: 0.69, F1-Score: 0.69, AUC: 0.70

# %%
plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies, NUM_ITEMS)

# %% [markdown]
# ## Testing

# %%
# Predict on test set
test_predictions = []
test_true_labels = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, _, _ = model(X_batch.to(dtype=torch.float32).to(device))
        
        predictions = (outputs.squeeze(1) >= 0.5).long()
        test_true_labels.extend(y_batch.cpu().numpy())
        test_predictions.extend(predictions.cpu().numpy())

# %%
# Evaluation metrics
# Precision, Recall, F1-Score
precision, recall, f1_score, _ = precision_recall_fscore_support(
    test_true_labels, 
    test_predictions, 
    average='binary'  # Use 'macro' for multi-class
)

test_acc_score = accuracy_score(test_true_labels, test_predictions) * 100
test_auc_score = roc_auc_score(test_true_labels, test_predictions)
cr = classification_report(test_true_labels, test_predictions)
cm = confusion_matrix(test_true_labels, test_predictions)

# %%
test_output = f"""Accuracy Score on test set: {test_acc_score:.2f} %
AUC Score on test set: {test_auc_score:.2f}
Precision: {precision:.4f}
Recall: {recall:.4f}
F1-Score: {f1_score:.4f}

Detailed Classification Report:
{cr}

Confusion Matrix:
{cm}
"""

print(test_output)
# Out:
# Accuracy Score on test set: 70.03 %
# AUC Score on test set: 0.70
# Precision: 0.6851
# Recall: 0.6783
# F1-Score: 0.6817
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.72      5269
#            1       0.69      0.68      0.68      4731
#
#     accuracy                           0.70     10000
#    macro avg       0.70      0.70      0.70     10000
# weighted avg       0.70      0.70      0.70     10000
#
#
# Confusion Matrix:
# [[3794 1475]
#  [1522 3209]]

# %%
# Save the test output to text file
test_file_name = os.path.join(WORKING_DIR, 'output', 'test', MODE, f"{MODEL_MODE}-{DROPOUT_RATE}-test-results-{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}.txt")
with open(test_file_name, 'w', newline = '') as text_file:
    text_file.write(test_output)

# %% [markdown]
# # Saving All Metrics

# %%
# Training metrics
file_name = f"{MODEL_MODE}-{DROPOUT_RATE}-train-validation-metrics-{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}.csv"
result_file = os.path.join(WORKING_DIR, 'output', 'train', MODE, f"{file_name}")

experiment_results = {
    'train_loss'    : train_losses,
    'train_accuracy': train_accuracies,
    'train_auc'     : train_aucs,
    'val_loss'      : val_losses,
    'val_accuracy'  : val_accuracies,
    'val_auc'       : val_aucs
}

experiment_pl = pl.DataFrame(experiment_results)

experiment_pl.write_csv(result_file)

# %%
# Test output
test_name = f"{MODEL_MODE}-{DROPOUT_RATE}-test-metrics-{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}.csv"
test_file = os.path.join(WORKING_DIR, 'output', 'test', MODE,f"{test_name}")

test_results = {
    'test_acc'    : round(test_acc_score, 4),
    'test_auc'    : round(test_auc_score, 4)
}

test_pl = pl.DataFrame(test_results)
test_pl.write_csv(test_file)

# %%
# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(test_true_labels, test_predictions) 
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC for HepG2 Ranking')
plt.legend()

img_name = f"{MODEL_MODE}-{DROPOUT_RATE}-roc-{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}.png"
plt.savefig(os.path.join(WORKING_DIR, 'output', 'img', 'roc', MODE, img_name))

plt.show()

# %%
# Plot the confusion matrix
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm)
fig, ax = plt.subplots(figsize=(10, 8))
cm_display.plot(ax=ax)
img_name = f"{MODEL_MODE}-{DROPOUT_RATE}-cm-{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}.png"
plt.savefig(os.path.join(WORKING_DIR, 'output', 'img', 'confusion_matrix', MODE, img_name))

# %%
img_name
# Out:
# 'do-0.5-cm-100000-100.png'
