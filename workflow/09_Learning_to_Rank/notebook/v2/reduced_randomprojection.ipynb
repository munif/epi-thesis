# %%
import os
import random
from datetime import datetime

import pandas as pd
import polars as pl
import numpy as np

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import Dataset, DataLoader, TensorDataset

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

import BinaryClassifier as BC
import HepG2Dataset as HG2D
import my_util

# %%
# Declare  variables, working directory and dataset directory
MODE = 'reduced_features_rp'
NUM_EPOCHS = 200
START_EPOCH = 0
NUM_ITEMS = 1_000_000
BATCH_SIZE = 128
DROPOUT_RATE = 0.3

L1_lambda = 0.005
L2_lambda = 0.001
# L1_lambda = 0.0
# L2_lambda = 0.0

WORKING_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank'
DATASET_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/dataset'

MODEL_MODE = "dol1l2" # regular (reg), dropout (do), dropout + l1l2 (dol1l2)
PREFIX = f"{MODEL_MODE}-leakyrelu-lrscheduler-{DROPOUT_RATE}"
SUFFIX = f"{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}-{L1_lambda}-{L2_lambda}"

CHECKPOINT_NAME = os.path.join(WORKING_DIR, 'output', 'model', MODE, "v2", f'{PREFIX}-checkpoint-{SUFFIX}.pt')

IMAGE_FILE = os.path.join(WORKING_DIR, 'output', 'img', 'train', MODE, "v2", f"{PREFIX}-ranking-{SUFFIX}.png")
TEST_FILE = os.path.join(WORKING_DIR, 'output', 'test', MODE, "v2", f"{PREFIX}-test-results-{SUFFIX}.txt")
TRAINING_FILE = os.path.join(WORKING_DIR, 'output', 'train', MODE, "v2", f"{PREFIX}-train-validation-metrics-{SUFFIX}.csv")
TEST_RESULT_FILE = os.path.join(WORKING_DIR, 'output', 'test', MODE, "v2", f"{PREFIX}-test-metrics-{SUFFIX}.csv")
ROC_FILE = os.path.join(WORKING_DIR, 'output', 'img', 'roc', MODE, "v2", f"{PREFIX}-roc-{SUFFIX}.png")
CM_FILE = os.path.join(WORKING_DIR, 'output', 'img', 'confusion_matrix', MODE, "v2", f"{PREFIX}-cm-{SUFFIX}.png")

INPUT_SIZE = 200

print(CHECKPOINT_NAME)
# Out:
# /group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/output/model/reduced_features_rp/v2/dol1l2-leakyrelu-lrscheduler-0.3-checkpoint-1000000-200-128-0.005-0.001.pt

# %%
device = my_util.get_device()
# Out:
# Using device: cuda
# Current CUDA device: 0
# CUDA device name: Tesla P100-SXM2-16GB

# %%
# Load dataset
all_features = pl.read_parquet(os.path.join(DATASET_DIR, 'features', f'{MODE}.parquet'))
all_features
# Out:
# shape: (22_154, 4)
# ┌───────┬─────────────┬───────────────────────────────┬───────────┐
# │ index ┆ gene_id     ┆ reduced_features              ┆ value_1   │
# │ ---   ┆ ---         ┆ ---                           ┆ ---       │
# │ u32   ┆ str         ┆ list[f64]                     ┆ f64       │
# ╞═══════╪═════════════╪═══════════════════════════════╪═══════════╡
# │ 0     ┆ XLOC_000001 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 1     ┆ XLOC_000003 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 2     ┆ XLOC_000006 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0888452 │
# │ 3     ┆ XLOC_000007 ┆ [0.0, 0.0, … 0.0]             ┆ 4.04743   │
# │ 4     ┆ XLOC_000008 ┆ [5.717444, -11.321019, … 0.0] ┆ 26.7934   │
# │ …     ┆ …           ┆ …                             ┆ …         │
# │ 22149 ┆ XLOC_030009 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 22150 ┆ XLOC_030012 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 22151 ┆ XLOC_030014 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 22152 ┆ XLOC_030017 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 22153 ┆ XLOC_030018 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# └───────┴─────────────┴───────────────────────────────┴───────────┘

# %%
# Convert to numpy array
all_features_np = all_features.to_numpy()

# %%
# Split train, test, validation by index
data_indices = np.arange(len(all_features_np))
print(data_indices)
# Out:
# [    0     1     2 ... 22151 22152 22153]

# %%
# First split: 80% train, 20% temporary (for test + validation)
train_idx, temp_idx = train_test_split(
    data_indices, 
    test_size=0.2, 
    random_state=42  # For reproducibility
)

# %%
# Second split: Split temp_idx into 50% test and 50% validation
val_idx, test_idx = train_test_split(
    temp_idx, 
    test_size=0.5, 
    random_state=42  # Same random_state for consistency
)

# %%
print(train_idx)
print(val_idx)
print(test_idx)
# Out:
# [12829 12333  8225 ...  5390   860 15795]
# [13202 15153  3113 ...  1158  6603 15289]
# [17261  8344  1396 ...  7985   482 16493]

# %%
# Result: train_idx (80%), test_idx (10%), val_idx (10%)
print(f"Train indices: {len(train_idx)}")
print(f"Test indices: {len(test_idx)}")
print(f"Validation indices: {len(val_idx)}")
# Out:
# Train indices: 17723
# Test indices: 2216
# Validation indices: 2215

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Training

# %%
# Define the dataset
train_dataset = HG2D.HepG2Dataset(int(0.8 * NUM_ITEMS), all_features_np, train_idx)
val_dataset = HG2D.HepG2Dataset(int(0.1 * NUM_ITEMS), all_features_np, val_idx)
test_dataset = HG2D.HepG2Dataset(int(0.1 * NUM_ITEMS), all_features_np, test_idx)

# %%
print(len(train_dataset))
print(len(val_dataset))
print(len(test_dataset))
# Out:
# 800000
# 100000
# 100000

# %%
# Define the dataloader
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)

# %%
# Initialize model
if MODEL_MODE == "reg":
    model = BinaryClassifier(input_size=INPUT_SIZE).to(device)
elif MODEL_MODE == "do":
    model = BinaryClassifierDropOut(input_size=INPUT_SIZE, dropout_rate=DROPOUT_RATE).to(device)
elif MODEL_MODE == "dol1l2":
    model = BC.BinaryClassifierDropOutL1L2(input_size=INPUT_SIZE, dropout_rate=DROPOUT_RATE, l1_lambda=L1_lambda, l2_lambda=L2_lambda).to(device)

# Define loss function for binary classification
criterion = nn.BCELoss()  # Binary Cross Entropy Loss

# Training loop example
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
optimizer = optim.SGD(model.parameters(), lr=0.0001, momentum=0.9)

# Define learning rate scheduler
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.1)

# %%
print(model)
# Out:
# BinaryClassifierDropOutL1L2(
#   (network): Sequential(
#     (0): Linear(in_features=200, out_features=64, bias=True)
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=64, out_features=32, bias=True)
#     (4): LeakyReLU(negative_slope=0.1)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=32, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )

# %%
# Arrays for saving the performance metric
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
train_aucs, val_aucs = [], []
val_precisions = []
val_recalls = []
val_f1_scores = []

# %%
# Check if the checkpoint exists
if os.path.exists(CHECKPOINT_NAME):
    checkpoint = torch.load(CHECKPOINT_NAME)
    
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler'])
    START_EPOCH = checkpoint['epoch'] + 1
    train_losses = checkpoint['train_losses']
    val_losses = checkpoint['val_losses']
    train_accuracies = checkpoint['train_accuracies']
    val_accuracies = checkpoint['val_accuracies']
    train_aucs = checkpoint['train_aucs']
    val_aucs = checkpoint['val_aucs']
    val_precisions = checkpoint['val_precisions']
    val_recalls = checkpoint['val_recalls']
    val_f1_scores = checkpoint['val_f1_scores']

    print(f"{CHECKPOINT_NAME} exists. Resuming training from epoch {START_EPOCH}.")
else:
    START_EPOCH = 0
# Out:
# /group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/output/model/reduced_features_rp/v2/dol1l2-leakyrelu-lrscheduler-0.3-checkpoint-1000000-200-128-0.005-0.001.pt exists. Resuming training from epoch 200.

# %%
# Training loop
for epoch in range(START_EPOCH, NUM_EPOCHS):
    model.train()

    train_loss = 0
    train_correct = 0
    train_total = 0
    train_true_labels = []
    train_predicted_labels = []

    # Training phase
    for X_batch, y_batch in train_loader:

        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Calculate accuracy
        predictions = (outputs.squeeze(1) >= 0.5).long()

        train_loss += loss.item()
        train_correct += (predictions == y_batch.to(device)).sum().item()
        train_total += y_batch.size(0)
        
        train_true_labels.extend(y_batch.cpu().numpy())
        train_predicted_labels.extend(predictions.cpu().numpy())
        
    # # Adjust learning rate
    # scheduler.step()
    
    avg_train_loss = train_loss / len(train_loader)
    train_accuracy = 100 * train_correct / train_total
    train_auc_score = roc_auc_score(train_true_labels, train_predicted_labels)

    train_losses.append(round(avg_train_loss, 4))
    train_accuracies.append(round(train_accuracy, 2))
    train_aucs.append(round(train_auc_score, 2))

    # Validation phase
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    val_metric = 0
    val_true_labels = []
    val_predicted_labels = []

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            
            if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
                outputs = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
            elif MODEL_MODE == "dol1l2":
                outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg
            
            predictions = (outputs.squeeze(1) >= 0.5).long()
            
            val_loss += loss.item()
            val_correct += (predictions == y_batch.to(dtype=torch.float32).to(device)).sum().item()
            val_total += y_batch.size(0)
            val_true_labels.extend(y_batch.cpu().numpy())
            val_predicted_labels.extend(predictions.cpu().numpy())
            
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_metric = val_correct / len(val_loader)

        # Calculate precision, recall, and F1-score
        precision, recall, f1_score, _ = precision_recall_fscore_support(
            val_true_labels, 
            val_predicted_labels, 
            average='binary'  # Use macro average for multi-class classification
        )

        val_true_labels = np.array(val_true_labels)
        val_predicted_labels = np.array(val_predicted_labels)
        val_auc_score = roc_auc_score(val_true_labels, val_predicted_labels)

        val_losses.append(round(avg_val_loss, 4))
        val_accuracies.append(round(val_accuracy, 2))
        val_aucs.append(round(val_auc_score, 2))
        val_precisions.append(round(precision, 2))
        val_recalls.append(round(recall, 2))
        val_f1_scores.append(round(f1_score, 2))

    # Adjust learning rate
    scheduler.step(val_loss)

    print(f'Epoch [{epoch+1}/{NUM_EPOCHS}] - '
          f'[TRAIN] Loss: {avg_train_loss:.4f}, Accuracy: {train_accuracy:.2f}%, AUC: {train_auc_score:.2f} '
          f'[VAL] Loss: {avg_val_loss:.4f}, Accuracy: {val_accuracy:.2f}%, '
          f'Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1_score:.2f}, '
          f'AUC: {val_auc_score:.2f}')
    
    # Save the model
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler': scheduler.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accuracies': train_accuracies,
        'val_accuracies': val_accuracies,
        'train_aucs': train_aucs,
        'val_aucs': val_aucs,
        'val_precisions': val_precisions,
        'val_recalls': val_recalls,
        'val_f1_scores': val_f1_scores,
    }, CHECKPOINT_NAME)
# Out:
# Epoch [1/200] - [TRAIN] Loss: 0.6498, Accuracy: 66.50%, AUC: 0.67 [VAL] Loss: 0.6253, Accuracy: 69.20%, Precision: 0.70, Recall: 0.61, F1-Score: 0.65, AUC: 0.69
# Epoch [2/200] - [TRAIN] Loss: 0.6250, Accuracy: 69.60%, AUC: 0.69 [VAL] Loss: 0.6141, Accuracy: 69.69%, Precision: 0.70, Recall: 0.62, F1-Score: 0.66, AUC: 0.69
# Epoch [3/200] - [TRAIN] Loss: 0.6170, Accuracy: 69.81%, AUC: 0.69 [VAL] Loss: 0.6095, Accuracy: 69.65%, Precision: 0.71, Recall: 0.61, F1-Score: 0.65, AUC: 0.69
# Epoch [4/200] - [TRAIN] Loss: 0.6125, Accuracy: 70.01%, AUC: 0.70 [VAL] Loss: 0.6099, Accuracy: 69.47%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [5/200] - [TRAIN] Loss: 0.6093, Accuracy: 69.99%, AUC: 0.70 [VAL] Loss: 0.6057, Accuracy: 69.76%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [6/200] - [TRAIN] Loss: 0.6075, Accuracy: 70.02%, AUC: 0.70 [VAL] Loss: 0.6061, Accuracy: 69.55%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [7/200] - [TRAIN] Loss: 0.6056, Accuracy: 70.05%, AUC: 0.70 [VAL] Loss: 0.6046, Accuracy: 69.58%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [8/200] - [TRAIN] Loss: 0.6029, Accuracy: 70.28%, AUC: 0.70 [VAL] Loss: 0.6028, Accuracy: 69.66%, Precision: 0.71, Recall: 0.59, F1-Score: 0.65, AUC: 0.69
# Epoch [9/200] - [TRAIN] Loss: 0.6012, Accuracy: 70.29%, AUC: 0.70 [VAL] Loss: 0.6019, Accuracy: 69.77%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [10/200] - [TRAIN] Loss: 0.6009, Accuracy: 70.32%, AUC: 0.70 [VAL] Loss: 0.6029, Accuracy: 69.66%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [11/200] - [TRAIN] Loss: 0.5993, Accuracy: 70.35%, AUC: 0.70 [VAL] Loss: 0.6018, Accuracy: 69.60%, Precision: 0.71, Recall: 0.59, F1-Score: 0.65, AUC: 0.69
# Epoch [12/200] - [TRAIN] Loss: 0.5991, Accuracy: 70.35%, AUC: 0.70 [VAL] Loss: 0.6019, Accuracy: 69.48%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [13/200] - [TRAIN] Loss: 0.5970, Accuracy: 70.42%, AUC: 0.70 [VAL] Loss: 0.5985, Accuracy: 69.89%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [14/200] - [TRAIN] Loss: 0.5971, Accuracy: 70.42%, AUC: 0.70 [VAL] Loss: 0.5974, Accuracy: 70.03%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [15/200] - [TRAIN] Loss: 0.5962, Accuracy: 70.46%, AUC: 0.70 [VAL] Loss: 0.5983, Accuracy: 70.07%, Precision: 0.72, Recall: 0.60, F1-Score: 0.66, AUC: 0.70
# Epoch [16/200] - [TRAIN] Loss: 0.5949, Accuracy: 70.53%, AUC: 0.70 [VAL] Loss: 0.5969, Accuracy: 69.96%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [17/200] - [TRAIN] Loss: 0.5947, Accuracy: 70.49%, AUC: 0.70 [VAL] Loss: 0.5976, Accuracy: 69.73%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [18/200] - [TRAIN] Loss: 0.5935, Accuracy: 70.60%, AUC: 0.70 [VAL] Loss: 0.5967, Accuracy: 69.87%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [19/200] - [TRAIN] Loss: 0.5926, Accuracy: 70.62%, AUC: 0.70 [VAL] Loss: 0.5970, Accuracy: 69.74%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [20/200] - [TRAIN] Loss: 0.5928, Accuracy: 70.60%, AUC: 0.70 [VAL] Loss: 0.5939, Accuracy: 70.13%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [21/200] - [TRAIN] Loss: 0.5914, Accuracy: 70.76%, AUC: 0.70 [VAL] Loss: 0.5972, Accuracy: 69.86%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [22/200] - [TRAIN] Loss: 0.5911, Accuracy: 70.67%, AUC: 0.70 [VAL] Loss: 0.5929, Accuracy: 70.02%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [23/200] - [TRAIN] Loss: 0.5905, Accuracy: 70.72%, AUC: 0.70 [VAL] Loss: 0.5977, Accuracy: 69.67%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [24/200] - [TRAIN] Loss: 0.5909, Accuracy: 70.68%, AUC: 0.70 [VAL] Loss: 0.5936, Accuracy: 69.99%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [25/200] - [TRAIN] Loss: 0.5903, Accuracy: 70.70%, AUC: 0.70 [VAL] Loss: 0.5965, Accuracy: 69.73%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [26/200] - [TRAIN] Loss: 0.5893, Accuracy: 70.79%, AUC: 0.70 [VAL] Loss: 0.5951, Accuracy: 69.80%, Precision: 0.71, Recall: 0.60, F1-Score: 0.65, AUC: 0.69
# Epoch [27/200] - [TRAIN] Loss: 0.5886, Accuracy: 70.86%, AUC: 0.70 [VAL] Loss: 0.5928, Accuracy: 70.09%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [28/200] - [TRAIN] Loss: 0.5877, Accuracy: 70.84%, AUC: 0.70 [VAL] Loss: 0.5909, Accuracy: 70.31%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [29/200] - [TRAIN] Loss: 0.5883, Accuracy: 70.71%, AUC: 0.70 [VAL] Loss: 0.5919, Accuracy: 70.23%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [30/200] - [TRAIN] Loss: 0.5874, Accuracy: 70.83%, AUC: 0.70 [VAL] Loss: 0.5914, Accuracy: 70.26%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [31/200] - [TRAIN] Loss: 0.5862, Accuracy: 70.83%, AUC: 0.70 [VAL] Loss: 0.5939, Accuracy: 69.96%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [32/200] - [TRAIN] Loss: 0.5863, Accuracy: 70.89%, AUC: 0.71 [VAL] Loss: 0.5906, Accuracy: 70.05%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [33/200] - [TRAIN] Loss: 0.5861, Accuracy: 70.78%, AUC: 0.70 [VAL] Loss: 0.5933, Accuracy: 70.03%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [34/200] - [TRAIN] Loss: 0.5856, Accuracy: 70.83%, AUC: 0.70 [VAL] Loss: 0.5931, Accuracy: 70.15%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [35/200] - [TRAIN] Loss: 0.5841, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5946, Accuracy: 69.99%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [36/200] - [TRAIN] Loss: 0.5851, Accuracy: 70.90%, AUC: 0.71 [VAL] Loss: 0.5898, Accuracy: 70.27%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [37/200] - [TRAIN] Loss: 0.5840, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5897, Accuracy: 70.20%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [38/200] - [TRAIN] Loss: 0.5838, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5898, Accuracy: 70.09%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [39/200] - [TRAIN] Loss: 0.5834, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5916, Accuracy: 70.03%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [40/200] - [TRAIN] Loss: 0.5837, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5894, Accuracy: 70.17%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [41/200] - [TRAIN] Loss: 0.5829, Accuracy: 70.91%, AUC: 0.71 [VAL] Loss: 0.5873, Accuracy: 70.32%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [42/200] - [TRAIN] Loss: 0.5828, Accuracy: 70.99%, AUC: 0.71 [VAL] Loss: 0.5900, Accuracy: 70.23%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [43/200] - [TRAIN] Loss: 0.5827, Accuracy: 70.92%, AUC: 0.71 [VAL] Loss: 0.5885, Accuracy: 70.18%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [44/200] - [TRAIN] Loss: 0.5821, Accuracy: 70.95%, AUC: 0.71 [VAL] Loss: 0.5910, Accuracy: 70.23%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [45/200] - [TRAIN] Loss: 0.5825, Accuracy: 70.84%, AUC: 0.70 [VAL] Loss: 0.5906, Accuracy: 70.09%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [46/200] - [TRAIN] Loss: 0.5817, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5900, Accuracy: 70.10%, Precision: 0.72, Recall: 0.60, F1-Score: 0.66, AUC: 0.70
# Epoch [47/200] - [TRAIN] Loss: 0.5815, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5879, Accuracy: 70.36%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [48/200] - [TRAIN] Loss: 0.5811, Accuracy: 70.99%, AUC: 0.71 [VAL] Loss: 0.5893, Accuracy: 70.28%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [49/200] - [TRAIN] Loss: 0.5807, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5888, Accuracy: 70.27%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [50/200] - [TRAIN] Loss: 0.5808, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5910, Accuracy: 70.13%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [51/200] - [TRAIN] Loss: 0.5808, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5891, Accuracy: 70.25%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [52/200] - [TRAIN] Loss: 0.5806, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5912, Accuracy: 70.14%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [53/200] - [TRAIN] Loss: 0.5813, Accuracy: 70.94%, AUC: 0.71 [VAL] Loss: 0.5905, Accuracy: 70.09%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [54/200] - [TRAIN] Loss: 0.5815, Accuracy: 70.88%, AUC: 0.71 [VAL] Loss: 0.5894, Accuracy: 70.10%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [55/200] - [TRAIN] Loss: 0.5806, Accuracy: 71.09%, AUC: 0.71 [VAL] Loss: 0.5885, Accuracy: 70.28%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [56/200] - [TRAIN] Loss: 0.5814, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5904, Accuracy: 70.12%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [57/200] - [TRAIN] Loss: 0.5812, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5900, Accuracy: 70.10%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [58/200] - [TRAIN] Loss: 0.5810, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5909, Accuracy: 70.05%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [59/200] - [TRAIN] Loss: 0.5798, Accuracy: 71.06%, AUC: 0.71 [VAL] Loss: 0.5886, Accuracy: 70.13%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [60/200] - [TRAIN] Loss: 0.5807, Accuracy: 70.99%, AUC: 0.71 [VAL] Loss: 0.5906, Accuracy: 69.91%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [61/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5878, Accuracy: 70.37%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [62/200] - [TRAIN] Loss: 0.5800, Accuracy: 71.05%, AUC: 0.71 [VAL] Loss: 0.5881, Accuracy: 70.28%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [63/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5894, Accuracy: 70.03%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [64/200] - [TRAIN] Loss: 0.5815, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5897, Accuracy: 70.21%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [65/200] - [TRAIN] Loss: 0.5805, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5896, Accuracy: 70.11%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [66/200] - [TRAIN] Loss: 0.5801, Accuracy: 71.08%, AUC: 0.71 [VAL] Loss: 0.5909, Accuracy: 70.11%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [67/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.05%, AUC: 0.71 [VAL] Loss: 0.5884, Accuracy: 70.16%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [68/200] - [TRAIN] Loss: 0.5805, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5901, Accuracy: 70.01%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [69/200] - [TRAIN] Loss: 0.5817, Accuracy: 70.93%, AUC: 0.71 [VAL] Loss: 0.5879, Accuracy: 70.33%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [70/200] - [TRAIN] Loss: 0.5796, Accuracy: 71.06%, AUC: 0.71 [VAL] Loss: 0.5887, Accuracy: 70.21%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [71/200] - [TRAIN] Loss: 0.5808, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5895, Accuracy: 70.08%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [72/200] - [TRAIN] Loss: 0.5807, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5881, Accuracy: 70.29%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [73/200] - [TRAIN] Loss: 0.5810, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5874, Accuracy: 70.26%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [74/200] - [TRAIN] Loss: 0.5807, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5878, Accuracy: 70.27%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [75/200] - [TRAIN] Loss: 0.5806, Accuracy: 70.99%, AUC: 0.71 [VAL] Loss: 0.5871, Accuracy: 70.27%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [76/200] - [TRAIN] Loss: 0.5813, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5897, Accuracy: 70.10%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [77/200] - [TRAIN] Loss: 0.5807, Accuracy: 70.95%, AUC: 0.71 [VAL] Loss: 0.5884, Accuracy: 70.34%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [78/200] - [TRAIN] Loss: 0.5813, Accuracy: 70.94%, AUC: 0.71 [VAL] Loss: 0.5898, Accuracy: 70.17%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [79/200] - [TRAIN] Loss: 0.5808, Accuracy: 71.07%, AUC: 0.71 [VAL] Loss: 0.5882, Accuracy: 70.38%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [80/200] - [TRAIN] Loss: 0.5803, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5910, Accuracy: 70.08%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [81/200] - [TRAIN] Loss: 0.5808, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5885, Accuracy: 70.23%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [82/200] - [TRAIN] Loss: 0.5812, Accuracy: 70.94%, AUC: 0.71 [VAL] Loss: 0.5880, Accuracy: 70.24%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [83/200] - [TRAIN] Loss: 0.5801, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5901, Accuracy: 69.94%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [84/200] - [TRAIN] Loss: 0.5814, Accuracy: 70.95%, AUC: 0.71 [VAL] Loss: 0.5877, Accuracy: 70.23%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [85/200] - [TRAIN] Loss: 0.5806, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5873, Accuracy: 70.34%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [86/200] - [TRAIN] Loss: 0.5803, Accuracy: 71.07%, AUC: 0.71 [VAL] Loss: 0.5880, Accuracy: 70.34%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [87/200] - [TRAIN] Loss: 0.5810, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5875, Accuracy: 70.19%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [88/200] - [TRAIN] Loss: 0.5815, Accuracy: 70.91%, AUC: 0.71 [VAL] Loss: 0.5901, Accuracy: 69.99%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [89/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.07%, AUC: 0.71 [VAL] Loss: 0.5887, Accuracy: 70.17%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [90/200] - [TRAIN] Loss: 0.5813, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5879, Accuracy: 70.20%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [91/200] - [TRAIN] Loss: 0.5808, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5889, Accuracy: 69.96%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [92/200] - [TRAIN] Loss: 0.5803, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5888, Accuracy: 70.11%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [93/200] - [TRAIN] Loss: 0.5812, Accuracy: 70.93%, AUC: 0.71 [VAL] Loss: 0.5870, Accuracy: 70.49%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [94/200] - [TRAIN] Loss: 0.5806, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5892, Accuracy: 70.14%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [95/200] - [TRAIN] Loss: 0.5811, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5899, Accuracy: 70.13%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [96/200] - [TRAIN] Loss: 0.5812, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5887, Accuracy: 70.16%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [97/200] - [TRAIN] Loss: 0.5790, Accuracy: 71.13%, AUC: 0.71 [VAL] Loss: 0.5906, Accuracy: 70.27%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [98/200] - [TRAIN] Loss: 0.5808, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5889, Accuracy: 70.13%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [99/200] - [TRAIN] Loss: 0.5806, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5877, Accuracy: 70.19%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [100/200] - [TRAIN] Loss: 0.5809, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5902, Accuracy: 70.19%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [101/200] - [TRAIN] Loss: 0.5809, Accuracy: 70.99%, AUC: 0.71 [VAL] Loss: 0.5870, Accuracy: 70.28%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [102/200] - [TRAIN] Loss: 0.5810, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5892, Accuracy: 69.95%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [103/200] - [TRAIN] Loss: 0.5807, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5874, Accuracy: 70.41%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [104/200] - [TRAIN] Loss: 0.5811, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5896, Accuracy: 70.14%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [105/200] - [TRAIN] Loss: 0.5805, Accuracy: 71.05%, AUC: 0.71 [VAL] Loss: 0.5892, Accuracy: 70.20%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [106/200] - [TRAIN] Loss: 0.5800, Accuracy: 71.10%, AUC: 0.71 [VAL] Loss: 0.5888, Accuracy: 70.20%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [107/200] - [TRAIN] Loss: 0.5808, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5883, Accuracy: 70.38%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [108/200] - [TRAIN] Loss: 0.5806, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5898, Accuracy: 70.17%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [109/200] - [TRAIN] Loss: 0.5797, Accuracy: 71.13%, AUC: 0.71 [VAL] Loss: 0.5896, Accuracy: 70.26%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [110/200] - [TRAIN] Loss: 0.5807, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5905, Accuracy: 70.16%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [111/200] - [TRAIN] Loss: 0.5806, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5891, Accuracy: 70.10%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [112/200] - [TRAIN] Loss: 0.5815, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5897, Accuracy: 70.11%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [113/200] - [TRAIN] Loss: 0.5801, Accuracy: 71.08%, AUC: 0.71 [VAL] Loss: 0.5868, Accuracy: 70.29%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [114/200] - [TRAIN] Loss: 0.5810, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5902, Accuracy: 70.17%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [115/200] - [TRAIN] Loss: 0.5805, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5892, Accuracy: 70.14%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [116/200] - [TRAIN] Loss: 0.5806, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5915, Accuracy: 70.15%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [117/200] - [TRAIN] Loss: 0.5801, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5902, Accuracy: 70.04%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [118/200] - [TRAIN] Loss: 0.5796, Accuracy: 71.12%, AUC: 0.71 [VAL] Loss: 0.5883, Accuracy: 70.11%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [119/200] - [TRAIN] Loss: 0.5808, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5886, Accuracy: 70.24%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [120/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.07%, AUC: 0.71 [VAL] Loss: 0.5877, Accuracy: 70.20%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [121/200] - [TRAIN] Loss: 0.5799, Accuracy: 71.05%, AUC: 0.71 [VAL] Loss: 0.5891, Accuracy: 70.09%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [122/200] - [TRAIN] Loss: 0.5814, Accuracy: 70.94%, AUC: 0.71 [VAL] Loss: 0.5901, Accuracy: 70.01%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [123/200] - [TRAIN] Loss: 0.5812, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5866, Accuracy: 70.25%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [124/200] - [TRAIN] Loss: 0.5808, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5899, Accuracy: 69.90%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [125/200] - [TRAIN] Loss: 0.5813, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5905, Accuracy: 70.08%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [126/200] - [TRAIN] Loss: 0.5809, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5873, Accuracy: 70.38%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [127/200] - [TRAIN] Loss: 0.5817, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5902, Accuracy: 70.20%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [128/200] - [TRAIN] Loss: 0.5813, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5879, Accuracy: 70.33%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [129/200] - [TRAIN] Loss: 0.5806, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5881, Accuracy: 70.30%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [130/200] - [TRAIN] Loss: 0.5793, Accuracy: 71.13%, AUC: 0.71 [VAL] Loss: 0.5882, Accuracy: 70.35%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [131/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5870, Accuracy: 70.34%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [132/200] - [TRAIN] Loss: 0.5800, Accuracy: 71.06%, AUC: 0.71 [VAL] Loss: 0.5875, Accuracy: 70.19%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [133/200] - [TRAIN] Loss: 0.5799, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5907, Accuracy: 70.04%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [134/200] - [TRAIN] Loss: 0.5813, Accuracy: 70.95%, AUC: 0.71 [VAL] Loss: 0.5893, Accuracy: 70.03%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [135/200] - [TRAIN] Loss: 0.5805, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5910, Accuracy: 70.00%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [136/200] - [TRAIN] Loss: 0.5805, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5880, Accuracy: 70.24%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [137/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5882, Accuracy: 70.09%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [138/200] - [TRAIN] Loss: 0.5817, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5878, Accuracy: 70.37%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [139/200] - [TRAIN] Loss: 0.5813, Accuracy: 70.91%, AUC: 0.71 [VAL] Loss: 0.5880, Accuracy: 70.15%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [140/200] - [TRAIN] Loss: 0.5802, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5879, Accuracy: 70.24%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [141/200] - [TRAIN] Loss: 0.5811, Accuracy: 70.95%, AUC: 0.71 [VAL] Loss: 0.5875, Accuracy: 70.43%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [142/200] - [TRAIN] Loss: 0.5802, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5886, Accuracy: 70.41%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [143/200] - [TRAIN] Loss: 0.5799, Accuracy: 71.07%, AUC: 0.71 [VAL] Loss: 0.5910, Accuracy: 69.92%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [144/200] - [TRAIN] Loss: 0.5804, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5877, Accuracy: 70.40%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [145/200] - [TRAIN] Loss: 0.5801, Accuracy: 71.07%, AUC: 0.71 [VAL] Loss: 0.5886, Accuracy: 70.23%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [146/200] - [TRAIN] Loss: 0.5811, Accuracy: 70.90%, AUC: 0.71 [VAL] Loss: 0.5898, Accuracy: 70.16%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [147/200] - [TRAIN] Loss: 0.5807, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5881, Accuracy: 70.33%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [148/200] - [TRAIN] Loss: 0.5801, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5909, Accuracy: 70.00%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [149/200] - [TRAIN] Loss: 0.5808, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5911, Accuracy: 70.13%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [150/200] - [TRAIN] Loss: 0.5807, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5904, Accuracy: 70.16%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [151/200] - [TRAIN] Loss: 0.5808, Accuracy: 70.99%, AUC: 0.71 [VAL] Loss: 0.5883, Accuracy: 70.25%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [152/200] - [TRAIN] Loss: 0.5805, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5854, Accuracy: 70.57%, Precision: 0.72, Recall: 0.62, F1-Score: 0.67, AUC: 0.70
# Epoch [153/200] - [TRAIN] Loss: 0.5800, Accuracy: 71.08%, AUC: 0.71 [VAL] Loss: 0.5900, Accuracy: 70.22%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [154/200] - [TRAIN] Loss: 0.5802, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5873, Accuracy: 70.28%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [155/200] - [TRAIN] Loss: 0.5808, Accuracy: 70.99%, AUC: 0.71 [VAL] Loss: 0.5902, Accuracy: 70.05%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [156/200] - [TRAIN] Loss: 0.5802, Accuracy: 71.05%, AUC: 0.71 [VAL] Loss: 0.5878, Accuracy: 70.11%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [157/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5903, Accuracy: 70.00%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [158/200] - [TRAIN] Loss: 0.5811, Accuracy: 70.92%, AUC: 0.71 [VAL] Loss: 0.5920, Accuracy: 70.11%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [159/200] - [TRAIN] Loss: 0.5806, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5869, Accuracy: 70.05%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [160/200] - [TRAIN] Loss: 0.5809, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5892, Accuracy: 70.11%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [161/200] - [TRAIN] Loss: 0.5803, Accuracy: 71.06%, AUC: 0.71 [VAL] Loss: 0.5905, Accuracy: 70.17%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [162/200] - [TRAIN] Loss: 0.5810, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5919, Accuracy: 69.93%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [163/200] - [TRAIN] Loss: 0.5803, Accuracy: 71.06%, AUC: 0.71 [VAL] Loss: 0.5871, Accuracy: 70.31%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [164/200] - [TRAIN] Loss: 0.5791, Accuracy: 71.13%, AUC: 0.71 [VAL] Loss: 0.5896, Accuracy: 70.18%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [165/200] - [TRAIN] Loss: 0.5803, Accuracy: 71.12%, AUC: 0.71 [VAL] Loss: 0.5917, Accuracy: 70.16%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [166/200] - [TRAIN] Loss: 0.5811, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5905, Accuracy: 70.16%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [167/200] - [TRAIN] Loss: 0.5797, Accuracy: 71.07%, AUC: 0.71 [VAL] Loss: 0.5911, Accuracy: 69.98%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [168/200] - [TRAIN] Loss: 0.5803, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5881, Accuracy: 70.33%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [169/200] - [TRAIN] Loss: 0.5803, Accuracy: 71.05%, AUC: 0.71 [VAL] Loss: 0.5899, Accuracy: 70.35%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [170/200] - [TRAIN] Loss: 0.5809, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5866, Accuracy: 70.33%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [171/200] - [TRAIN] Loss: 0.5810, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5882, Accuracy: 70.30%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [172/200] - [TRAIN] Loss: 0.5805, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5901, Accuracy: 70.14%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [173/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5884, Accuracy: 70.32%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [174/200] - [TRAIN] Loss: 0.5817, Accuracy: 70.87%, AUC: 0.71 [VAL] Loss: 0.5893, Accuracy: 70.24%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [175/200] - [TRAIN] Loss: 0.5811, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5892, Accuracy: 70.09%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [176/200] - [TRAIN] Loss: 0.5810, Accuracy: 70.95%, AUC: 0.71 [VAL] Loss: 0.5891, Accuracy: 70.32%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [177/200] - [TRAIN] Loss: 0.5802, Accuracy: 71.05%, AUC: 0.71 [VAL] Loss: 0.5907, Accuracy: 70.09%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [178/200] - [TRAIN] Loss: 0.5819, Accuracy: 70.88%, AUC: 0.71 [VAL] Loss: 0.5887, Accuracy: 70.17%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [179/200] - [TRAIN] Loss: 0.5812, Accuracy: 70.94%, AUC: 0.71 [VAL] Loss: 0.5912, Accuracy: 69.94%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [180/200] - [TRAIN] Loss: 0.5808, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5900, Accuracy: 70.21%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [181/200] - [TRAIN] Loss: 0.5808, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5929, Accuracy: 69.80%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [182/200] - [TRAIN] Loss: 0.5812, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5901, Accuracy: 70.02%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [183/200] - [TRAIN] Loss: 0.5803, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5887, Accuracy: 70.17%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [184/200] - [TRAIN] Loss: 0.5798, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5882, Accuracy: 70.22%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [185/200] - [TRAIN] Loss: 0.5812, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5892, Accuracy: 70.22%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [186/200] - [TRAIN] Loss: 0.5809, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5894, Accuracy: 70.28%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [187/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5895, Accuracy: 70.22%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [188/200] - [TRAIN] Loss: 0.5803, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5886, Accuracy: 70.06%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [189/200] - [TRAIN] Loss: 0.5807, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.5898, Accuracy: 70.17%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [190/200] - [TRAIN] Loss: 0.5804, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5915, Accuracy: 69.80%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [191/200] - [TRAIN] Loss: 0.5806, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5897, Accuracy: 70.15%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [192/200] - [TRAIN] Loss: 0.5807, Accuracy: 71.05%, AUC: 0.71 [VAL] Loss: 0.5882, Accuracy: 70.18%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [193/200] - [TRAIN] Loss: 0.5802, Accuracy: 71.07%, AUC: 0.71 [VAL] Loss: 0.5875, Accuracy: 70.30%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [194/200] - [TRAIN] Loss: 0.5813, Accuracy: 70.92%, AUC: 0.71 [VAL] Loss: 0.5877, Accuracy: 70.39%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [195/200] - [TRAIN] Loss: 0.5813, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.5895, Accuracy: 70.14%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [196/200] - [TRAIN] Loss: 0.5807, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5889, Accuracy: 70.22%, Precision: 0.71, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [197/200] - [TRAIN] Loss: 0.5812, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5902, Accuracy: 70.16%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [198/200] - [TRAIN] Loss: 0.5800, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5871, Accuracy: 70.36%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [199/200] - [TRAIN] Loss: 0.5800, Accuracy: 71.06%, AUC: 0.71 [VAL] Loss: 0.5896, Accuracy: 70.09%, Precision: 0.71, Recall: 0.62, F1-Score: 0.66, AUC: 0.70
# Epoch [200/200] - [TRAIN] Loss: 0.5808, Accuracy: 71.03%, AUC: 0.71 [VAL] Loss: 0.5886, Accuracy: 70.34%, Precision: 0.72, Recall: 0.62, F1-Score: 0.66, AUC: 0.70

# %%
# Plot metrics
my_util.plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies, NUM_ITEMS, IMAGE_FILE)

# %% [markdown]
# ## Testing

# %%
# Predict on test set
test_predictions = []
test_true_labels = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, _, _ = model(X_batch.to(dtype=torch.float32).to(device))
        
        predictions = (outputs.squeeze(1) >= 0.5).long()
        test_true_labels.extend(y_batch.cpu().numpy())
        test_predictions.extend(predictions.cpu().numpy())

# %%
# Evaluation metrics
# Precision, Recall, F1-Score
precision, recall, f1_score, _ = precision_recall_fscore_support(
    test_true_labels, 
    test_predictions, 
    average='binary'  # Use 'macro' for multi-class
)

test_acc_score = accuracy_score(test_true_labels, test_predictions) * 100
test_auc_score = roc_auc_score(test_true_labels, test_predictions)
cr = classification_report(test_true_labels, test_predictions)
cm = confusion_matrix(test_true_labels, test_predictions)

# %%
test_output = f"""Accuracy Score on test set: {test_acc_score:.2f} %
AUC Score on test set: {test_auc_score:.2f}
Precision: {precision:.4f}
Recall: {recall:.4f}
F1-Score: {f1_score:.4f}

Detailed Classification Report:
{cr}

Confusion Matrix:
{cm}
"""

print(test_output)
# Out:
# Accuracy Score on test set: 70.61 %
# AUC Score on test set: 0.70
# Precision: 0.7181
# Recall: 0.6241
# F1-Score: 0.6678
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74     52665
#            1       0.72      0.62      0.67     47335
#
#     accuracy                           0.71    100000
#    macro avg       0.71      0.70      0.70    100000
# weighted avg       0.71      0.71      0.70    100000
#
#
# Confusion Matrix:
# [[41070 11595]
#  [17793 29542]]

# %%
# Save the test output to text file
with open(TEST_FILE, 'w', newline = '') as text_file:
    text_file.write(test_output)

# %% [markdown]
# # Saving all metrics

# %%
# Training metrics
experiment_results = {
    'train_loss'    : train_losses,
    'train_accuracy': train_accuracies,
    'train_auc'     : train_aucs,
    'val_loss'      : val_losses,
    'val_accuracy'  : val_accuracies,
    'val_auc'       : val_aucs
}

experiment_pl = pl.DataFrame(experiment_results)
experiment_pl.write_csv(TRAINING_FILE)

# %%
# Test output
test_results = {
    'test_acc'    : round(test_acc_score, 4),
    'test_auc'    : round(test_auc_score, 4)
}

test_pl = pl.DataFrame(test_results)
test_pl.write_csv(TEST_RESULT_FILE)

# %%
# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(test_true_labels, test_predictions) 
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC for HepG2 Ranking')
plt.legend()

plt.savefig(ROC_FILE)

plt.show()

# %%
# Plot the confusion matrix
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm)
fig, ax = plt.subplots(figsize=(10, 8))
cm_display.plot(ax=ax)
plt.savefig(CM_FILE)
