# %%
import os
import random
from datetime import datetime

import pandas as pd
import polars as pl
import numpy as np

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import Dataset, DataLoader, TensorDataset

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve, auc, precision_recall_fscore_support, confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Declare  variables, working directory and dataset directory
MODE = 'reduced_features_rp'
NUM_EPOCHS = 100
START_EPOCH = 0
NUM_ITEMS = 100_000
BATCH_SIZE = 128
DROPOUT_RATE = 0.5
L1_lambda = 0.005
L2_lambda = 0.001

WORKING_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank'
DATASET_DIR = '/group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/dataset'

MODEL_MODE = "dol1l2" # regular (reg), dropout (do), dropout + l1l2 (dol1l2)
PREFIX = f"{MODEL_MODE}-leakyrelu-complex-lrscheduler-{DROPOUT_RATE}"
SUFFIX = f"{NUM_ITEMS}-{NUM_EPOCHS}-{BATCH_SIZE}-{L1_lambda}-{L2_lambda}"

CHECKPOINT_NAME = os.path.join(WORKING_DIR, 'output', 'model', MODE, f'{PREFIX}-checkpoint-{SUFFIX}.pt')

INPUT_SIZE = 200

print(CHECKPOINT_NAME)
# Out:
# /group/pmc021/amunif/epi-thesis/workflow/09_Learning_to_Rank/output/model/reduced_features_rp/dol1l2-leakyrelu-complex-lrscheduler-0.5-checkpoint-100000-100-128-0.005-0.001.pt

# %%
def get_device():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    if device.type == "cuda":
        print(f"Current CUDA device: {torch.cuda.current_device()}")
        print(f"CUDA device name: {torch.cuda.get_device_name(0)}")

    return device

# %%
device = get_device()
# Out:
# Using device: cuda
# Current CUDA device: 0
# CUDA device name: Tesla P100-SXM2-16GB

# %%
class HepG2Dataset(Dataset):
    def __init__(self, total_samples, features, indexes):
        self.total_samples = total_samples
        self.features = features
        self.indexes = indexes

    def __len__(self):
        return self.total_samples

    def __getitem__(self, idx):
        r1 = random.choice(self.indexes)
        r2 = random.choice(self.indexes)
        
        feature_1 = self.features[r1, 2]
        feature_2 = self.features[r2, 2]
        feature = np.concatenate((feature_1, feature_2), axis=0)
        
        val_1 = self.features[r1, 3]
        val_2 = self.features[r2, 3]
        
        y = 1 if val_1 > val_2 else 0
        
        return feature, y

# %%
class BinaryClassifier(nn.Module):
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1):
        super(BinaryClassifier, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(input_size, hidden1_size),
            nn.ReLU(),
            nn.Linear(hidden1_size, hidden2_size),
            nn.ReLU(),
            nn.Linear(hidden2_size, output_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        # x = x.squeeze(1)
        return self.network(x)

    def predict(self, x):
        with torch.no_grad():
            outputs = self.forward(x)
            return (outputs >= 0.5).long()

# %%
class BinaryClassifierDropOut(nn.Module):
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1, dropout_rate=0.2):
        super(BinaryClassifierDropOut, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(input_size, 128),
            # nn.ReLU(),
            nn.LeakyReLU(0.1),
            nn.Dropout(p=dropout_rate),
            
            nn.Linear(128, 64),
            # nn.ReLU(),
            nn.LeakyReLU(0.1),
            nn.Dropout(p=dropout_rate),

            nn.Linear(64, 32),
            # nn.ReLU(),
            nn.LeakyReLU(0.1),
            nn.Dropout(p=dropout_rate),
            
            nn.Linear(32, output_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        # x = x.squeeze(1)
        return self.network(x)

    def predict(self, x):
        with torch.no_grad():
            outputs = self.forward(x)
            return (outputs >= 0.5).long()

# %%
class BinaryClassifierDropOutL1L2(nn.Module):
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1, dropout_rate=0.2, l1_lambda=0.001, l2_lambda=0.001):
        super(BinaryClassifierDropOutL1L2, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(input_size, 128),
            # nn.ReLU(),
            nn.LeakyReLU(0.1),
            nn.Dropout(p=dropout_rate),
            
            nn.Linear(128, 64),
            # nn.ReLU(),
            nn.LeakyReLU(0.1),
            nn.Dropout(p=dropout_rate),

            nn.Linear(64, 32),
            # nn.ReLU(),
            nn.LeakyReLU(0.1),
            nn.Dropout(p=dropout_rate),
            
            nn.Linear(32, output_size),
            nn.Sigmoid()
        )

        self.l1_lambda = l1_lambda
        self.l2_lambda = l2_lambda

    def forward(self, x):
        # x = x.squeeze(1)
        outputs = self.network(x)
        l1_reg = torch.tensor(0., requires_grad=True)
        l2_reg = torch.tensor(0., requires_grad=True)

        for name, param in self.named_parameters():
            if 'weight' in name:
                l1_reg = l1_reg + torch.linalg.norm(param, 1)
                l2_reg = l2_reg + torch.linalg.norm(param, 2)

        return outputs, self.l1_lambda * l1_reg, self.l2_lambda * l2_reg

    def predict(self, x):
        with torch.no_grad():
            outputs, _, _ = self.forward(x)
            return (outputs >= 0.5).long()

# %%
def plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies, num_items):
    epochs = range(1, len(train_losses) + 1)
    
    plt.figure(figsize=(14, 6))
    
    # Plot for training and validation Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, 'blue', label='Training Loss')
    plt.plot(epochs, val_losses, 'orange', label='Validation Loss')
    plt.title(f'Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim(0.4, 0.8)
    plt.legend()
    plt.grid(True)
    
    # Plot for training and validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, 'blue', label='Training Accuracy')
    plt.plot(epochs, val_accuracies, 'orange', label='Validation Accuracy')
    plt.title(f'Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.ylim(50, 90)
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()

    img_name = f"{PREFIX}-ranking-{SUFFIX}.png"
    plt.savefig(os.path.join(WORKING_DIR, 'output', 'img', 'train', MODE, img_name))
    
    plt.show()

# %%
# Load dataset
all_features = pl.read_parquet(os.path.join(DATASET_DIR, 'features', f'{MODE}.parquet'))
all_features
# Out:
# shape: (22_154, 4)
# ┌───────┬─────────────┬───────────────────────────────┬───────────┐
# │ index ┆ gene_id     ┆ reduced_features              ┆ value_1   │
# │ ---   ┆ ---         ┆ ---                           ┆ ---       │
# │ u32   ┆ str         ┆ list[f64]                     ┆ f64       │
# ╞═══════╪═════════════╪═══════════════════════════════╪═══════════╡
# │ 0     ┆ XLOC_000001 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 1     ┆ XLOC_000003 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 2     ┆ XLOC_000006 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0888452 │
# │ 3     ┆ XLOC_000007 ┆ [0.0, 0.0, … 0.0]             ┆ 4.04743   │
# │ 4     ┆ XLOC_000008 ┆ [5.717444, -11.321019, … 0.0] ┆ 26.7934   │
# │ …     ┆ …           ┆ …                             ┆ …         │
# │ 22149 ┆ XLOC_030009 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 22150 ┆ XLOC_030012 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 22151 ┆ XLOC_030014 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 22152 ┆ XLOC_030017 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# │ 22153 ┆ XLOC_030018 ┆ [0.0, 0.0, … 0.0]             ┆ 0.0       │
# └───────┴─────────────┴───────────────────────────────┴───────────┘

# %%
# Convert to numpy array
all_features_np = all_features.to_numpy()

# %%
# Split train, test, validation by index
data_indices = np.arange(len(all_features_np))
print(data_indices)
# Out:
# [    0     1     2 ... 22151 22152 22153]

# %%
# First split: 80% train, 20% temporary (for test + validation)
train_idx, temp_idx = train_test_split(
    data_indices, 
    test_size=0.2, 
    random_state=42  # For reproducibility
)

# %%
# Second split: Split temp_idx into 50% test and 50% validation
val_idx, test_idx = train_test_split(
    temp_idx, 
    test_size=0.5, 
    random_state=42  # Same random_state for consistency
)

# %%
print(train_idx)
print(val_idx)
print(test_idx)
# Out:
# [12829 12333  8225 ...  5390   860 15795]
# [13202 15153  3113 ...  1158  6603 15289]
# [17261  8344  1396 ...  7985   482 16493]

# %%
# Result: train_idx (80%), test_idx (10%), val_idx (10%)
print(f"Train indices: {len(train_idx)}")
print(f"Test indices: {len(test_idx)}")
print(f"Validation indices: {len(val_idx)}")
# Out:
# Train indices: 17723
# Test indices: 2216
# Validation indices: 2215

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Training

# %%
# Define the dataset
train_dataset = HepG2Dataset(int(0.8 * NUM_ITEMS), all_features_np, train_idx)
val_dataset = HepG2Dataset(int(0.1 * NUM_ITEMS), all_features_np, val_idx)
test_dataset = HepG2Dataset(int(0.1 * NUM_ITEMS), all_features_np, test_idx)

# %%
print(len(train_dataset))
print(len(val_dataset))
print(len(test_dataset))
# Out:
# 80000
# 10000
# 10000

# %%
# Define the dataloader
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)

# %%
# Initialize model
if MODEL_MODE == "reg":
    model = BinaryClassifier(input_size=INPUT_SIZE).to(device)
elif MODEL_MODE == "do":
    model = BinaryClassifierDropOut(input_size=INPUT_SIZE, dropout_rate=DROPOUT_RATE).to(device)
elif MODEL_MODE == "dol1l2":
    model = BinaryClassifierDropOutL1L2(input_size=INPUT_SIZE, dropout_rate=DROPOUT_RATE, l1_lambda=L1_lambda, l2_lambda=L2_lambda).to(device)

# Define loss function for binary classification
criterion = nn.BCELoss()  # Binary Cross Entropy Loss

# Training loop example
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Define learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

# %%
print(model)
# Out:
# BinaryClassifierDropOutL1L2(
#   (network): Sequential(
#     (0): Linear(in_features=200, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=128, out_features=64, bias=True)
#     (4): LeakyReLU(negative_slope=0.1)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=64, out_features=32, bias=True)
#     (7): LeakyReLU(negative_slope=0.1)
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Linear(in_features=32, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )

# %%
# Arrays for saving the performance metric
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
train_aucs, val_aucs = [], []
val_precisions = []
val_recalls = []
val_f1_scores = []

# %%
# Check if the checkpoint exists
if os.path.exists(CHECKPOINT_NAME):
    checkpoint = torch.load(CHECKPOINT_NAME)
    
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler'])
    START_EPOCH = checkpoint['epoch'] + 1
    train_losses = checkpoint['train_losses']
    val_losses = checkpoint['val_losses']
    train_accuracies = checkpoint['train_accuracies']
    val_accuracies = checkpoint['val_accuracies']
    train_aucs = checkpoint['train_aucs']
    val_aucs = checkpoint['val_aucs']
    val_precisions = checkpoint['val_precisions']
    val_recalls = checkpoint['val_recalls']
    val_f1_scores = checkpoint['val_f1_scores']

    print(f"{CHECKPOINT_NAME} exists. Resuming training from epoch {START_EPOCH}.")
else:
    START_EPOCH = 0

# %%
# Training loop
for epoch in range(START_EPOCH, NUM_EPOCHS):
    model.train()

    train_loss = 0
    train_correct = 0
    train_total = 0
    train_true_labels = []
    train_predicted_labels = []

    # Training phase
    for X_batch, y_batch in train_loader:

        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
            loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Calculate accuracy
        predictions = (outputs.squeeze(1) >= 0.5).long()

        train_loss += loss.item()
        train_correct += (predictions == y_batch.to(device)).sum().item()
        train_total += y_batch.size(0)
        
        train_true_labels.extend(y_batch.cpu().numpy())
        train_predicted_labels.extend(predictions.cpu().numpy())
        
    # Adjust learning rate
    scheduler.step()
    
    avg_train_loss = train_loss / len(train_loader)
    train_accuracy = 100 * train_correct / train_total
    train_auc_score = roc_auc_score(train_true_labels, train_predicted_labels)

    train_losses.append(round(avg_train_loss, 4))
    train_accuracies.append(round(train_accuracy, 2))
    train_aucs.append(round(train_auc_score, 2))

    # Validation phase
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    val_metric = 0
    val_true_labels = []
    val_predicted_labels = []

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            
            if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
                outputs = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device))
            elif MODEL_MODE == "dol1l2":
                outputs, l1_reg, l2_reg = model(X_batch.to(dtype=torch.float32).to(device))
                loss = criterion(outputs.squeeze(1), y_batch.to(dtype=torch.float32).to(device)) + l1_reg + l2_reg
            
            predictions = (outputs.squeeze(1) >= 0.5).long()
            
            val_loss += loss.item()
            val_correct += (predictions == y_batch.to(dtype=torch.float32).to(device)).sum().item()
            val_total += y_batch.size(0)
            val_true_labels.extend(y_batch.cpu().numpy())
            val_predicted_labels.extend(predictions.cpu().numpy())
            
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_metric = val_correct / len(val_loader)

        # Calculate precision, recall, and F1-score
        precision, recall, f1_score, _ = precision_recall_fscore_support(
            val_true_labels, 
            val_predicted_labels, 
            average='binary'  # Use macro average for multi-class classification
        )

        val_true_labels = np.array(val_true_labels)
        val_predicted_labels = np.array(val_predicted_labels)
        val_auc_score = roc_auc_score(val_true_labels, val_predicted_labels)

        val_losses.append(round(avg_val_loss, 4))
        val_accuracies.append(round(val_accuracy, 2))
        val_aucs.append(round(val_auc_score, 2))
        val_precisions.append(round(precision, 2))
        val_recalls.append(round(recall, 2))
        val_f1_scores.append(round(f1_score, 2))
    

    print(f'Epoch [{epoch+1}/{NUM_EPOCHS}] - '
          f'[TRAIN] Loss: {avg_train_loss:.4f}, Accuracy: {train_accuracy:.2f}%, AUC: {train_auc_score:.2f} '
          f'[VAL] Loss: {avg_val_loss:.4f}, Accuracy: {val_accuracy:.2f}%, '
          f'Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1_score:.2f}, '
          f'AUC: {val_auc_score:.2f}')
    
    # Save the model
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler': scheduler.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accuracies': train_accuracies,
        'val_accuracies': val_accuracies,
        'train_aucs': train_aucs,
        'val_aucs': val_aucs,
        'val_precisions': val_precisions,
        'val_recalls': val_recalls,
        'val_f1_scores': val_f1_scores,
    }, CHECKPOINT_NAME)
# Out:
# Epoch [1/100] - [TRAIN] Loss: 0.6472, Accuracy: 69.11%, AUC: 0.69 [VAL] Loss: 0.6281, Accuracy: 69.68%, Precision: 0.68, Recall: 0.66, F1-Score: 0.67, AUC: 0.69
# Epoch [2/100] - [TRAIN] Loss: 0.6238, Accuracy: 70.39%, AUC: 0.70 [VAL] Loss: 0.6143, Accuracy: 70.25%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [3/100] - [TRAIN] Loss: 0.6157, Accuracy: 70.39%, AUC: 0.70 [VAL] Loss: 0.6200, Accuracy: 69.88%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [4/100] - [TRAIN] Loss: 0.6091, Accuracy: 70.75%, AUC: 0.71 [VAL] Loss: 0.6042, Accuracy: 70.11%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [5/100] - [TRAIN] Loss: 0.6083, Accuracy: 70.70%, AUC: 0.71 [VAL] Loss: 0.6048, Accuracy: 70.23%, Precision: 0.70, Recall: 0.67, F1-Score: 0.69, AUC: 0.70
# Epoch [6/100] - [TRAIN] Loss: 0.6084, Accuracy: 70.64%, AUC: 0.70 [VAL] Loss: 0.6094, Accuracy: 69.86%, Precision: 0.67, Recall: 0.71, F1-Score: 0.69, AUC: 0.70
# Epoch [7/100] - [TRAIN] Loss: 0.6063, Accuracy: 70.67%, AUC: 0.71 [VAL] Loss: 0.6070, Accuracy: 69.74%, Precision: 0.67, Recall: 0.69, F1-Score: 0.68, AUC: 0.70
# Epoch [8/100] - [TRAIN] Loss: 0.6071, Accuracy: 70.36%, AUC: 0.70 [VAL] Loss: 0.6106, Accuracy: 69.05%, Precision: 0.67, Recall: 0.70, F1-Score: 0.69, AUC: 0.69
# Epoch [9/100] - [TRAIN] Loss: 0.6063, Accuracy: 70.56%, AUC: 0.70 [VAL] Loss: 0.6023, Accuracy: 70.75%, Precision: 0.71, Recall: 0.63, F1-Score: 0.67, AUC: 0.70
# Epoch [10/100] - [TRAIN] Loss: 0.6080, Accuracy: 70.50%, AUC: 0.70 [VAL] Loss: 0.6082, Accuracy: 69.64%, Precision: 0.70, Recall: 0.61, F1-Score: 0.66, AUC: 0.69
# Epoch [11/100] - [TRAIN] Loss: 0.6016, Accuracy: 71.12%, AUC: 0.71 [VAL] Loss: 0.6086, Accuracy: 70.05%, Precision: 0.67, Recall: 0.72, F1-Score: 0.70, AUC: 0.70
# Epoch [12/100] - [TRAIN] Loss: 0.6054, Accuracy: 70.68%, AUC: 0.71 [VAL] Loss: 0.6108, Accuracy: 69.15%, Precision: 0.68, Recall: 0.70, F1-Score: 0.69, AUC: 0.69
# Epoch [13/100] - [TRAIN] Loss: 0.6047, Accuracy: 70.58%, AUC: 0.70 [VAL] Loss: 0.6117, Accuracy: 69.48%, Precision: 0.70, Recall: 0.61, F1-Score: 0.65, AUC: 0.69
# Epoch [14/100] - [TRAIN] Loss: 0.6023, Accuracy: 70.98%, AUC: 0.71 [VAL] Loss: 0.6094, Accuracy: 69.89%, Precision: 0.68, Recall: 0.69, F1-Score: 0.69, AUC: 0.70
# Epoch [15/100] - [TRAIN] Loss: 0.6056, Accuracy: 70.62%, AUC: 0.70 [VAL] Loss: 0.6062, Accuracy: 70.60%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [16/100] - [TRAIN] Loss: 0.6032, Accuracy: 70.88%, AUC: 0.71 [VAL] Loss: 0.6084, Accuracy: 69.76%, Precision: 0.68, Recall: 0.67, F1-Score: 0.67, AUC: 0.70
# Epoch [17/100] - [TRAIN] Loss: 0.6047, Accuracy: 70.67%, AUC: 0.71 [VAL] Loss: 0.6036, Accuracy: 69.96%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [18/100] - [TRAIN] Loss: 0.6038, Accuracy: 70.88%, AUC: 0.71 [VAL] Loss: 0.6032, Accuracy: 70.28%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [19/100] - [TRAIN] Loss: 0.6068, Accuracy: 70.68%, AUC: 0.71 [VAL] Loss: 0.6122, Accuracy: 69.63%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.69
# Epoch [20/100] - [TRAIN] Loss: 0.6035, Accuracy: 70.65%, AUC: 0.71 [VAL] Loss: 0.6097, Accuracy: 69.73%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.69
# Epoch [21/100] - [TRAIN] Loss: 0.5978, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5963, Accuracy: 70.98%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.71
# Epoch [22/100] - [TRAIN] Loss: 0.5978, Accuracy: 70.82%, AUC: 0.71 [VAL] Loss: 0.6068, Accuracy: 69.93%, Precision: 0.68, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [23/100] - [TRAIN] Loss: 0.5933, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.6041, Accuracy: 69.86%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [24/100] - [TRAIN] Loss: 0.5952, Accuracy: 70.95%, AUC: 0.71 [VAL] Loss: 0.5931, Accuracy: 69.80%, Precision: 0.71, Recall: 0.63, F1-Score: 0.66, AUC: 0.69
# Epoch [25/100] - [TRAIN] Loss: 0.5948, Accuracy: 70.79%, AUC: 0.71 [VAL] Loss: 0.5861, Accuracy: 70.71%, Precision: 0.70, Recall: 0.68, F1-Score: 0.69, AUC: 0.71
# Epoch [26/100] - [TRAIN] Loss: 0.5949, Accuracy: 70.89%, AUC: 0.71 [VAL] Loss: 0.5994, Accuracy: 70.17%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [27/100] - [TRAIN] Loss: 0.5932, Accuracy: 70.91%, AUC: 0.71 [VAL] Loss: 0.6068, Accuracy: 69.47%, Precision: 0.67, Recall: 0.70, F1-Score: 0.68, AUC: 0.69
# Epoch [28/100] - [TRAIN] Loss: 0.5900, Accuracy: 71.27%, AUC: 0.71 [VAL] Loss: 0.5995, Accuracy: 70.07%, Precision: 0.70, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [29/100] - [TRAIN] Loss: 0.5949, Accuracy: 70.81%, AUC: 0.71 [VAL] Loss: 0.5989, Accuracy: 69.89%, Precision: 0.69, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [30/100] - [TRAIN] Loss: 0.5933, Accuracy: 70.82%, AUC: 0.71 [VAL] Loss: 0.6006, Accuracy: 70.26%, Precision: 0.70, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [31/100] - [TRAIN] Loss: 0.5924, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5918, Accuracy: 70.56%, Precision: 0.70, Recall: 0.68, F1-Score: 0.69, AUC: 0.70
# Epoch [32/100] - [TRAIN] Loss: 0.5919, Accuracy: 71.01%, AUC: 0.71 [VAL] Loss: 0.5923, Accuracy: 69.84%, Precision: 0.68, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [33/100] - [TRAIN] Loss: 0.5910, Accuracy: 71.11%, AUC: 0.71 [VAL] Loss: 0.5943, Accuracy: 70.46%, Precision: 0.68, Recall: 0.72, F1-Score: 0.70, AUC: 0.71
# Epoch [34/100] - [TRAIN] Loss: 0.5895, Accuracy: 71.14%, AUC: 0.71 [VAL] Loss: 0.5949, Accuracy: 70.36%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [35/100] - [TRAIN] Loss: 0.5933, Accuracy: 70.71%, AUC: 0.71 [VAL] Loss: 0.5963, Accuracy: 70.40%, Precision: 0.68, Recall: 0.72, F1-Score: 0.70, AUC: 0.70
# Epoch [36/100] - [TRAIN] Loss: 0.5896, Accuracy: 71.00%, AUC: 0.71 [VAL] Loss: 0.6010, Accuracy: 70.25%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [37/100] - [TRAIN] Loss: 0.5902, Accuracy: 71.17%, AUC: 0.71 [VAL] Loss: 0.5972, Accuracy: 69.95%, Precision: 0.69, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [38/100] - [TRAIN] Loss: 0.5946, Accuracy: 70.56%, AUC: 0.70 [VAL] Loss: 0.5977, Accuracy: 70.67%, Precision: 0.70, Recall: 0.67, F1-Score: 0.68, AUC: 0.71
# Epoch [39/100] - [TRAIN] Loss: 0.5914, Accuracy: 71.05%, AUC: 0.71 [VAL] Loss: 0.5871, Accuracy: 70.38%, Precision: 0.70, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [40/100] - [TRAIN] Loss: 0.5893, Accuracy: 71.14%, AUC: 0.71 [VAL] Loss: 0.5910, Accuracy: 70.73%, Precision: 0.68, Recall: 0.71, F1-Score: 0.69, AUC: 0.71
# Epoch [41/100] - [TRAIN] Loss: 0.5918, Accuracy: 71.02%, AUC: 0.71 [VAL] Loss: 0.5934, Accuracy: 70.59%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [42/100] - [TRAIN] Loss: 0.5891, Accuracy: 70.91%, AUC: 0.71 [VAL] Loss: 0.5856, Accuracy: 71.26%, Precision: 0.70, Recall: 0.67, F1-Score: 0.68, AUC: 0.71
# Epoch [43/100] - [TRAIN] Loss: 0.5826, Accuracy: 71.50%, AUC: 0.71 [VAL] Loss: 0.5942, Accuracy: 70.19%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [44/100] - [TRAIN] Loss: 0.5852, Accuracy: 71.11%, AUC: 0.71 [VAL] Loss: 0.5953, Accuracy: 70.14%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [45/100] - [TRAIN] Loss: 0.5851, Accuracy: 71.22%, AUC: 0.71 [VAL] Loss: 0.5955, Accuracy: 70.22%, Precision: 0.69, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [46/100] - [TRAIN] Loss: 0.5881, Accuracy: 70.93%, AUC: 0.71 [VAL] Loss: 0.5885, Accuracy: 70.68%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [47/100] - [TRAIN] Loss: 0.5841, Accuracy: 71.30%, AUC: 0.71 [VAL] Loss: 0.5788, Accuracy: 71.43%, Precision: 0.70, Recall: 0.67, F1-Score: 0.69, AUC: 0.71
# Epoch [48/100] - [TRAIN] Loss: 0.5857, Accuracy: 70.86%, AUC: 0.71 [VAL] Loss: 0.5915, Accuracy: 70.67%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [49/100] - [TRAIN] Loss: 0.5877, Accuracy: 70.80%, AUC: 0.71 [VAL] Loss: 0.5969, Accuracy: 69.51%, Precision: 0.71, Recall: 0.61, F1-Score: 0.65, AUC: 0.69
# Epoch [50/100] - [TRAIN] Loss: 0.5860, Accuracy: 71.24%, AUC: 0.71 [VAL] Loss: 0.5931, Accuracy: 70.24%, Precision: 0.69, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [51/100] - [TRAIN] Loss: 0.5854, Accuracy: 71.18%, AUC: 0.71 [VAL] Loss: 0.5925, Accuracy: 70.26%, Precision: 0.69, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [52/100] - [TRAIN] Loss: 0.5853, Accuracy: 71.16%, AUC: 0.71 [VAL] Loss: 0.5963, Accuracy: 69.36%, Precision: 0.68, Recall: 0.67, F1-Score: 0.68, AUC: 0.69
# Epoch [53/100] - [TRAIN] Loss: 0.5848, Accuracy: 70.89%, AUC: 0.71 [VAL] Loss: 0.5980, Accuracy: 69.61%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.69
# Epoch [54/100] - [TRAIN] Loss: 0.5853, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5946, Accuracy: 69.81%, Precision: 0.69, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [55/100] - [TRAIN] Loss: 0.5847, Accuracy: 71.11%, AUC: 0.71 [VAL] Loss: 0.5926, Accuracy: 70.12%, Precision: 0.68, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [56/100] - [TRAIN] Loss: 0.5850, Accuracy: 70.92%, AUC: 0.71 [VAL] Loss: 0.5914, Accuracy: 70.09%, Precision: 0.69, Recall: 0.64, F1-Score: 0.66, AUC: 0.70
# Epoch [57/100] - [TRAIN] Loss: 0.5825, Accuracy: 71.39%, AUC: 0.71 [VAL] Loss: 0.5863, Accuracy: 70.77%, Precision: 0.70, Recall: 0.67, F1-Score: 0.68, AUC: 0.71
# Epoch [58/100] - [TRAIN] Loss: 0.5826, Accuracy: 70.96%, AUC: 0.71 [VAL] Loss: 0.5950, Accuracy: 69.91%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [59/100] - [TRAIN] Loss: 0.5833, Accuracy: 71.36%, AUC: 0.71 [VAL] Loss: 0.5985, Accuracy: 69.64%, Precision: 0.68, Recall: 0.67, F1-Score: 0.67, AUC: 0.70
# Epoch [60/100] - [TRAIN] Loss: 0.5856, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5879, Accuracy: 70.01%, Precision: 0.68, Recall: 0.70, F1-Score: 0.69, AUC: 0.70
# Epoch [61/100] - [TRAIN] Loss: 0.5813, Accuracy: 71.34%, AUC: 0.71 [VAL] Loss: 0.5898, Accuracy: 70.80%, Precision: 0.70, Recall: 0.68, F1-Score: 0.69, AUC: 0.71
# Epoch [62/100] - [TRAIN] Loss: 0.5844, Accuracy: 71.13%, AUC: 0.71 [VAL] Loss: 0.5743, Accuracy: 71.73%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [63/100] - [TRAIN] Loss: 0.5849, Accuracy: 70.86%, AUC: 0.71 [VAL] Loss: 0.5821, Accuracy: 71.58%, Precision: 0.72, Recall: 0.66, F1-Score: 0.69, AUC: 0.71
# Epoch [64/100] - [TRAIN] Loss: 0.5826, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5849, Accuracy: 70.75%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [65/100] - [TRAIN] Loss: 0.5810, Accuracy: 71.15%, AUC: 0.71 [VAL] Loss: 0.5934, Accuracy: 70.05%, Precision: 0.68, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [66/100] - [TRAIN] Loss: 0.5795, Accuracy: 71.23%, AUC: 0.71 [VAL] Loss: 0.5847, Accuracy: 70.69%, Precision: 0.69, Recall: 0.68, F1-Score: 0.69, AUC: 0.71
# Epoch [67/100] - [TRAIN] Loss: 0.5809, Accuracy: 71.15%, AUC: 0.71 [VAL] Loss: 0.5921, Accuracy: 70.17%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [68/100] - [TRAIN] Loss: 0.5812, Accuracy: 71.34%, AUC: 0.71 [VAL] Loss: 0.5860, Accuracy: 70.33%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [69/100] - [TRAIN] Loss: 0.5819, Accuracy: 71.18%, AUC: 0.71 [VAL] Loss: 0.5867, Accuracy: 70.76%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [70/100] - [TRAIN] Loss: 0.5796, Accuracy: 71.29%, AUC: 0.71 [VAL] Loss: 0.5915, Accuracy: 70.46%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [71/100] - [TRAIN] Loss: 0.5809, Accuracy: 71.06%, AUC: 0.71 [VAL] Loss: 0.5800, Accuracy: 70.77%, Precision: 0.71, Recall: 0.64, F1-Score: 0.68, AUC: 0.70
# Epoch [72/100] - [TRAIN] Loss: 0.5817, Accuracy: 70.97%, AUC: 0.71 [VAL] Loss: 0.5816, Accuracy: 70.37%, Precision: 0.69, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [73/100] - [TRAIN] Loss: 0.5808, Accuracy: 71.20%, AUC: 0.71 [VAL] Loss: 0.5880, Accuracy: 70.57%, Precision: 0.72, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [74/100] - [TRAIN] Loss: 0.5817, Accuracy: 70.99%, AUC: 0.71 [VAL] Loss: 0.5925, Accuracy: 70.86%, Precision: 0.70, Recall: 0.67, F1-Score: 0.69, AUC: 0.71
# Epoch [75/100] - [TRAIN] Loss: 0.5816, Accuracy: 71.06%, AUC: 0.71 [VAL] Loss: 0.5872, Accuracy: 70.10%, Precision: 0.68, Recall: 0.68, F1-Score: 0.68, AUC: 0.70
# Epoch [76/100] - [TRAIN] Loss: 0.5802, Accuracy: 71.31%, AUC: 0.71 [VAL] Loss: 0.5911, Accuracy: 70.11%, Precision: 0.72, Recall: 0.61, F1-Score: 0.66, AUC: 0.70
# Epoch [77/100] - [TRAIN] Loss: 0.5801, Accuracy: 71.18%, AUC: 0.71 [VAL] Loss: 0.5916, Accuracy: 69.97%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [78/100] - [TRAIN] Loss: 0.5820, Accuracy: 71.17%, AUC: 0.71 [VAL] Loss: 0.5812, Accuracy: 71.32%, Precision: 0.71, Recall: 0.67, F1-Score: 0.69, AUC: 0.71
# Epoch [79/100] - [TRAIN] Loss: 0.5785, Accuracy: 71.31%, AUC: 0.71 [VAL] Loss: 0.5835, Accuracy: 70.69%, Precision: 0.70, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [80/100] - [TRAIN] Loss: 0.5823, Accuracy: 70.94%, AUC: 0.71 [VAL] Loss: 0.5828, Accuracy: 70.46%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [81/100] - [TRAIN] Loss: 0.5801, Accuracy: 71.23%, AUC: 0.71 [VAL] Loss: 0.5899, Accuracy: 70.83%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.71
# Epoch [82/100] - [TRAIN] Loss: 0.5778, Accuracy: 71.45%, AUC: 0.71 [VAL] Loss: 0.5846, Accuracy: 70.59%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [83/100] - [TRAIN] Loss: 0.5802, Accuracy: 71.11%, AUC: 0.71 [VAL] Loss: 0.5890, Accuracy: 70.29%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70
# Epoch [84/100] - [TRAIN] Loss: 0.5819, Accuracy: 70.94%, AUC: 0.71 [VAL] Loss: 0.5876, Accuracy: 69.98%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [85/100] - [TRAIN] Loss: 0.5778, Accuracy: 71.34%, AUC: 0.71 [VAL] Loss: 0.5789, Accuracy: 70.80%, Precision: 0.71, Recall: 0.67, F1-Score: 0.69, AUC: 0.71
# Epoch [86/100] - [TRAIN] Loss: 0.5803, Accuracy: 71.17%, AUC: 0.71 [VAL] Loss: 0.5929, Accuracy: 69.94%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [87/100] - [TRAIN] Loss: 0.5788, Accuracy: 71.44%, AUC: 0.71 [VAL] Loss: 0.5917, Accuracy: 69.95%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.70
# Epoch [88/100] - [TRAIN] Loss: 0.5774, Accuracy: 71.40%, AUC: 0.71 [VAL] Loss: 0.5811, Accuracy: 70.82%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.71
# Epoch [89/100] - [TRAIN] Loss: 0.5790, Accuracy: 71.15%, AUC: 0.71 [VAL] Loss: 0.5911, Accuracy: 70.77%, Precision: 0.69, Recall: 0.67, F1-Score: 0.68, AUC: 0.71
# Epoch [90/100] - [TRAIN] Loss: 0.5802, Accuracy: 71.10%, AUC: 0.71 [VAL] Loss: 0.5825, Accuracy: 71.01%, Precision: 0.70, Recall: 0.66, F1-Score: 0.68, AUC: 0.71
# Epoch [91/100] - [TRAIN] Loss: 0.5789, Accuracy: 71.04%, AUC: 0.71 [VAL] Loss: 0.5824, Accuracy: 70.37%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [92/100] - [TRAIN] Loss: 0.5820, Accuracy: 70.88%, AUC: 0.71 [VAL] Loss: 0.5883, Accuracy: 70.31%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [93/100] - [TRAIN] Loss: 0.5772, Accuracy: 71.33%, AUC: 0.71 [VAL] Loss: 0.5815, Accuracy: 70.54%, Precision: 0.71, Recall: 0.65, F1-Score: 0.68, AUC: 0.70
# Epoch [94/100] - [TRAIN] Loss: 0.5759, Accuracy: 71.43%, AUC: 0.71 [VAL] Loss: 0.5850, Accuracy: 70.82%, Precision: 0.71, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [95/100] - [TRAIN] Loss: 0.5762, Accuracy: 71.57%, AUC: 0.71 [VAL] Loss: 0.5948, Accuracy: 69.36%, Precision: 0.70, Recall: 0.63, F1-Score: 0.66, AUC: 0.69
# Epoch [96/100] - [TRAIN] Loss: 0.5781, Accuracy: 71.39%, AUC: 0.71 [VAL] Loss: 0.5810, Accuracy: 70.66%, Precision: 0.70, Recall: 0.64, F1-Score: 0.67, AUC: 0.70
# Epoch [97/100] - [TRAIN] Loss: 0.5772, Accuracy: 71.47%, AUC: 0.71 [VAL] Loss: 0.5946, Accuracy: 70.06%, Precision: 0.69, Recall: 0.66, F1-Score: 0.67, AUC: 0.70
# Epoch [98/100] - [TRAIN] Loss: 0.5794, Accuracy: 71.22%, AUC: 0.71 [VAL] Loss: 0.5892, Accuracy: 70.37%, Precision: 0.69, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [99/100] - [TRAIN] Loss: 0.5765, Accuracy: 71.41%, AUC: 0.71 [VAL] Loss: 0.5885, Accuracy: 70.66%, Precision: 0.71, Recall: 0.66, F1-Score: 0.68, AUC: 0.70
# Epoch [100/100] - [TRAIN] Loss: 0.5774, Accuracy: 71.26%, AUC: 0.71 [VAL] Loss: 0.5802, Accuracy: 70.11%, Precision: 0.70, Recall: 0.65, F1-Score: 0.67, AUC: 0.70

# %%
plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies, NUM_ITEMS)

# %% [markdown]
# ## Testing

# %%
# Predict on test set
test_predictions = []
test_true_labels = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        if (MODEL_MODE == "reg") or (MODEL_MODE == "do"):
            outputs = model(X_batch.to(dtype=torch.float32).to(device))
        elif MODEL_MODE == "dol1l2":
            outputs, _, _ = model(X_batch.to(dtype=torch.float32).to(device))
        
        predictions = (outputs.squeeze(1) >= 0.5).long()
        test_true_labels.extend(y_batch.cpu().numpy())
        test_predictions.extend(predictions.cpu().numpy())

# %%
# Evaluation metrics
# Precision, Recall, F1-Score
precision, recall, f1_score, _ = precision_recall_fscore_support(
    test_true_labels, 
    test_predictions, 
    average='binary'  # Use 'macro' for multi-class
)

test_acc_score = accuracy_score(test_true_labels, test_predictions) * 100
test_auc_score = roc_auc_score(test_true_labels, test_predictions)
cr = classification_report(test_true_labels, test_predictions)
cm = confusion_matrix(test_true_labels, test_predictions)

# %%
test_output = f"""Accuracy Score on test set: {test_acc_score:.2f} %
AUC Score on test set: {test_auc_score:.2f}
Precision: {precision:.4f}
Recall: {recall:.4f}
F1-Score: {f1_score:.4f}

Detailed Classification Report:
{cr}

Confusion Matrix:
{cm}
"""

print(test_output)
# Out:
# Accuracy Score on test set: 70.93 %
# AUC Score on test set: 0.71
# Precision: 0.7081
# Recall: 0.6624
# F1-Score: 0.6845
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.75      0.73      5240
#            1       0.71      0.66      0.68      4760
#
#     accuracy                           0.71     10000
#    macro avg       0.71      0.71      0.71     10000
# weighted avg       0.71      0.71      0.71     10000
#
#
# Confusion Matrix:
# [[3940 1300]
#  [1607 3153]]

# %%
# Save the test output to text file
test_file_name = os.path.join(WORKING_DIR, 'output', 'test', MODE, f"{PREFIX}-test-results-{SUFFIX}.txt")
with open(test_file_name, 'w', newline = '') as text_file:
    text_file.write(test_output)

# %% [markdown]
# # Saving all metrics

# %%
# Training metrics
file_name = f"{PREFIX}-train-validation-metrics-{SUFFIX}.csv"
result_file = os.path.join(WORKING_DIR, 'output', 'train', MODE, f"{file_name}")

experiment_results = {
    'train_loss'    : train_losses,
    'train_accuracy': train_accuracies,
    'train_auc'     : train_aucs,
    'val_loss'      : val_losses,
    'val_accuracy'  : val_accuracies,
    'val_auc'       : val_aucs
}

experiment_pl = pl.DataFrame(experiment_results)
experiment_pl.write_csv(result_file)

# %%
# Test output
test_name = f"{PREFIX}-test-metrics-{SUFFIX}.csv"
test_file = os.path.join(WORKING_DIR, 'output', 'test', MODE,f"{test_name}")

test_results = {
    'test_acc'    : round(test_acc_score, 4),
    'test_auc'    : round(test_auc_score, 4)
}

test_pl = pl.DataFrame(test_results)
test_pl.write_csv(test_file)

# %%
# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(test_true_labels, test_predictions) 
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC for HepG2 Ranking')
plt.legend()

img_name = f"{PREFIX}-roc-{SUFFIX}.png"
plt.savefig(os.path.join(WORKING_DIR, 'output', 'img', 'roc', MODE, img_name))

plt.show()

# %%
# Plot the confusion matrix
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm)
fig, ax = plt.subplots(figsize=(10, 8))
cm_display.plot(ax=ax)
img_name = f"{PREFIX}-cm-{SUFFIX}.png"
plt.savefig(os.path.join(WORKING_DIR, 'output', 'img', 'confusion_matrix', MODE, img_name))
