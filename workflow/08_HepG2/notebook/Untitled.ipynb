# %%
import site

# %%
site.getsitepackages()
# Out:
# ['/uwahpc/centos8/python/Anaconda3/2024.06/lib/python3.12/site-packages']

# %%
import smogn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import smogn
#
# ModuleNotFoundError: No module named 'smogn'

# %%
import polars
