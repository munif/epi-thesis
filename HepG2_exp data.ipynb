# %%
import pandas as pd

# %%
hepg2_exp = pd.read_csv("dataset/GSM3718064_HepG2_exp.txt", sep="\t")

# %%
hepg2_exp.head()
# Out:
#        test_id      gene_id                       gene               locus  \
# 0  XLOC_000001  XLOC_000001                      OR4F5    chr1:69090-70008
# 1  XLOC_000002  XLOC_000002  LOC100132062,LOC100133331  chr1:323891-328581
# 2  XLOC_000003  XLOC_000003                     OR4F29  chr1:367658-368597
# 3  XLOC_000004  XLOC_000004                  LOC643837  chr1:761585-794889
# 4  XLOC_000005  XLOC_000005                          -  chr1:840263-843900
#
#     sample_1   sample_2  status   value_1   value_2  log2(fold_change)  \
# 0  hepg2_hr2  hepg2_hr3  NOTEST  0.000000  0.000000           0.000000
# 1  hepg2_hr2  hepg2_hr3  NOTEST  0.047392  0.034159          -0.472389
# 2  hepg2_hr2  hepg2_hr3  NOTEST  0.000000  0.000000           0.000000
# 3  hepg2_hr2  hepg2_hr3      OK  2.468570  2.805800           0.184736
# 4  hepg2_hr2  hepg2_hr3  NOTEST  0.000000  0.000000           0.000000
#
#    test_stat  p_value   q_value significant
# 0   0.000000  1.00000  1.000000          no
# 1   0.000000  1.00000  1.000000          no
# 2   0.000000  1.00000  1.000000          no
# 3   0.455074  0.63585  0.999565          no
# 4   0.000000  1.00000  1.000000          no

# %%
hepg2_exp.shape
# Out:
# (30032, 14)

# %%
hepg2_exp[["locus_chr", "locus_pos"]] = hepg2_exp["locus"].str.split(':', expand=True)
hepg2_exp.head()
# Out:
#        test_id      gene_id                       gene               locus  \
# 0  XLOC_000001  XLOC_000001                      OR4F5    chr1:69090-70008
# 1  XLOC_000002  XLOC_000002  LOC100132062,LOC100133331  chr1:323891-328581
# 2  XLOC_000003  XLOC_000003                     OR4F29  chr1:367658-368597
# 3  XLOC_000004  XLOC_000004                  LOC643837  chr1:761585-794889
# 4  XLOC_000005  XLOC_000005                          -  chr1:840263-843900
#
#     sample_1   sample_2  status   value_1   value_2  log2(fold_change)  \
# 0  hepg2_hr2  hepg2_hr3  NOTEST  0.000000  0.000000           0.000000
# 1  hepg2_hr2  hepg2_hr3  NOTEST  0.047392  0.034159          -0.472389
# 2  hepg2_hr2  hepg2_hr3  NOTEST  0.000000  0.000000           0.000000
# 3  hepg2_hr2  hepg2_hr3      OK  2.468570  2.805800           0.184736
# 4  hepg2_hr2  hepg2_hr3  NOTEST  0.000000  0.000000           0.000000
#
#    test_stat  p_value   q_value significant locus_chr      locus_pos
# 0   0.000000  1.00000  1.000000          no      chr1    69090-70008
# 1   0.000000  1.00000  1.000000          no      chr1  323891-328581
# 2   0.000000  1.00000  1.000000          no      chr1  367658-368597
# 3   0.455074  0.63585  0.999565          no      chr1  761585-794889
# 4   0.000000  1.00000  1.000000          no      chr1  840263-843900

# %%
hepg2_exp[["locus_start", "locus_end"]] = hepg2_exp["locus_pos"].str.split('-', expand=True)
hepg2_exp.head()
# Out:
#        test_id      gene_id                       gene               locus  \
# 0  XLOC_000001  XLOC_000001                      OR4F5    chr1:69090-70008
# 1  XLOC_000002  XLOC_000002  LOC100132062,LOC100133331  chr1:323891-328581
# 2  XLOC_000003  XLOC_000003                     OR4F29  chr1:367658-368597
# 3  XLOC_000004  XLOC_000004                  LOC643837  chr1:761585-794889
# 4  XLOC_000005  XLOC_000005                          -  chr1:840263-843900
#
#     sample_1   sample_2  status   value_1   value_2  log2(fold_change)  \
# 0  hepg2_hr2  hepg2_hr3  NOTEST  0.000000  0.000000           0.000000
# 1  hepg2_hr2  hepg2_hr3  NOTEST  0.047392  0.034159          -0.472389
# 2  hepg2_hr2  hepg2_hr3  NOTEST  0.000000  0.000000           0.000000
# 3  hepg2_hr2  hepg2_hr3      OK  2.468570  2.805800           0.184736
# 4  hepg2_hr2  hepg2_hr3  NOTEST  0.000000  0.000000           0.000000
#
#    test_stat  p_value   q_value significant locus_chr      locus_pos  \
# 0   0.000000  1.00000  1.000000          no      chr1    69090-70008
# 1   0.000000  1.00000  1.000000          no      chr1  323891-328581
# 2   0.000000  1.00000  1.000000          no      chr1  367658-368597
# 3   0.455074  0.63585  0.999565          no      chr1  761585-794889
# 4   0.000000  1.00000  1.000000          no      chr1  840263-843900
#
#   locus_start locus_end
# 0       69090     70008
# 1      323891    328581
# 2      367658    368597
# 3      761585    794889
# 4      840263    843900

# %%
hepg2_exp["locus_chr"].unique()
# Out:
# array(['chr1', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15',
#        'chr16', 'chr17', 'chr17_ctg5_hap1', 'chr17_gl000205_random',
#        'chr18', 'chr19', 'chr19_gl000209_random', 'chr1_gl000191_random',
#        'chr2', 'chr20', 'chr21', 'chr22', 'chr3', 'chr4',
#        'chr4_ctg9_hap1', 'chr4_gl000194_random', 'chr5', 'chr6',
#        'chr6_apd_hap1', 'chr6_cox_hap2', 'chr6_dbb_hap3',
#        'chr6_mann_hap4', 'chr6_mcf_hap5', 'chr6_qbl_hap6',
#        'chr6_ssto_hap7', 'chr7', 'chr8', 'chr9', 'chrM', 'chrUn_gl000211',
#        'chrUn_gl000212', 'chrUn_gl000218', 'chrUn_gl000219',
#        'chrUn_gl000220', 'chrUn_gl000222', 'chrUn_gl000223',
#        'chrUn_gl000228', 'chrX', 'chrY'], dtype=object)
